# %% [markdown]
# # **GROUP PROJECT**

# %% [markdown]
# https://link.springer.com/referenceworkentry/10.1007%2F978-0-387-74759-0_345

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import geopandas as gpd
import random
import pyproj
from shapely.geometry import Point, LineString
import matplotlib.pyplot as plt
import seaborn as sns
import ortools as ort
import datetime as dt
# pysal submodule imports
from pysal.lib import cg, examples
from pysal.explore import spaghetti as spgh

import geopandas as gpd
from shapely.geometry import Point
from ortools.linear_solver import pywraplp
import copy, sys, warnings
from collections import OrderedDict

import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.colors import ListedColormap

try:
    from IPython.display import set_matplotlib_formats
    set_matplotlib_formats('retina')
except ImportError:
    pass

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
from ortools.sat.python import cp_model
# %load_ext line_profiler
# Out:
# C:\Users\Noah\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# # **1. FUNCTIONS**

# %%
def buildCityDF(nCities,gridX=100,gridY=100):
    xs = np.random.randint(0,gridX,nCities)
    ys = np.random.randint(0,gridY,nCities)
    pts = [Point(xs[i],ys[i]) for i in range(0,nCities)]
    demands = np.random.randint(0,101,nCities)
    facilityOneCosts = np.random.randint(0,101,nCities)
    facilityTwoCosts = np.random.randint(100,201,nCities)
    cityIndices = range(0,nCities)
    cities = gpd.GeoDataFrame({"x":xs,"y":ys,"demand":demands,"geometry":pts,"City Index":cityIndices,"Facility One Cost":facilityOneCosts,"Facility Two Cost":facilityTwoCosts})
    return cities

# %%
def buildDistanceMatrix_Euclidean(cities):
    distances = np.zeros((len(cities),len(cities)))
    for i,row in cities.iterrows():
        for j,row2 in cities.iterrows():
            distances[j,i] = row.geometry.distance(row2.geometry)
    return distances

# %%
def assignFacilitiesAndCluster(cities,M = 100,Rvz=[100000,200000],truckCapacityZ = [40000,80000],alpha=75.0,truckCapacity = 80000,fractionTruckRangeAllowed=0.8,nFacility=1,maxTimeLimit=5*60*1000):
    solver_instance = pywraplp.Solver.CBC_MIXED_INTEGER_PROGRAMMING # SAT_INTEGER_PROGRAMMING
#     solver_instance = cp_model.CpModel()
    distances = buildDistanceMatrix_Euclidean(cities)
    cij = distances
    n_customers = cij.shape[0]
    range_customers = range(n_customers)
    n_facilityCandidates = cij.shape[1]
    range_facilityCandidates = range(n_facilityCandidates)
    demands = np.array(cities["demand"])
    demands_sum = demands.sum()
    fiz = facilityCost = cities[["Facility One Cost","Facility Two Cost"]].as_matrix()
    zRange = len(Rvz)
    model = pywraplp.Solver("Capacitated Fixed Charge", solver_instance)
    model.set_time_limit(maxTimeLimit)
    model.SetNumThreads(4)

    xij = {(i,j): model.IntVar(0,1, 'x[%i,%i]' % (i,j)) for i in range_customers for j in range_facilityCandidates} # which facility is served by which 
    yjz = {(j,z): model.IntVar(0,1, 'y[%i,%i]' % (j,z)) for j in range_facilityCandidates for z in range(zRange)} # charging station location decision/ concentrator
    
    obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + alpha*2*cij[0,j]*yjz[j,z] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]
#     obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]

    # Service Constraint
    for i in range_customers:
        model.Add(model.Sum([xij[i,j] for j in range_facilityCandidates]) == nFacility)
    
    # Capacity Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([demands[i] * xij[i,j] for i in range_facilityCandidates]) <= model.Sum([truckCapacityZ[z]*yjz[j,z] for z in range(zRange)]))
    
    # Assignment Constraint
    for i in range_customers:
        for j in range_facilityCandidates:
            model.Add(xij[i,j] <= model.Sum([yjz[j,z] for z in range(zRange)]))
    
    # Maximum Concentratorrs Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for j in range_facilityCandidates for z in range(zRange)]) <= M)
        
    # Total tour length constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([xij[i,j]*cij[i,j] for i in range_facilityCandidates]) <= model.Sum([yjz[j,z]*Rvz[z]*fractionTruckRangeAllowed for z in range(zRange)]))
        
    # Z limitation constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for z in range(zRange)]) <= 1)

    model.Minimize(model.Sum(obj))
    status = model.Solve()

    if status == pywraplp.Solver.OPTIMAL:
        print('Optimal Solution Found')

    resultGDF = cities.copy(deep=True)
    for z in range(2):
        resultGDF[f"Status: Facility Type {z}"] = [yjz[j,z].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 0"] = [yjz[j,0].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 1"] = [yjz[j,1].solution_value() for j in range_facilityCandidates]
    return model,yjz,xij,resultGDF,status

# %%
def assignFacilitiesAndCluster(cities,M = 100,Rvz=[100000,200000],truckCapacityZ = [40000,80000],alpha=75.0,truckCapacity = 80000,fractionTruckRangeAllowed=0.8,nFacility=1,maxTimeLimit=5*60*1000,tourLengthViolationPenalty = 500):
    solver_instance = pywraplp.Solver.CBC_MIXED_INTEGER_PROGRAMMING
#     solver_instance = cp_model.CpModel()
    distances = buildDistanceMatrix_Euclidean(cities)
    cij = distances
    n_customers = cij.shape[0]
    range_customers = range(n_customers)
    n_facilityCandidates = cij.shape[1]
    range_facilityCandidates = range(n_facilityCandidates)
    demands = np.array(cities["demand"])
    demands_sum = demands.sum()
    fiz = facilityCost = cities[["Facility One Cost","Facility Two Cost"]].as_matrix()
    zRange = len(Rvz)
    model = pywraplp.Solver("Capacitated Fixed Charge", solver_instance)
    model.set_time_limit(maxTimeLimit)

#     model.parameters.max_time_in_seconds = 60.0 * 5

    xij = {(i,j): model.IntVar(0,1, 'x[%i,%i]' % (i,j)) for i in range_customers for j in range_facilityCandidates} # which facility is served by which 
    yjz = {(j,z): model.IntVar(0,1, 'y[%i,%i]' % (j,z)) for j in range_facilityCandidates for z in range(zRange)} # charging station location decision/ concentrator
    obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + alpha*2*cij[0,j]*yjz[j,z] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]
#     tourLengthObj = [tourLengthViolationPenalty * model.Sum([yjz[j,z]*Rvz[z]-xij[i,j]*cij[i,j] for i in range_customers for z in range(zRange)]) for j in range_customers]
#     tourLengthObj = [tourLengthViolationPenalty * yjz[j,0]*Rvz[0]+yjz[j,1]*Rvz[1]-xij[i,j]*cij[i,j] for i in range_customers for j in range_facilityCandidates]
#     obj = obj.extend(tourLengthObj)
    obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + alpha*2*cij[0,j]*yjz[j,z] + fiz[i,z] * yjz[j,z] + tourLengthViolationPenalty * (yjz[j,0]*Rvz[0]+yjz[j,1]*Rvz[1]-xij[i,j]*cij[i,j]) for i in range_customers for j in range_facilityCandidates for z in range(zRange)]

    # Service Constraint
    for i in range_customers:
        model.Add(model.Sum([xij[i,j] for j in range_facilityCandidates]) == nFacility)
    
    # Capacity Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([demands[i] * xij[i,j] for i in range_facilityCandidates]) <= model.Sum([truckCapacityZ[z]*yjz[j,z] for z in range(zRange)]))
    
    # Assignment Constraint
    for i in range_customers:
        for j in range_facilityCandidates:
            model.Add(xij[i,j] <= model.Sum([yjz[j,z] for z in range(zRange)]))
    
    # Maximum Concentratorrs Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for j in range_facilityCandidates for z in range(zRange)]) <= M)
        
    # Total tour length constraint
#     for j in range_facilityCandidates:
#         model.Add(model.Sum([xij[i,j]*cij[i,j] for i in range_facilityCandidates]) <= model.Sum([yjz[j,z]*Rvz[z]*fractionTruckRangeAllowed for z in range(zRange)]))
        
    # Z limitation constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for z in range(zRange)]) <= 1)

    model.Minimize(model.Sum(obj))
    status = model.Solve()

    if status == pywraplp.Solver.OPTIMAL:
        print('Optimal Solution Found')

    resultGDF = cities.copy(deep=True)
    for z in range(2):
        resultGDF[f"Status: Facility Type {z}"] = [yjz[j,z].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 0"] = [yjz[j,0].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 1"] = [yjz[j,1].solution_value() for j in range_facilityCandidates]
    return model,yjz,xij,resultGDF,status

# %%
def convertTourToPathDF(tour,resultGDF):
#     tour = list(resultGDF[resultGDF["assignment"]==tour]["City Index"])
    tour.append(tour[0]) # Return to end
    startNodes = []
    endNodes = []
    startCoords = []
    endCoords = []
    lines = [] # https://gis.stackexchange.com/questions/95670/how-to-create-a-shapely-linestring-from-two-points
    for i in range(0,len(tour)):
        currentCity = tour[i]
        if i < len(tour)-1:
            nextCity = tour[i+1]
        else:
            nextCity = tour[0]
        startNodes.append(currentCity)
        endNodes.append(nextCity)
        startPoint = resultGDF[resultGDF["City Index"]==currentCity].geometry
        startCoords.append(startPoint)
        endPoint = resultGDF[resultGDF["City Index"]==nextCity].geometry
        endCoords.append(endPoint)
        line = LineString([(startPoint.x,startPoint.y),(endPoint.x,endPoint.y)])
        lines.append(line)
    gdf = gpd.GeoDataFrame({"Start Node":startNodes,"End Node":endNodes,"geometry":lines})
    return gdf

# %%
# https://developers.google.com/optimization/routing/tsp
"""Simple travelling salesman problem between cities."""

def create_data_model(dfSubset):
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = buildDistanceMatrix_Euclidean(dfSubset.reset_index())
    data['num_vehicles'] = 1
    data['depot'] = 0
    return data


def print_solution(manager, routing, assignment,dfSubset):
    """Prints assignment on console."""
    optimizedRoute = []
#     print(f"Objective: ")
#     print('Objective: {} meters'.format(assignment.ObjectiveValue()))
    index = routing.Start(0)
    plan_output = 'Route for vehicle 0:\n'
    route_distance = 0
    orderedDFSubset = dfSubset.reset_index()
    while not routing.IsEnd(index):
        correctedCityIndex = orderedDFSubset.iloc[manager.IndexToNode(index)][0]
        optimizedRoute.append(correctedCityIndex)
#         print(f"******{correctedCityIndex}")
#         print(f"====>{orderedDFSubset.iloc[manager.IndexToNode(index)]}")
#         plan_output += ' {} ->'.format(manager.IndexToNode(index))
        plan_output += ' {} ->'.format(correctedCityIndex)

        previous_index = index
        index = assignment.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
#     plan_output += ' {}\n'.format(manager.IndexToNode(index))
    correctedCityIndex = orderedDFSubset.iloc[manager.IndexToNode(index)][0]
    plan_output += ' {}\n'.format(correctedCityIndex)
#     print(f"******{correctedCityIndex}")
    optimizedRoute.append(correctedCityIndex)
#     print(f"====>{orderedDFSubset.iloc[manager.IndexToNode(index)]}")
    plan_output += f'Route distance: {route_distance/1000.0} km\n'
    print(plan_output)
    return optimizedRoute,route_distance


def main(dfSubset):
    """Entry point of the program."""
    # Instantiate the data problem.
    data = create_data_model(dfSubset)

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    # Solve the problem.
    assignment = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if assignment:
        route,route_distance = print_solution(manager, routing, assignment,dfSubset)
    return route,route_distance

# %%
def solveAndPlot(illinoisCities,M=20,Rvz=[200000,400000],truckCapacityZ = [40000,80000],alpha=0.001,fractionTruckRangeAllowed=0.75,maxTimeLimit=5*60*1000):
    model,yjz,xij,resultGDF,status = assignFacilitiesAndCluster(illinoisCities,M=M,Rvz=Rvz,truckCapacityZ=truckCapacityZ,alpha=alpha,fractionTruckRangeAllowed=fractionTruckRangeAllowed,maxTimeLimit=maxTimeLimit)
    assignments = np.zeros((nCities,nCities))
    for k,v in xij.items():
        i = k[0]
        j = k[1]
        assignments[i,j] = v.solution_value()
    cluster = []
    for cityNodeID in range(nCities):
        for rootNodeID in range(nCities):
            lookup = assignments[cityNodeID,rootNodeID]
            if lookup == 1:
                cluster.append(rootNodeID)
    resultGDF["assignment"] = cluster
    uniqueClusters = list(set(cluster))


    fig = plt.figure(figsize=(20,20))
    ax1 = fig.add_subplot(1,2,1)
    ax2 = fig.add_subplot(1,2,2)
    fig.tight_layout()

    illinois.plot(ax=ax1,color="blue",alpha=0.1)
    illinois.sort_values("ALAND",ascending=False).reset_index()[0:nCities].plot(ax=ax1,color="red",alpha=0.2)
    # illinois.sort_values("ALAND",ascending=False).reset_index()[0:40].centroid.plot(ax=ax1,color="white",marker='*')

    colors = ['#'+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(len(uniqueClusters))]
    totalCost = 0.0
    subtourRoutingCosts = {}
    subtourConstructionCosts = {}
    subtourDistances = {}
    totalConstructionCost = np.sum(resultGDF["Facility One Cost"] * resultGDF["Status: Facility Type 0"] + resultGDF["Facility Two Cost"] * resultGDF["Status: Facility Type 1"])
    for i in range(0,len(uniqueClusters)):
        dfSubset = resultGDF[resultGDF["assignment"]==uniqueClusters[i]]
        tour,tourLength = main(dfSubset)
        if resultGDF.iloc[uniqueClusters[i]]["Status: Facility Type 0"]==1:
            facilityType = 0
            vehicleType = "Standard range"
        else:
            facilityType = 1
            vehicleType = "Extended range"
        subtourRoutingCosts[i] = alpha * tourLength
        subtourDistances[i] = tourLength
        # check if constraint violated
        label = f"{resultGDF.iloc[uniqueClusters[i]].Name}: {tourLength/1000:,.0f} KM, {vehicleType} vehicle"
        if tourLength > Rvz[facilityType]:
            label += " CONSTRAINT VIOLATED"
        # plot the nodes
        dfSubset.plot(ax=ax1,color=colors[i],markersize=dfSubset["demand"]/100,label=label)
        # plot the tour
        ls = "dashed"
        if facilityType == 1:
            ls = "dotted"
        convertTourToPathDF(tour,resultGDF).plot(ax=ax1,colors=colors[i],ls=ls,alpha=0.75)
        # plot the facilities
        dfFacility = resultGDF[resultGDF["City Index"]==uniqueClusters[i]]
        dfFacility.plot(ax=ax1,markersize=1000,marker="o",alpha=.75,facecolors='none', edgecolors=colors[i])
    totalRoutingCost = np.sum(list(subtourRoutingCosts.values()))
    totalRoutingDistance = np.sum(list(subtourDistances.values()))
    f""
    ax1.set_title(f"Tours organized by cluster\nNode sizes proportional to demand\nConstruction Cost: ${totalConstructionCost:,.2f}, Routing Distance: {totalRoutingDistance/1000:,.0f} KM\n$Total Cost: {totalConstructionCost + totalRoutingCost:,.2f}")
    ax1.legend()
    # Plot assignments
    plt.imshow(assignments)
    ax2.set_title("Assignment of citites to subtours")
    ax2.set_xlabel("Subtour Root (Flag/Concentrator) Node")
    ax2.set_ylabel("City")

# %% [markdown]
# # **2. SET UP CITIES**

# %%
illinoisCitiesPath = "Final Presentation\\tl_2016_17_place\\tl_2016_17_place.shp"
illinoisCitiesPath = "Final Presentation\\illinois_projected.shp"
illinois = gpd.read_file(illinoisCitiesPath)

# %%
nCities = 50
facilityOneBaseCost = 100000
facilityOneBaseSTD = 10000
facilityTwoBaseCost = 1000000
facilityTwoBaseSTD = 100000
baseDemand = 10000
baseDemandSTD = 10000
demands = np.random.normal(baseDemand, baseDemandSTD, nCities)
demands = [np.abs(demand) for demand in demands]
facilityOneCosts = np.random.normal(facilityOneBaseCost, facilityOneBaseSTD, nCities)
facilityOneCosts = [np.abs(facilityOneCost) for facilityOneCost in facilityOneCosts]
facilityTwoCosts = np.random.normal(facilityTwoBaseCost, facilityTwoBaseSTD, nCities)
facilityTwoCosts = [np.abs(facilityTwoCost) for facilityTwoCost in facilityTwoCosts]
cityIndices = range(nCities)
xs = []
ys = []
pts = []
polygons = []
cityNames = []
illinoisGeoms = illinois.sort_values("ALAND",ascending=False).reset_index()
for i,row in illinoisGeoms[0:nCities].iterrows():
    pts.append(row["geometry"].centroid)
    polygons.append(row["geometry"])
    xs.append(row["geometry"].centroid.x)
    ys.append(row["geometry"].centroid.y)
    cityNames.append(row["NAME"])


illinoisCities = gpd.GeoDataFrame({"x":xs,"y":ys,"demand":demands,"geometry":pts,"polygon":polygons,"City Index":cityIndices,"Facility One Cost":facilityOneCosts,"Facility Two Cost":facilityTwoCosts,"Name":cityNames})

# %% [markdown]
# # **3. SOLVE TSP SUB-TOURS**

# %%
# %prun solveAndPlot(illinoisCities,M=10,Rvz=[300000,600000],truckCapacityZ=[40000,80000],alpha=0.01,fractionTruckRangeAllowed=0.75,maxTimeLimit=2*60*1000)

# %%
# %prun solveAndPlot(illinoisCities,M=6,Rvz=[300000,600000],truckCapacityZ=[40000,80000],alpha=0.001,fractionTruckRangeAllowed=0.75,maxTimeLimit=2*60*1000)
# Out:
# Route for vehicle 0:
#  0 -> 1 -> 5 -> 2 -> 13 -> 0
# Route distance: 440.086 km
#
# Route for vehicle 0:
#  3 -> 9 -> 24 -> 15 -> 22 -> 3
# Route distance: 385.905 km
#
# Route for vehicle 0:
#  12 -> 26 -> 17 -> 14 -> 19 -> 23 -> 12
# Route distance: 234.132 km
#
# Route for vehicle 0:
#  18 -> 28 -> 18
# Route distance: 435.03 km
#
# Route for vehicle 0:
#  7 -> 25 -> 11 -> 8 -> 20 -> 16 -> 7
# Route distance: 612.231 km
#
# Route for vehicle 0:
#  4 -> 21 -> 27 -> 10 -> 6 -> 29 -> 4
# Route distance: 493.487 km
#          3785839 function calls (3750139 primitive calls) in 129.593 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1  119.595  119.595  119.595  119.595 {built-in method ortools.linear_solver._pywraplp.Solver_Solve}
#       210    1.516    0.007    1.586    0.008 {method 'draw_path_collection' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      5542    0.297    0.000    0.614    0.000 coords.py:124(array_interface)
# 44060/43718    0.258    0.000    1.088    0.000 {built-in method numpy.array}
#     22324    0.257    0.000    0.428    0.000 coords.py:48(__len__)
#     28106    0.211    0.000    0.219    0.000 coords.py:44(_update)
#     24986    0.191    0.000    0.242    0.000 predicates.py:23(__call__)
#    280359    0.163    0.000    0.286    0.000 {built-in method builtins.isinstance}
#       594    0.147    0.000    0.147    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#     12637    0.146    0.000    0.146    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      7168    0.139    0.000    0.234    0.000 polygon.py:183(_get_ring)
#     79878    0.123    0.000    0.157    0.000 __init__.py:810(__getitem__)
#         1    0.123    0.123    0.267    0.267 <ipython-input-4-f2b12116fc1d>:20(<listcomp>)
#      3860    0.118    0.000    0.196    0.000 cycler.py:349(by_key)
# 238464/238446    0.117    0.000    0.553    0.000 {built-in method builtins.getattr}
#     24986    0.117    0.000    0.397    0.000 base.py:640(is_empty)
#      5500    0.111    0.000    0.498    0.000 patch.py:33(coding)
# 78137/67232    0.109    0.000    0.159    0.000 artist.py:219(stale)
#     13332    0.103    0.000    0.480    0.000 colors.py:149(to_rgba)
#      8403    0.098    0.000    0.197    0.000 fromnumeric.py:69(_wrapreduction)
#      8735    0.090    0.000    0.090    0.000 {built-in method numpy.concatenate}
#       220    0.084    0.000    0.086    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      4226    0.071    0.000    0.105    0.000 artist.py:74(__init__)
#     82565    0.060    0.000    0.074    0.000 generic.py:7(_check)
#      3832    0.059    0.000    0.156    0.000 polygon.py:246(exterior)
#      1928    0.057    0.000    0.800    0.000 patches.py:42(__init__)
#      1110    0.052    0.000    0.436    0.000 lines.py:273(__init__)
#      9412    0.051    0.000    0.051    0.000 base.py:67(geometry_type_name)
#      1916    0.051    0.000    1.385    0.001 patch.py:63(<listcomp>)
#     61260    0.050    0.000    0.100    0.000 pywraplp.py:419(__getattr__)
# 82495/72339    0.049    0.000    0.291    0.000 {built-in method builtins.len}
#      6487    0.049    0.000    0.049    0.000 {built-in method numpy.empty}
#       890    0.045    0.000    0.148    0.000 lines.py:667(recache)
#      2435    0.044    0.000    0.751    0.000 series.py:152(__init__)
#      4262    0.043    0.000    0.043    0.000 {built-in method numpy.dot}
#     37377    0.043    0.000    0.091    0.000 {built-in method builtins.hasattr}
#     14012    0.043    0.000    0.043    0.000 {method 'match' of 're.Pattern' objects}
#      1916    0.042    0.000    2.591    0.001 patch.py:29(PolygonPath)
#      1320    0.040    0.000    0.403    0.000 text.py:655(draw)
#     42464    0.038    0.000    0.038    0.000 cycler.py:227(<genexpr>)
#      1560    0.038    0.000    0.289    0.000 lines.py:751(draw)
#      2973    0.038    0.000    0.220    0.000 path.py:96(__init__)
#      5500    0.037    0.000    0.037    0.000 {built-in method numpy.copyto}
#    124886    0.037    0.000    0.037    0.000 base.py:253(_geom)
#      2973    0.037    0.000    0.147    0.000 path.py:188(_update_values)
#     52149    0.037    0.000    0.039    0.000 {built-in method _abc._abc_instancecheck}
#     17978    0.036    0.000    0.076    0.000 common.py:1845(_is_dtype_type)
#       336    0.035    0.000    0.817    0.002 ticker.py:2016(_raw_ticks)
#      7168    0.035    0.000    0.035    0.000 {built-in method builtins.repr}
#      2810    0.035    0.000    0.052    0.000 blocks.py:78(__init__)
#     11809    0.034    0.000    0.049    0.000 base.py:257(_geom)
#      1916    0.034    0.000    0.636    0.000 patch.py:64(<listcomp>)
#        20    0.034    0.002    0.034    0.002 {method 'clear' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     79881    0.034    0.000    0.034    0.000 {function RcParams.__getitem__ at 0x000001D4E5472158}
#     78747    0.034    0.000    0.034    0.000 artist.py:774(get_animated)
#     13332    0.034    0.000    0.149    0.000 colors.py:115(_is_nth_color)
#      1916    0.034    0.000    0.874    0.000 patch.py:67(<listcomp>)
#      7438    0.032    0.000    0.081    0.000 dtypes.py:68(find)
#     11282    0.032    0.000    0.198    0.000 base.py:320(_get_coords)
#     13341    0.031    0.000    0.046    0.000 re.py:271(_compile)
#     11000    0.030    0.000    0.264    0.000 polygon.py:139(__next__)
#     45152    0.030    0.000    0.030    0.000 path.py:197(vertices)
#     27110    0.030    0.000    0.049    0.000 topology.py:16(_validate)
#       520    0.029    0.000    0.035    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     26048    0.029    0.000    0.029    0.000 impl.py:56(__getitem__)
#     18629    0.029    0.000    0.124    0.000 base.py:75(is_dtype)
#      3867    0.029    0.000    0.411    0.000 patches.py:303(_set_facecolor)
#      3867    0.029    0.000    0.108    0.000 patches.py:277(_set_edgecolor)
#      2037    0.028    0.000    0.362    0.000 construction.py:537(sanitize_array)
#     55931    0.027    0.000    0.027    0.000 {built-in method builtins.issubclass}
#     23660    0.027    0.000    0.027    0.000 base.py:222(empty)
#     13340    0.026    0.000    0.112    0.000 re.py:170(match)
#      5542    0.025    0.000    0.817    0.000 linestring.py:84(array_interface)
#      1051    0.025    0.000    0.062    0.000 linear_solver_natural_api.py:95(GetCoeffs)
#      4559    0.025    0.000    0.045    0.000 generic.py:5069(__setattr__)
#      2324    0.024    0.000    0.114    0.000 cast.py:953(maybe_cast_to_datetime)
#   4244/20    0.024    0.000    3.906    0.195 artist.py:30(draw_wrapper)
#      1916    0.024    0.000    0.479    0.000 patch.py:68(<listcomp>)
#      1928    0.024    0.000    0.059    0.000 patches.py:375(set_linestyle)
#     16724    0.023    0.000    0.023    0.000 transforms.py:82(__init__)
#      5500    0.023    0.000    0.101    0.000 numeric.py:175(ones)
#     15257    0.023    0.000    0.052    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
# 23010/22675    0.023    0.000    1.042    0.000 numeric.py:469(asarray)
#       168    0.022    0.000    1.152    0.007 axis.py:1074(_update_ticks)
#      3070    0.022    0.000    0.027    0.000 lines.py:31(_get_dash_pattern)
#     52149    0.021    0.000    0.061    0.000 abc.py:137(__instancecheck__)
#     11809    0.021    0.000    0.034    0.000 base.py:233(__del__)
#      3832    0.021    0.000    0.021    0.000 polygon.py:150(__len__)
#        20    0.021    0.001    0.023    0.001 {built-in method matplotlib._path.get_path_collection_extents}
#      1260    0.021    0.000    0.033    0.000 {pandas._libs.lib.infer_dtype}
#     13131    0.021    0.000    0.039    0.000 transforms.py:1683(__init__)
#      2134    0.021    0.000    0.136    0.000 blocks.py:3034(get_block_type)
#      4200    0.020    0.000    0.058    0.000 _dtype.py:319(_name_get)
#      5287    0.020    0.000    0.020    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     69480    0.020    0.000    0.020    0.000 linear_solver_natural_api.py:164(__init__)
#       370    0.019    0.000    0.803    0.002 axis.py:56(__init__)
#      7304    0.019    0.000    0.027    0.000 {method 'format' of 'str' objects}
#      6635    0.019    0.000    0.059    0.000 common.py:1981(pandas_dtype)
#      3832    0.019    0.000    0.111    0.000 polygon.py:260(interiors)
# 18802/15986    0.019    0.000    0.041    0.000 {built-in method builtins.hash}
#      3410    0.019    0.000    0.031    0.000 font_manager.py:660(__hash__)
#      2060    0.018    0.000    0.095    0.000 artist.py:942(update)
#      3060    0.018    0.000    0.020    0.000 contextlib.py:81(__init__)
#       540    0.018    0.000    0.018    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#       540    0.018    0.000    0.254    0.000 backend_agg.py:164(draw_text)
#      1062    0.017    0.000    0.033    0.000 topology.py:44(__call__)
#      4295    0.017    0.000    0.029    0.000 {pandas._libs.lib.is_scalar}
#      1088    0.017    0.000    0.035    0.000 transforms.py:671(translated)
#      1240    0.017    0.000    0.217    0.000 text.py:852(get_window_extent)
#      4392    0.017    0.000    0.033    0.000 common.py:160(is_sparse)
#       336    0.017    0.000    0.059    0.000 ticker.py:764(_set_format)
#     11000    0.017    0.000    0.017    0.000 polygon.py:31(__init__)
#      1916    0.017    0.000    0.018    0.000 patch.py:10(__init__)
#      2019    0.016    0.000    0.246    0.000 construction.py:684(_try_cast)
#      7168    0.016    0.000    0.059    0.000 polygon.py:180(gtag)
#      6928    0.016    0.000    0.068    0.000 common.py:1702(is_extension_array_dtype)
#       540    0.016    0.000    0.018    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1490    0.016    0.000    0.047    0.000 backend_bases.py:718(__init__)
#      5543    0.016    0.000    0.047    0.000 __init__.py:1382(_to_unmasked_float_array)
#      4560    0.016    0.000    0.023    0.000 __init__.py:2012(_setattr_cm)
#      7983    0.016    0.000    0.042    0.000 common.py:131(is_object_dtype)
#      2435    0.015    0.000    0.212    0.000 managers.py:1443(__init__)
#       384    0.015    0.000    0.349    0.001 ops.py:1660(wrapper)
#      2232    0.015    0.000    0.085    0.000 base.py:4342(get_value)
#      1643    0.014    0.000    0.047    0.000 cast.py:832(maybe_castable)
#      4915    0.014    0.000    0.143    0.000 generic.py:5053(__getattr__)
#      1248    0.014    0.000    0.014    0.000 transforms.py:2867(_interval_contains_close)
#     72568    0.014    0.000    0.014    0.000 {method 'append' of 'list' objects}
# 2320/1970    0.014    0.000    0.059    0.000 transforms.py:2395(get_affine)
#      2751    0.014    0.000    0.016    0.000 transforms.py:164(set_children)
#      1628    0.014    0.000    0.080    0.000 text.py:270(_get_layout)
#       336    0.014    0.000    0.032    0.000 ticker.py:688(_compute_offset)
#      9412    0.014    0.000    0.068    0.000 base.py:347(geometryType)
#      1971    0.013    0.000    0.034    0.000 transforms.py:726(__init__)
#     10252    0.013    0.000    0.016    0.000 __init__.py:2151(_check_in_list)
#      1916    0.013    0.000    3.409    0.002 patch.py:73(PolygonPatch)
#      2532    0.013    0.000    0.013    0.000 common.py:122(classes_and_not_datetimelike)
#      2376    0.013    0.000    0.075    0.000 markers.py:245(_recache)
#     43183    0.013    0.000    0.013    0.000 path.py:211(codes)
#         1    0.013    0.013  129.611  129.611 <ipython-input-8-52f7402de033>:1(solveAndPlot)
#      6801    0.013    0.000    0.032    0.000 inference.py:253(is_list_like)
#     42323    0.013    0.000    0.013    0.000 path.py:230(simplify_threshold)
#     34004    0.012    0.000    0.012    0.000 {method 'items' of 'dict' objects}
#      1184    0.012    0.000    0.012    0.000 {method 'round' of 'numpy.ndarray' objects}
#      1248    0.012    0.000    0.019    0.000 ticker.py:576(__call__)
#      2810    0.012    0.000    0.205    0.000 blocks.py:3080(make_block)
#      1317    0.012    0.000    0.057    0.000 transforms.py:1976(scale)
#      3864    0.012    0.000    0.012    0.000 cycler.py:138(keys)
#      5038    0.012    0.000    0.033    0.000 transforms.py:1819(__init__)
#      2232    0.011    0.000    0.153    0.000 series.py:865(__getitem__)
#      8400    0.011    0.000    0.027    0.000 numerictypes.py:293(issubclass_)
#      6952    0.011    0.000    0.067    0.000 base.py:421(geom_type)
#      3832    0.011    0.000    0.012    0.000 polygon.py:129(__init__)
#         7    0.011    0.002    0.543    0.078 <ipython-input-3-a4e7a57e50e3>:1(buildDistanceMatrix_Euclidean)
#       440    0.011    0.000    0.025    0.000 patches.py:504(_bind_draw_path_function)
#      1628    0.011    0.000    0.044    0.000 text.py:823(get_prop_tup)
#     25740    0.011    0.000    0.039    0.000 linear_solver_natural_api.py:52(CastToLinExp)
#     24986    0.011    0.000    0.011    0.000 geos.py:545(errcheck_predicate)
#      1188    0.011    0.000    0.096    0.000 markers.py:292(set_marker)
#      1548    0.011    0.000    0.011    0.000 numeric.py:2758(geterr)
#     42323    0.010    0.000    0.010    0.000 path.py:251(should_simplify)
#      2350    0.010    0.000    0.010    0.000 {built-in method matplotlib._path.affine_transform}
#       803    0.010    0.000    0.056    0.000 font_manager.py:620(__init__)
#      1110    0.010    0.000    0.023    0.000 lines.py:1145(set_linestyle)
#      6144    0.010    0.000    0.023    0.000 lines.py:59(_scale_dashes)
# 2678/1768    0.010    0.000    0.012    0.000 transforms.py:137(_invalidate_internal)
#      8340    0.010    0.000    0.034    0.000 linear_solver_natural_api.py:174(__init__)
#      2232    0.010    0.000    0.018    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#      1080    0.010    0.000    0.010    0.000 {method 'round' of 'numpy.generic' objects}
#      5671    0.010    0.000    0.012    0.000 linear_solver_natural_api.py:214(AddSelfToCoeffMapOrStack)
#       761    0.010    0.000    0.072    0.000 text.py:121(__init__)
#      4200    0.010    0.000    0.038    0.000 numerictypes.py:365(issubdtype)
#      7955    0.010    0.000    0.063    0.000 common.py:434(is_datetime64tz_dtype)
#      3832    0.010    0.000    0.031    0.000 polygon.py:134(__iter__)
#      2851    0.010    0.000    0.027    0.000 dtypes.py:827(is_dtype)
#       890    0.010    0.000    0.010    0.000 stride_tricks.py:185(_broadcast_shape)
#     23866    0.010    0.000    0.010    0.000 {built-in method _ctypes.byref}
#       376    0.010    0.000    0.276    0.001 base.py:103(_unary_op)
#      8403    0.010    0.000    0.010    0.000 fromnumeric.py:70(<dictcomp>)
#     11282    0.010    0.000    0.010    0.000 coords.py:41(__init__)
#       288    0.010    0.000    0.010    0.000 {pandas._libs.ops.scalar_compare}
#       336    0.010    0.000    0.016    0.000 ticker.py:727(_set_order_of_magnitude)
#      9512    0.010    0.000    0.012    0.000 base.py:652(__len__)
#      3864    0.010    0.000    0.012    0.000 cycler.py:225(__iter__)
#      1752    0.010    0.000    0.121    0.000 transforms.py:1470(transform_point)
#       462    0.009    0.000    0.013    0.000 transforms.py:2791(nonsingular)
#        48    0.009    0.000    0.009    0.000 socket.py:337(send)
#      8725    0.009    0.000    0.013    0.000 artist.py:338(pchanged)
#      1796    0.009    0.000    0.099    0.000 transforms.py:1377(transform)
#      8220    0.009    0.000    0.060    0.000 pywraplp.py:569(<lambda>)
#      3832    0.009    0.000    0.040    0.000 common.py:403(is_datetime64_dtype)
# 1488/1480    0.009    0.000    0.013    0.000 spines.py:487(get_spine_transform)
#      2719    0.009    0.000    0.025    0.000 dtypes.py:973(is_dtype)
#      2868    0.009    0.000    0.023    0.000 text.py:809(get_unitless_position)
#      1548    0.009    0.000    0.025    0.000 numeric.py:2656(seterr)
#       926    0.009    0.000    0.024    0.000 shape_base.py:599(column_stack)
#      2435    0.009    0.000    0.012    0.000 series.py:354(_set_axis)
#      1140    0.009    0.000    0.036    0.000 cast.py:846(maybe_infer_to_datetimelike)
#      5251    0.009    0.000    0.048    0.000 common.py:572(is_categorical_dtype)
# 6604/3459    0.009    0.000    0.011    0.000 transforms.py:2357(<lambda>)
#     15446    0.008    0.000    0.008    0.000 common.py:117(classes)
#      1916    0.008    0.000    0.805    0.000 patches.py:942(__init__)
#      2849    0.008    0.000    0.010    0.000 blocks.py:199(mgr_locs)
#       294    0.008    0.000    0.055    0.000 algorithms.py:1544(take_nd)
#      2554    0.008    0.000    0.008    0.000 generic.py:127(__init__)
#      5511    0.008    0.000    0.032    0.000 artist.py:49(_stale_axes_callback)
#      1928    0.008    0.000    0.251    0.000 patches.py:409(set_fill)
#      4532    0.008    0.000    0.014    0.000 managers.py:1549(internal_values)
#       805    0.008    0.000    0.009    0.000 font_manager.py:776(set_weight)
#      9473    0.008    0.000    0.008    0.000 {method 'get' of 'dict' objects}
#      2468    0.008    0.000    0.022    0.000 common.py:472(is_timedelta64_dtype)
#      5671    0.008    0.000    0.032    0.000 linear_solver_natural_api.py:209(<listcomp>)
#     27040    0.008    0.000    0.008    0.000 artist.py:194(axes)
#      3467    0.008    0.000    0.014    0.000 series.py:392(name)
#      1050    0.008    0.000    0.054    0.000 linear_solver_natural_api.py:251(Extract)
#      3060    0.008    0.000    0.019    0.000 contextlib.py:116(__exit__)
#      3411    0.008    0.000    0.026    0.000 transforms.py:2470(composite_transform_factory)
#     15446    0.008    0.000    0.012    0.000 common.py:119(<lambda>)
# 2312/2310    0.008    0.000    0.021    0.000 transforms.py:1776(transform_affine)
#      1938    0.008    0.000    0.017    0.000 patches.py:355(set_linewidth)
#     12688    0.008    0.000    0.008    0.000 linear_solver_natural_api.py:167(AddSelfToCoeffMapOrStack)
#         1    0.008    0.008    0.008    0.008 backend_agg.py:80(__init__)
#       520    0.008    0.000    0.703    0.001 axis.py:289(draw)
#   219/197    0.008    0.000    0.042    0.000 base.py:253(__new__)
#      6453    0.008    0.000    0.060    0.000 {built-in method builtins.next}
#         6    0.007    0.001    0.011    0.002 {built-in method ortools.constraint_solver._pywrapcp.RoutingModel_SolveWithParameters}
#       134    0.007    0.000    0.015    0.000 managers.py:186(_rebuild_blknos_and_blklocs)
#       210    0.007    0.000    1.638    0.008 collections.py:249(draw)
#      5293    0.007    0.000    0.021    0.000 {pandas._libs.lib.values_from_object}
#     12916    0.007    0.000    0.007    0.000 managers.py:1488(_block)
#      4810    0.007    0.000    0.012    0.000 artist.py:373(get_transform)
#      2851    0.007    0.000    0.035    0.000 common.py:503(is_period_dtype)
#      5556    0.007    0.000    0.013    0.000 managers.py:1522(dtype)
#       594    0.007    0.000    0.032    0.000 font_manager.py:1179(findfont)
#       890    0.007    0.000    0.025    0.000 stride_tricks.py:208(broadcast_arrays)
#      3060    0.007    0.000    0.027    0.000 contextlib.py:237(helper)
#      1796    0.007    0.000    0.071    0.000 transforms.py:2371(transform_affine)
#      1281    0.007    0.000    0.007    0.000 {built-in method builtins.sorted}
#       168    0.007    0.000    0.391    0.002 axis.py:2486(get_tick_space)
#       168    0.007    0.000    0.353    0.002 axis.py:2179(get_tick_space)
#      5376    0.007    0.000    0.018    0.000 integer.py:80(construct_from_string)
#       108    0.007    0.000    0.007    0.000 {method 'acquire' of '_thread.lock' objects}
#      1189    0.007    0.000    0.358    0.000 frame.py:797(iterrows)
#      6749    0.006    0.000    0.006    0.000 {method 'update' of 'dict' objects}
#      2460    0.006    0.000    0.060    0.000 fromnumeric.py:2083(any)
#      5836    0.006    0.000    0.006    0.000 {built-in method __new__ of type object at 0x00007FFF42D56BA0}
#      2220    0.006    0.000    0.011    0.000 lines.py:1112(_split_drawstyle_linestyle)
#      2676    0.006    0.000    0.009    0.000 base.py:3918(__contains__)
#       189    0.006    0.000    0.108    0.001 series.py:3600(_reduce)
#      2295    0.006    0.000    0.026    0.000 common.py:868(is_integer_dtype)
#     16016    0.006    0.000    0.006    0.000 {method 'startswith' of 'str' objects}
#      7720    0.006    0.000    0.006    0.000 cycler.py:371(<genexpr>)
#      2959    0.006    0.000    0.039    0.000 fromnumeric.py:54(_wrapfunc)
#      3832    0.006    0.000    0.125    0.000 patch.py:21(interiors)
#       220    0.006    0.000    0.159    0.001 patches.py:563(draw)
#         2    0.006    0.003    3.415    1.708 plotting.py:103(<listcomp>)
#      2264    0.006    0.000    0.037    0.000 fromnumeric.py:3373(round_)
#       475    0.006    0.000    0.037    0.000 base.py:1117(__iter__)
#       210    0.006    0.000    0.018    0.000 missing.py:183(_isna_ndarraylike)
#      1936    0.006    0.000    0.012    0.000 patches.py:431(set_capstyle)
#      1690    0.006    0.000    0.029    0.000 transforms.py:1748(frozen)
#      8340    0.006    0.000    0.007    0.000 linear_solver_natural_api.py:187(AddSelfToCoeffMapOrStack)
#      3832    0.006    0.000    0.171    0.000 patch.py:16(exterior)
#      5556    0.006    0.000    0.019    0.000 series.py:406(dtype)
#      2616    0.006    0.000    0.015    0.000 managers.py:1556(get_values)
#      4532    0.006    0.000    0.019    0.000 series.py:476(_values)
#       891    0.006    0.000    0.021    0.000 axis.py:617(update_position)
#     26699    0.005    0.000    0.005    0.000 {method 'pop' of 'list' objects}
#      3291    0.005    0.000    0.010    0.000 lines.py:1282(set_xdata)
#      8315    0.005    0.000    0.005    0.000 {built-in method builtins.iter}
#      1188    0.005    0.000    0.107    0.000 markers.py:223(__init__)
#      3060    0.005    0.000    0.051    0.000 contextlib.py:107(__enter__)
#      1659    0.005    0.000    0.024    0.000 blocks.py:2626(__init__)
#      3564    0.005    0.000    0.009    0.000 font_manager.py:1233(<genexpr>)
#      4226    0.005    0.000    0.011    0.000 <string>:1(__new__)
#      2233    0.005    0.000    0.014    0.000 base.py:2849(_convert_scalar_indexer)
#      5394    0.005    0.000    0.011    0.000 figure.py:49(_stale_figure_callback)
#      1110    0.005    0.000    0.010    0.000 lines.py:1398(set_dash_capstyle)
#       262    0.005    0.000    0.007    0.000 numerictypes.py:578(_can_coerce_all)
#      2744    0.005    0.000    0.007    0.000 series.py:399(name)
#      6360    0.005    0.000    0.033    0.000 linear_solver_natural_api.py:119(__rmul__)
#      1018    0.005    0.000    0.012    0.000 transforms.py:2299(__init__)
#       805    0.005    0.000    0.007    0.000 font_manager.py:812(set_size)
#      2279    0.005    0.000    0.047    0.000 patches.py:209(get_transform)
#      5671    0.005    0.000    0.038    0.000 linear_solver_natural_api.py:208(__init__)
#     10931    0.005    0.000    0.005    0.000 {method 'pop' of 'dict' objects}
#         1    0.005    0.005  120.494  120.494 <ipython-input-4-f2b12116fc1d>:1(assignFacilitiesAndCluster)
#       212    0.005    0.000    0.023    0.000 generic.py:3056(_get_item_cache)
#     12879    0.005    0.000    0.005    0.000 {method 'lower' of 'str' objects}
#      1284    0.005    0.000    0.013    0.000 path.py:159(_fast_from_codes_and_verts)
#       310    0.005    0.000    0.199    0.001 frame.py:2893(__getitem__)
#      2866    0.005    0.000    0.030    0.000 common.py:536(is_interval_dtype)
#      1768    0.005    0.000    0.017    0.000 transforms.py:126(invalidate)
#      2315    0.005    0.000    0.014    0.000 artist.py:673(set_figure)
#      2224    0.005    0.000    0.005    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       567    0.005    0.000    0.006    0.000 text.py:41(get_rotation)
#       727    0.005    0.000    0.019    0.000 axis.py:500(update_position)
#      3875    0.005    0.000    0.046    0.000 common.py:262(is_categorical)
#       767    0.005    0.000    0.005    0.000 {built-in method numpy.arange}
#      1025    0.005    0.000    0.093    0.000 fromnumeric.py:2171(all)
#        97    0.005    0.000    0.005    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#        80    0.005    0.000    2.011    0.025 axis.py:1195(draw)
#      3354    0.005    0.000    0.008    0.000 {method 'view' of 'numpy.ndarray' objects}
#       336    0.005    0.000    0.006    0.000 ticker.py:1828(scale_range)
#       168    0.005    0.000    0.198    0.001 axis.py:1149(<listcomp>)
#      2432    0.005    0.000    0.031    0.000 fromnumeric.py:2512(amin)
#      2474    0.004    0.000    0.032    0.000 fromnumeric.py:2397(amax)
#       744    0.004    0.000    0.011    0.000 transforms.py:2654(__init__)
#       694    0.004    0.000    0.008    0.000 dtypes.py:786(construct_from_string)
#      1161    0.004    0.000    0.015    0.000 artist.py:946(_update_property)
#       240    0.004    0.000    0.018    0.000 coords.py:69(__getitem__)
#       294    0.004    0.000    0.010    0.000 algorithms.py:1417(_get_take_nd_function)
#      1179    0.004    0.000    0.005    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      3523    0.004    0.000    0.004    0.000 {built-in method builtins.max}
#       140    0.004    0.000    0.005    0.000 __init__.py:1673(normalize_kwargs)
#       803    0.004    0.000    0.007    0.000 font_manager.py:757(set_style)
#       384    0.004    0.000    0.039    0.000 ops.py:1615(na_op)
#       132    0.004    0.000    0.006    0.000 collections.py:839(set_sizes)
#      1110    0.004    0.000    0.044    0.000 lines.py:1241(set_markerfacecolor)
#       376    0.004    0.000    0.051    0.000 base.py:106(<listcomp>)
#      6714    0.004    0.000    0.004    0.000 transforms.py:946(get_points)
#      1188    0.004    0.000    0.007    0.000 markers.py:267(set_fillstyle)
#      4293    0.004    0.000    0.013    0.000 artist.py:170(convert_xunits)
#       168    0.004    0.000    0.417    0.002 axis.py:1326(get_minorticklocs)
#       764    0.004    0.000    0.019    0.000 transforms.py:1506(transform_path_non_affine)
#      3783    0.004    0.000    0.008    0.000 lines.py:1294(set_ydata)
#      1741    0.004    0.000    0.051    0.000 common.py:1643(is_extension_type)
#       803    0.004    0.000    0.005    0.000 font_manager.py:794(set_stretch)
#       823    0.004    0.000    0.032    0.000 text.py:170(update)
#      1928    0.004    0.000    0.007    0.000 patches.py:450(set_joinstyle)
#       336    0.004    0.000    0.008    0.000 _methods.py:151(_ptp)
#        44    0.004    0.000    0.047    0.001 _base.py:2503(_update_title_position)
#       594    0.004    0.000    0.043    0.000 backend_agg.py:241(_get_agg_font)
#       971    0.004    0.000    0.006    0.000 __init__.py:1373(is_math_text)
#       189    0.004    0.000    0.052    0.000 nanops.py:203(_get_values)
#      3159    0.004    0.000    0.024    0.000 transforms.py:1236(__add__)
#      6585    0.004    0.000    0.004    0.000 transforms.py:1857(get_matrix)
#         6    0.004    0.001    0.836    0.139 <ipython-input-6-4ad955854af3>:1(convertTourToPathDF)
#        40    0.004    0.000    0.049    0.001 _base.py:2425(handle_single_axis)
#      2264    0.004    0.000    0.031    0.000 fromnumeric.py:2940(around)
#      2736    0.004    0.000    0.005    0.000 function_base.py:258(iterable)
#      1110    0.004    0.000    0.008    0.000 lines.py:1095(set_linewidth)
#       336    0.004    0.000    0.831    0.002 ticker.py:2080(tick_values)
#      7350    0.004    0.000    0.004    0.000 {built-in method ortools.linear_solver._pywraplp.Constraint_SetCoefficient}
#      2280    0.004    0.000    0.004    0.000 __init__.py:2017(<listcomp>)
#      1532    0.004    0.000    0.009    0.000 {built-in method builtins.all}
#      1490    0.004    0.000    0.005    0.000 artist.py:828(_set_gc_clip)
#      1751    0.003    0.000    0.005    0.000 range.py:510(__len__)
#      2154    0.003    0.000    0.022    0.000 base.py:3975(_can_hold_identifiers_and_holds_name)
#      1938    0.003    0.000    0.051    0.000 patches.py:292(set_edgecolor)
#      1384    0.003    0.000    0.013    0.000 axis.py:1881(getter)
#      6827    0.003    0.000    0.003    0.000 blocks.py:308(dtype)
#      8488    0.003    0.000    0.003    0.000 artist.py:858(get_agg_filter)
#      1142    0.003    0.000    0.019    0.000 transforms.py:362(ymax)
#      1282    0.003    0.000    0.003    0.000 dtypes.py:452(construct_from_string)
#       187    0.003    0.000    0.055    0.000 axis.py:543(_get_text1)
#        20    0.003    0.000    0.049    0.002 plotting.py:8(_flatten_multi_geoms)
#       293    0.003    0.000    0.012    0.000 cast.py:255(maybe_promote)
#      4369    0.003    0.000    0.009    0.000 artist.py:182(convert_yunits)
#        98    0.003    0.000    0.005    0.000 indexing.py:2575(maybe_convert_indices)
#       336    0.003    0.000    0.110    0.000 ticker.py:677(set_locs)
#       959    0.003    0.000    0.007    0.000 dtypes.py:672(construct_from_string)
#       168    0.003    0.000    0.004    0.000 spines.py:254(_adjust_location)
#      1918    0.003    0.000    0.009    0.000 artist.py:360(set_transform)
#      4639    0.003    0.000    0.003    0.000 artist.py:199(axes)
#      1796    0.003    0.000    0.011    0.000 transforms.py:2375(transform_non_affine)
#       336    0.003    0.000    0.023    0.000 ticker.py:259(<listcomp>)
#      1062    0.003    0.000    0.037    0.000 base.py:434(distance)
#      1110    0.003    0.000    0.007    0.000 lines.py:1352(set_dash_joinstyle)
#      1110    0.003    0.000    0.010    0.000 lines.py:648(set_data)
#       710    0.003    0.000    0.027    0.000 missing.py:105(_isna_new)
#      1938    0.003    0.000    0.234    0.000 patches.py:310(set_facecolor)
#       336    0.003    0.000    0.838    0.002 ticker.py:2076(__call__)
#       182    0.003    0.000    0.080    0.000 transforms.py:697(union)
#      1110    0.003    0.000    0.006    0.000 lines.py:1061(set_drawstyle)
#        67    0.003    0.000    0.021    0.000 managers.py:772(_interleave)
#       187    0.003    0.000    0.123    0.001 axis.py:602(_get_gridline)
#      4538    0.003    0.000    0.013    0.000 numeric.py:541(asanyarray)
#      2372    0.003    0.000    0.008    0.000 transforms.py:2181(get_affine)
#      1050    0.003    0.000    0.003    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_Constraint}
#   215/214    0.003    0.000    0.007    0.000 transforms.py:413(bounds)
#        84    0.003    0.000    0.300    0.004 geoseries.py:67(y)
#       959    0.003    0.000    0.004    0.000 transforms.py:386(intervaly)
#       187    0.003    0.000    0.088    0.000 axis.py:573(_get_tick1line)
#       520    0.003    0.000    0.021    0.000 transforms.py:2710(_revalidate)
#      1560    0.003    0.000    0.008    0.000 lines.py:953(_get_markerfacecolor)
#  1687/935    0.003    0.000    0.007    0.000 _base.py:736(get_yaxis_transform)
#      1118    0.003    0.000    0.006    0.000 geodataframe.py:60(__setattr__)
#      1332    0.003    0.000    0.008    0.000 ticker.py:567(fix_minus)
#      1850    0.003    0.000    0.012    0.000 axis.py:325(_set_artist_props)
#      2888    0.003    0.000    0.004    0.000 common.py:1809(_get_dtype)
#      4560    0.003    0.000    0.027    0.000 linear_solver_natural_api.py:223(Sum)
#       183    0.003    0.000    0.095    0.001 axis.py:458(_get_tick1line)
#       183    0.003    0.000    0.084    0.000 axis.py:484(_get_gridline)
#      2037    0.003    0.000    0.015    0.000 arrays.py:7(extract_array)
#       252    0.003    0.000    0.007    0.000 cast.py:1193(construct_1d_object_array_from_listlike)
#      8506    0.003    0.000    0.003    0.000 artist.py:770(get_visible)
#        20    0.003    0.000    7.771    0.389 plotting.py:214(plot_series)
#      3149    0.003    0.000    0.003    0.000 transforms.py:1671(<lambda>)
#       187    0.003    0.000    0.089    0.000 axis.py:588(_get_tick2line)
#       959    0.003    0.000    0.004    0.000 transforms.py:377(intervalx)
#      2810    0.003    0.000    0.003    0.000 blocks.py:89(_check_ndim)
#      2162    0.003    0.000    0.004    0.000 __init__.py:1916(_str_lower_equal)
#      1100    0.003    0.000    0.016    0.000 transforms.py:352(ymin)
#       694    0.003    0.000    0.004    0.000 dtypes.py:929(construct_from_string)
#      2616    0.003    0.000    0.006    0.000 blocks.py:184(to_dense)
#      2661    0.003    0.000    0.005    0.000 base.py:5318(ensure_index)
#       138    0.003    0.000    0.006    0.000 transforms.py:1914(rotate)
#      3570    0.003    0.000    0.005    0.000 transforms.py:178(<lambda>)
#       310    0.003    0.000    0.206    0.001 geodataframe.py:465(__getitem__)
#         2    0.003    0.001    0.019    0.010 collections.py:1810(<listcomp>)
#      1110    0.003    0.000    0.020    0.000 lines.py:1255(set_markerfacecoloralt)
#      1110    0.003    0.000    0.006    0.000 lines.py:1412(set_solid_capstyle)
#       968    0.003    0.000    0.013    0.000 transforms.py:357(xmax)
#       183    0.003    0.000    0.046    0.000 axis.py:425(_get_text1)
#      8488    0.003    0.000    0.003    0.000 artist.py:838(get_rasterized)
#       968    0.003    0.000    0.016    0.000 transforms.py:347(xmin)
#       126    0.003    0.000    0.037    0.000 managers.py:97(__init__)
#       254    0.003    0.000    0.020    0.000 managers.py:318(apply)
#       826    0.003    0.000    0.010    0.000 common.py:1578(is_bool_dtype)
#      1490    0.003    0.000    0.050    0.000 backend_bases.py:654(new_gc)
#      1929    0.003    0.000    0.005    0.000 patches.py:264(set_antialiased)
#      1548    0.003    0.000    0.003    0.000 {built-in method numpy.seterrobj}
#   497/496    0.003    0.000    0.008    0.000 transforms.py:1025(get_points)
#      1722    0.003    0.000    0.010    0.000 cast.py:1218(construct_1d_ndarray_preserving_na)
#         6    0.003    0.000    0.003    0.000 {built-in method ortools.constraint_solver._pywrapcp.new_RoutingModel}
#      2154    0.003    0.000    0.013    0.000 base.py:1681(is_object)
#      1110    0.003    0.000    0.005    0.000 lines.py:1367(set_solid_joinstyle)
#  1651/915    0.003    0.000    0.010    0.000 _base.py:660(get_xaxis_transform)
#      2616    0.002    0.000    0.018    0.000 series.py:490(get_values)
#       187    0.002    0.000    0.015    0.000 _base.py:760(get_yaxis_text1_transform)
#       370    0.002    0.000    0.004    0.000 axis.py:198(_set_labelrotation)
#       567    0.002    0.000    0.007    0.000 text.py:1178(_preprocess_math)
#      1608    0.002    0.000    0.008    0.000 transforms.py:2133(<lambda>)
#       520    0.002    0.000    0.006    0.000 transforms.py:2694(__init__)
#        82    0.002    0.000    0.022    0.000 _base.py:1446(apply_aspect)
#        20    0.002    0.000    3.906    0.195 figure.py:1661(draw)
#       292    0.002    0.000    0.063    0.000 blocks.py:1217(take_nd)
#      1110    0.002    0.000    0.003    0.000 lines.py:1269(set_markersize)
#        86    0.002    0.000    0.007    0.000 numeric.py:2508(within_tol)
#      7350    0.002    0.000    0.006    0.000 pywraplp.py:458(SetCoefficient)
# 2228/2226    0.002    0.000    0.023    0.000 transforms.py:1696(transform)
#       767    0.002    0.000    0.004    0.000 base.py:894(_get_geom_item)
#      1110    0.002    0.000    0.008    0.000 lines.py:733(set_transform)
#      1947    0.002    0.000    0.006    0.000 artist.py:905(set_visible)
#        84    0.002    0.000    0.223    0.003 geoseries.py:58(x)
#      3096    0.002    0.000    0.002    0.000 {built-in method numpy.geterrobj}
#       770    0.002    0.000    0.005    0.000 text.py:1122(set_verticalalignment)
#       594    0.002    0.000    0.004    0.000 backend_agg.py:49(get_hinting_flag)
#       210    0.002    0.000    0.011    0.000 collections.py:212(_prepare_points)
#      2370    0.002    0.000    0.004    0.000 generic.py:426(_info_axis)
#       187    0.002    0.000    0.041    0.000 axis.py:558(_get_text2)
#      2435    0.002    0.000    0.002    0.000 series.py:382(_set_subtyp)
#       594    0.002    0.000    0.002    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#        98    0.002    0.000    0.129    0.001 managers.py:1329(take)
#      1928    0.002    0.000    0.004    0.000 patches.py:469(set_hatch)
#       386    0.002    0.000    0.005    0.000 __init__.py:968(get_siblings)
#        48    0.002    0.000    0.011    0.000 managers.py:868(fast_xs)
#      1284    0.002    0.000    0.007    0.000 transforms.py:2149(transform_non_affine)
#       111    0.002    0.000    0.023    0.000 patches.py:728(_update_patch_transform)
#      1110    0.002    0.000    0.003    0.000 lines.py:635(axes)
#      1019    0.002    0.000    0.004    0.000 shape_base.py:220(_warn_for_nonsequence)
#       168    0.002    0.000    0.002    0.000 {built-in method pandas._libs.index.get_value_at}
#       520    0.002    0.000    0.009    0.000 lines.py:709(_transform_path)
#       774    0.002    0.000    0.019    0.000 numeric.py:3058(__enter__)
#       615    0.002    0.000    0.006    0.000 managers.py:139(shape)
#      2060    0.002    0.000    0.017    0.000 artist.py:974(<listcomp>)
#       188    0.002    0.000    0.110    0.001 generic.py:11018(logical_func)
#       216    0.002    0.000    0.042    0.000 indexing.py:2205(_getitem_axis)
#      2000    0.002    0.000    0.009    0.000 transforms.py:2047(transform)
#       183    0.002    0.000    0.069    0.000 axis.py:469(_get_tick2line)
#       520    0.002    0.000    0.004    0.000 lines.py:928(get_markeredgecolor)
#        97    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#       239    0.002    0.000    0.002    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.002    0.001    3.493    1.746 plotting.py:48(plot_polygon_collection)
#      4532    0.002    0.000    0.002    0.000 blocks.py:165(internal_values)
#       434    0.002    0.000    0.010    0.000 common.py:93(is_bool_indexer)
#       336    0.002    0.000    0.002    0.000 {method 'clip' of 'numpy.ndarray' objects}
#      2629    0.002    0.000    0.003    0.000 __init__.py:1906(_str_equal)
#      4607    0.002    0.000    0.002    0.000 blocks.py:195(mgr_locs)
#       410    0.002    0.000    0.008    0.000 _dtype.py:46(__str__)
#        97    0.002    0.000    0.145    0.001 generic.py:3323(_take)
#       761    0.002    0.000    0.004    0.000 text.py:918(set_color)
#       774    0.002    0.000    0.010    0.000 numeric.py:3063(__exit__)
#      2168    0.002    0.000    0.006    0.000 patches.py:223(get_patch_transform)
#      3600    0.002    0.000    0.024    0.000 linear_solver_natural_api.py:104(__add__)
#       774    0.002    0.000    0.003    0.000 numeric.py:3054(__init__)
#        40    0.002    0.000    3.875    0.097 _base.py:2573(draw)
#       200    0.002    0.000    0.013    0.000 markers.py:748(_set_tickleft)
#       667    0.002    0.000    0.007    0.000 common.py:1198(is_datetime_or_timedelta_dtype)
#      1942    0.002    0.000    0.002    0.000 {method 'count' of 'str' objects}
#      1632    0.002    0.000    0.006    0.000 scale.py:101(get_transform)
#       462    0.002    0.000    0.002    0.000 getlimits.py:365(__new__)
#      1110    0.002    0.000    0.004    0.000 lines.py:1227(set_markeredgewidth)
#   252/126    0.002    0.000    0.025    0.000 transforms.py:2320(frozen)
#       120    0.002    0.000    0.017    0.000 generic.py:5948(fillna)
#       520    0.002    0.000    0.002    0.000 markers.py:258(__bool__)
#      1886    0.002    0.000    0.007    0.000 text.py:1089(set_x)
#       594    0.002    0.000    0.003    0.000 font_manager.py:1338(get_font)
#       210    0.002    0.000    0.003    0.000 artist.py:163(have_units)
#       336    0.002    0.000    0.010    0.000 fromnumeric.py:2324(ptp)
#       220    0.002    0.000    0.090    0.000 backend_agg.py:119(draw_path)
#       808    0.002    0.000    0.048    0.000 generic.py:178(_validate_dtype)
#       349    0.002    0.000    0.007    0.000 fromnumeric.py:41(_wrapit)
#       803    0.002    0.000    0.004    0.000 font_manager.py:767(set_variant)
#       890    0.002    0.000    0.003    0.000 stride_tricks.py:257(<listcomp>)
#      2040    0.002    0.000    0.006    0.000 backend_bases.py:918(set_foreground)
#      8288    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#      2761    0.002    0.000    0.003    0.000 common.py:316(apply_if_callable)
#      2214    0.002    0.000    0.006    0.000 text.py:1100(set_y)
#       183    0.002    0.000    0.043    0.000 axis.py:442(_get_text2)
#     60/20    0.002    0.000    3.876    0.194 image.py:117(_draw_list_compositing_images)
#      4342    0.002    0.000    0.002    0.000 font_manager.py:724(get_size_in_points)
#      1584    0.002    0.000    0.003    0.000 <ipython-input-7-e2210c2c3aae>:57(distance_callback)
#      3370    0.002    0.000    0.002    0.000 text.py:1136(set_text)
#      1348    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#        96    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#       183    0.002    0.000    0.010    0.000 _base.py:684(get_xaxis_text1_transform)
#      1954    0.002    0.000    0.002    0.000 inference.py:438(is_hashable)
#       230    0.002    0.000    0.011    0.000 base.py:786(array)
#      1248    0.002    0.000    0.010    0.000 axis.py:301(set_label1)
#      1587    0.002    0.000    0.013    0.000 {method 'max' of 'numpy.ndarray' objects}
#       594    0.002    0.000    0.002    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#    402/60    0.002    0.000    0.003    0.000 arrayprint.py:716(recurser)
#      1490    0.002    0.000    0.002    0.000 backend_bases.py:886(set_clip_path)
#      1490    0.002    0.000    0.002    0.000 backend_bases.py:976(get_hatch_path)
#      2532    0.002    0.000    0.002    0.000 common.py:127(<lambda>)
#       138    0.002    0.000    0.007    0.000 transforms.py:1930(rotate_deg)
#        61    0.002    0.000    0.002    0.000 __init__.py:143(__init__)
#       336    0.002    0.000    0.085    0.000 ticker.py:256(format_ticks)
#      1110    0.002    0.000    0.003    0.000 lines.py:1038(set_antialiased)
#       390    0.002    0.000    0.002    0.000 __init__.py:919(clean)
#       233    0.002    0.000    0.004    0.000 base.py:504(_simple_new)
# 1622/1619    0.002    0.000    0.004    0.000 transforms.py:2573(get_matrix)
#      1616    0.002    0.000    0.003    0.000 transforms.py:1687(__array__)
#      3695    0.002    0.000    0.002    0.000 text.py:841(get_text)
#       187    0.002    0.000    0.436    0.002 axis.py:2217(_get_tick)
#       230    0.002    0.000    0.004    0.000 numpy_.py:35(__init__)
#       672    0.002    0.000    0.002    0.000 ticker.py:1857(closeto)
#      1168    0.002    0.000    0.002    0.000 {built-in method math.log10}
#      2670    0.002    0.000    0.002    0.000 stride_tricks.py:261(<genexpr>)
#       183    0.002    0.000    0.370    0.002 axis.py:1928(_get_tick)
#       763    0.002    0.000    0.003    0.000 text.py:934(set_horizontalalignment)
#       414    0.002    0.000    0.002    0.000 generic.py:349(_get_axis_number)
#       320    0.002    0.000    0.002    0.000 ticker.py:712(<genexpr>)
#       475    0.002    0.000    0.019    0.000 common.py:702(is_datetimelike)
#       194    0.002    0.000    0.017    0.000 base.py:3940(__getitem__)
#      4619    0.002    0.000    0.002    0.000 {built-in method builtins.setattr}
#       960    0.002    0.000    0.002    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_IntVar}
#      1128    0.002    0.000    0.002    0.000 {pandas._libs.lib.infer_datetimelike_array}
#       778    0.002    0.000    0.004    0.000 artist.py:1005(set_zorder)
#      3176    0.002    0.000    0.002    0.000 {built-in method builtins.abs}
#      1020    0.002    0.000    0.012    0.000 linear_solver_natural_api.py:143(__le__)
#        94    0.002    0.000    0.007    0.000 path.py:497(get_extents)
#        20    0.002    0.000    0.002    0.000 {pandas._libs.lib.map_infer_mask}
#       187    0.002    0.000    0.009    0.000 _base.py:786(get_yaxis_text2_transform)
#        42    0.002    0.000    0.370    0.009 axis.py:2298(_update_label_position)
#       760    0.001    0.000    0.002    0.000 backend_bases.py:851(set_alpha)
#       116    0.001    0.000    0.006    0.000 managers.py:963(iget)
#      3410    0.001    0.000    0.001    0.000 font_manager.py:676(get_family)
#       731    0.001    0.000    0.009    0.000 {method 'any' of 'numpy.ndarray' objects}
#       160    0.001    0.000    0.082    0.001 spines.py:362(draw)
#        42    0.001    0.000    0.018    0.000 {shapely.speedups._speedups.geos_linestring_from_py}
#        16    0.001    0.000    0.003    0.000 frame.py:3565(_sanitize_column)
#      1248    0.001    0.000    0.009    0.000 axis.py:314(set_label2)
#       115    0.001    0.000    0.016    0.000 cast.py:1072(find_common_type)
#      2345    0.001    0.000    0.001    0.000 numerictypes.py:587(<listcomp>)
#       761    0.001    0.000    0.003    0.000 text.py:1212(set_usetex)
#       265    0.001    0.000    0.005    0.000 transforms.py:2415(__init__)
#       694    0.001    0.000    0.011    0.000 blocks.py:225(make_block_same_class)
#       116    0.001    0.000    0.002    0.000 artist.py:1043(update_from)
#      2284    0.001    0.000    0.001    0.000 figure.py:462(_get_dpi)
#      1901    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#       740    0.001    0.000    0.001    0.000 backend_bases.py:868(set_antialiased)
#       118    0.001    0.000    0.005    0.000 colors.py:254(to_rgba_array)
#       189    0.001    0.000    0.001    0.000 {built-in method numpy.putmask}
#       496    0.001    0.000    0.003    0.000 common.py:1545(is_float_dtype)
#       183    0.001    0.000    0.008    0.000 _base.py:710(get_xaxis_text2_transform)
#       476    0.001    0.000    0.037    0.000 {method 'all' of 'numpy.ndarray' objects}
#       803    0.001    0.000    0.003    0.000 font_manager.py:744(set_family)
#      2460    0.001    0.000    0.014    0.000 base.py:350(type)
#       370    0.001    0.000    0.067    0.000 lines.py:1021(get_path)
#       183    0.001    0.000    0.004    0.000 axis.py:411(apply_tickdir)
#        42    0.001    0.000    0.330    0.008 axis.py:2004(_update_label_position)
# 1496/1480    0.001    0.000    0.002    0.000 spines.py:208(_ensure_position_is_set)
#       173    0.001    0.000    0.033    0.000 base.py:584(_shallow_copy_with_infer)
#        40    0.001    0.000    0.003    0.000 transforms.py:534(anchored)
#      1752    0.001    0.000    0.002    0.000 transforms.py:2668(get_matrix)
#      1464    0.001    0.000    0.006    0.000 axis.py:792(get_transform)
#      1110    0.001    0.000    0.003    0.000 lines.py:1212(set_markeredgecolor)
#       181    0.001    0.000    0.007    0.000 transforms.py:778(from_bounds)
#       453    0.001    0.000    0.003    0.000 ops.py:43(get_op_result_name)
#       336    0.001    0.000    0.002    0.000 ticker.py:1874(ge)
#       102    0.001    0.000    0.001    0.000 _base.py:4248(get_children)
#       524    0.001    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#       575    0.001    0.000    0.002    0.000 generic.py:363(_get_axis_name)
#       216    0.001    0.000    0.044    0.000 indexing.py:1485(__getitem__)
#       187    0.001    0.000    0.004    0.000 axis.py:528(apply_tickdir)
#       111    0.001    0.000    0.004    0.000 managers.py:306(_verify_integrity)
#       404    0.001    0.000    0.004    0.000 units.py:122(is_numlike)
#       200    0.001    0.000    0.018    0.000 markers.py:754(_set_tickright)
#      1040    0.001    0.000    0.001    0.000 backend_agg.py:254(points_to_pixels)
#       157    0.001    0.000    0.005    0.000 numeric.py:34(__new__)
#       159    0.001    0.000    0.002    0.000 core.py:2905(_update_from)
#       119    0.001    0.000    0.020    0.000 geodataframe.py:44(__init__)
#       235    0.001    0.000    0.006    0.000 transforms.py:1962(translate)
#       477    0.001    0.000    0.001    0.000 _internal.py:886(npy_ctypes_check)
#       672    0.001    0.000    0.002    0.000 sparse.py:196(construct_from_string)
#       740    0.001    0.000    0.001    0.000 backend_bases.py:945(set_linewidth)
# ...
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.mul}
#         2    0.000    0.000    0.000    0.000 figure.py:108(bubble)
#         2    0.000    0.000    0.000    0.000 mathtext.py:3333(__init__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:519(__eq__)
#         6    0.000    0.000    0.000    0.000 numeric.py:2035(isscalar)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:150(__init__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3254(new_figure_manager_given_figure)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 __init__.py:23(find_module)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetOffset}
#         2    0.000    0.000    0.000    0.000 generic.py:1576(<genexpr>)
#         1    0.000    0.000    0.000    0.000 image.py:827(__init__)
#         6    0.000    0.000    0.000    0.000 index_tricks.py:729(__getitem__)
#         1    0.000    0.000    0.000    0.000 colors.py:997(autoscale_None)
#         2    0.000    0.000    0.000    0.000 pyplot.py:908(gca)
#        12    0.000    0.000    0.000    0.000 legend_handler.py:345(get_numpoints)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:173(Objective)
#         2    0.000    0.000    0.000    0.000 transforms.py:770(null)
#         2    0.000    0.000    0.000    0.000 gridspec.py:530(__hash__)
#        36    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         9    0.000    0.000    0.000    0.000 blocks.py:3146(<listcomp>)
#         5    0.000    0.000    0.000    0.000 __init__.py:76(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:543(set_constrained_layout_pads)
#        12    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        40    0.000    0.000    0.000    0.000 inspect.py:2517(name)
#         1    0.000    0.000    0.000    0.000 managers.py:2015(_preprocess_slice_or_indexer)
#         1    0.000    0.000    0.000    0.000 legend.py:1250(_parse_legend_args)
#         1    0.000    0.000    0.000    0.000 shape_base.py:1154(tile)
#         1    0.000    0.000    0.000    0.000 core.py:5686(max)
#         1    0.000    0.000    0.000    0.000 figure.py:1882(_set_artist_props)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#       3/1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#         1    0.000    0.000    0.000    0.000 nanops.py:403(nansum)
#         2    0.000    0.000    0.000    0.000 transforms.py:2616(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:1888(gca)
#         2    0.000    0.000    0.000    0.000 __init__.py:48(get_projection_class)
#         1    0.000    0.000    0.000    0.000 legend.py:978(set_title)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:237(set_time_limit)
#         2    0.000    0.000    0.000    0.000 transforms.py:886(x0)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_Objective}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         1    0.000    0.000    0.000    0.000 generic.py:3461(xs)
#         1    0.000    0.000    0.000    0.000 range.py:184(_get_data_as_items)
#         2    0.000    0.000    0.000    0.000 gridspec.py:311(<listcomp>)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#         2    0.000    0.000    0.000    0.000 patches.py:2214(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:802(_assert_take_fillable)
#         2    0.000    0.000    0.000    0.000 transforms.py:307(x1)
#         2    0.000    0.000    0.000    0.000 weakref.py:51(_cb)
#         1    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#         1    0.000    0.000    0.000    0.000 textpath.py:25(__init__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:427(__init__)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:21(_get_right)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:25(_get_bottom)
#         1    0.000    0.000    0.000    0.000 figure.py:70(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:168(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#         1    0.000    0.000    0.001    0.001 base.py:4447(get_indexer_for)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:29(_get_top)
#         8    0.000    0.000    0.000    0.000 axis.py:1462(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:2965(_convert_listlike_indexer)
#         2    0.000    0.000    0.000    0.000 text.py:1027(set_fontsize)
#         1    0.000    0.000    0.000    0.000 nanops.py:1052(_maybe_null_out)
#         3    0.000    0.000    0.000    0.000 generic.py:3205(_check_setitem_copy)
#         4    0.000    0.000    0.000    0.000 __init__.py:715(clear)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#         2    0.000    0.000    0.000    0.000 figure.py:100(_entry_from_axes)
#         2    0.000    0.000    0.000    0.000 figure.py:160(__contains__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1221(getLogger)
#         2    0.000    0.000    0.000    0.000 gridspec.py:310(locally_modified_subplot_params)
#         6    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         1    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#         1    0.000    0.000    0.000    0.000 patches.py:337(set_alpha)
#         4    0.000    0.000    0.000    0.000 nanops.py:71(<genexpr>)
#         1    0.000    0.000    0.000    0.000 cm.py:386(autoscale_None)
#         1    0.000    0.000    0.000    0.000 legend.py:598(_set_artist_props)
#        12    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 core.py:293(_scalar_fill_value)
#         2    0.000    0.000    0.000    0.000 missing.py:530(clean_reindex_fill_method)
#         2    0.000    0.000    0.000    0.000 transforms.py:891(y0)
#         1    0.000    0.000    0.000    0.000 _validators.py:114(_check_for_invalid_keys)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:188(<genexpr>)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:438(__getitem__)
#         2    0.000    0.000    0.000    0.000 core.py:291(_extremum_fill_value)
#         2    0.000    0.000    0.000    0.000 six.py:180(find_module)
#         1    0.000    0.000    0.000    0.000 warnings.py:453(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:3010(bind)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:238(obj2sctype)
#         2    0.000    0.000    0.000    0.000 frame.py:474(axes)
#         2    0.000    0.000    0.000    0.000 figure.py:1075(fixitems)
#         2    0.000    0.000    0.000    0.000 _base.py:898(set_axes_locator)
#         1    0.000    0.000    0.000    0.000 __init__.py:2065(add)
#         2    0.000    0.000    0.000    0.000 gridspec.py:509(get_topmost_subplotspec)
#         1    0.000    0.000    0.000    0.000 image.py:736(set_interpolation)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2500(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 __init__.py:1930(getLogger)
#         2    0.000    0.000    0.000    0.000 text.py:1044(set_fontweight)
#         1    0.000    0.000    0.000    0.000 cm.py:413(changed)
#         2    0.000    0.000    0.000    0.000 gridspec.py:144(_normalize)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#         3    0.000    0.000    0.000    0.000 base.py:4698(_validate_indexer)
#         2    0.000    0.000    0.000    0.000 transforms.py:317(y1)
#         2    0.000    0.000    0.000    0.000 transforms.py:896(x1)
#         2    0.000    0.000    0.000    0.000 transforms.py:901(y1)
#         6    0.000    0.000    0.000    0.000 collections.py:827(get_sizes)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.000    0.000    0.000    0.000 tight_layout.py:156(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _base.py:1783(_sci)
#         2    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:337(Clear)
#         1    0.000    0.000    0.000    0.000 _validators.py:130(validate_kwargs)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 text.py:1199(set_fontproperties)
#         1    0.000    0.000    0.000    0.000 pyplot.py:3053(sci)
#         1    0.000    0.000    0.000    0.000 legend.py:609(_set_loc)
#         2    0.000    0.000    0.000    0.000 core.py:211(_recursive_fill_value)
#         1    0.000    0.000    0.000    0.000 image.py:910(get_extent)
#         2    0.000    0.000    0.000    0.000 figure.py:101(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 core.py:226(_get_dtype_of)
#         3    0.000    0.000    0.000    0.000 nanops.py:63(check)
#         1    0.000    0.000    0.000    0.000 base.py:2999(_convert_arr_indexer)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:355(SetMinimization)
#         1    0.000    0.000    0.000    0.000 types.py:164(__get__)
#         2    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_Clear}
#         1    0.000    0.000    0.000    0.000 image.py:228(get_size)
#         1    0.000    0.000    0.000    0.000 image.py:246(changed)
#         2    0.000    0.000    0.000    0.000 offsetbox.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#         1    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         1    0.000    0.000    0.000    0.000 image.py:786(set_filternorm)
#         1    0.000    0.000    0.000    0.000 _validators.py:32(_check_for_default_values)
#         2    0.000    0.000    0.000    0.000 base.py:2915(is_int)
#         2    0.000    0.000    0.000    0.000 gridspec.py:77(set_height_ratios)
#         1    0.000    0.000    0.000    0.000 image.py:803(set_filterrad)
#         1    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         1    0.000    0.000    0.000    0.000 warnings.py:493(__exit__)
#         2    0.000    0.000    0.000    0.000 inspect.py:2609(__init__)
#         1    0.000    0.000    0.000    0.000 core.py:306(minimum_fill_value)
#         1    0.000    0.000    0.000    0.000 nanops.py:276(_wrap_results)
#         1    0.000    0.000    0.000    0.000 managers.py:706(nblocks)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.can_cast}
#         2    0.000    0.000    0.000    0.000 gridspec.py:68(set_width_ratios)
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 core.py:1821(_check_mask_axis)
#         1    0.000    0.000    0.000    0.000 base.py:3035(_convert_list_indexer)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:168(<listcomp>)
#         1    0.000    0.000    0.000    0.000 image.py:235(set_alpha)
#         1    0.000    0.000    0.000    0.000 image.py:768(set_resample)
#         2    0.000    0.000    0.000    0.000 widgets.py:33(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         1    0.000    0.000    0.000    0.000 base.py:1237(_get_names)
#         1    0.000    0.000    0.000    0.000 base.py:5381(_ensure_has_len)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:164(<listcomp>)
#         1    0.000    0.000    0.000    0.000 enum.py:628(value)
#         1    0.000    0.000    0.000    0.000 __init__.py:227(itervalues)
#         1    0.000    0.000    0.000    0.000 _validators.py:10(_check_arg_length)
#         1    0.000    0.000    0.000    0.000 indexing.py:2676(is_nested_tuple)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         1    0.000    0.000    0.000    0.000 legend.py:727(get_legend_handler_map)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_set_time_limit}
#         1    0.000    0.000    0.000    0.000 weakref.py:73(__eq__)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:93(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:2835(parameters)
#         2    0.000    0.000    0.000    0.000 patches.py:1927(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:160(<listcomp>)
#         1    0.000    0.000    0.000    0.000 figure.py:2034(add_axobserver)
#         2    0.000    0.000    0.000    0.000 legend.py:706(get_default_handler_map)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:755(set_minimumdescent)
#         1    0.000    0.000    0.000    0.000 core.py:357(maximum_fill_value)
#         2    0.000    0.000    0.000    0.000 missing.py:71(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:94(<listcomp>)
#         1    0.000    0.000    0.000    0.000 re.py:232(compile)
#         1    0.000    0.000    0.000    0.000 generic.py:1693(<listcomp>)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:173(set_offset)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         2    0.000    0.000    0.000    0.000 patches.py:1928(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 legend.py:958(get_frame)
#         1    0.000    0.000    0.000    0.000 legend.py:1046(set_bbox_to_anchor)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 artist.py:580(set_snap)
#         2    0.000    0.000    0.000    0.000 legend.py:675(_approx_text_height)
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#         2    0.000    0.000    0.000    0.000 shape_base.py:1226(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:1567(<listcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:1627(<listcomp>)
#         1    0.000    0.000    0.000    0.000 indexing.py:937(_convert_for_reindex)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetMinimization}
#         1    0.000    0.000    0.000    0.000 artist.py:545(set_url)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
