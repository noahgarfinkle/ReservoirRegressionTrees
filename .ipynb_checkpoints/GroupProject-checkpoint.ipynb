# %% [markdown]
# # **GROUP PROJECT**

# %% [markdown]
# https://link.springer.com/referenceworkentry/10.1007%2F978-0-387-74759-0_345

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import geopandas as gpd
import random
import pyproj
from shapely.geometry import Point, LineString
import matplotlib.pyplot as plt
import seaborn as sns
import ortools as ort
import datetime as dt
# pysal submodule imports
from pysal.lib import cg, examples
from pysal.explore import spaghetti as spgh

import geopandas as gpd
from shapely.geometry import Point
from ortools.linear_solver import pywraplp
import copy, sys, warnings
from collections import OrderedDict

import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.colors import ListedColormap

try:
    from IPython.display import set_matplotlib_formats
    set_matplotlib_formats('retina')
except ImportError:
    pass

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
from ortools.sat.python import cp_model
# %load_ext line_profiler
# Out:
# C:\Users\Noah\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# # **1. FUNCTIONS**

# %%
def buildCityDF(nCities,gridX=100,gridY=100):
    xs = np.random.randint(0,gridX,nCities)
    ys = np.random.randint(0,gridY,nCities)
    pts = [Point(xs[i],ys[i]) for i in range(0,nCities)]
    demands = np.random.randint(0,101,nCities)
    facilityOneCosts = np.random.randint(0,101,nCities)
    facilityTwoCosts = np.random.randint(100,201,nCities)
    cityIndices = range(0,nCities)
    cities = gpd.GeoDataFrame({"x":xs,"y":ys,"demand":demands,"geometry":pts,"City Index":cityIndices,"Facility One Cost":facilityOneCosts,"Facility Two Cost":facilityTwoCosts})
    return cities

# %%
def buildDistanceMatrix_Euclidean(cities):
    distances = np.zeros((len(cities),len(cities)))
    for i,row in cities.iterrows():
        for j,row2 in cities.iterrows():
            distances[j,i] = row.geometry.distance(row2.geometry)
    return distances

# %%
def assignFacilitiesAndCluster(cities,M = 100,Rvz=[100000,200000],truckCapacityZ = [40000,80000],alpha=75.0,truckCapacity = 80000,fractionTruckRangeAllowed=0.8,nFacility=1,maxTimeLimit=5*60*1000):
    solver_instance = pywraplp.Solver.CBC_MIXED_INTEGER_PROGRAMMING # SAT_INTEGER_PROGRAMMING
#     solver_instance = cp_model.CpModel()
    distances = buildDistanceMatrix_Euclidean(cities)
    cij = distances
    n_customers = cij.shape[0]
    range_customers = range(n_customers)
    n_facilityCandidates = cij.shape[1]
    range_facilityCandidates = range(n_facilityCandidates)
    demands = np.array(cities["demand"])
    demands_sum = demands.sum()
    fiz = facilityCost = cities[["Facility One Cost","Facility Two Cost"]].as_matrix()
    zRange = len(Rvz)
    model = pywraplp.Solver("Capacitated Fixed Charge", solver_instance)
    model.set_time_limit(maxTimeLimit)
    model.SetNumThreads(4)

    xij = {(i,j): model.IntVar(0,1, 'x[%i,%i]' % (i,j)) for i in range_customers for j in range_facilityCandidates} # which facility is served by which 
    yjz = {(j,z): model.IntVar(0,1, 'y[%i,%i]' % (j,z)) for j in range_facilityCandidates for z in range(zRange)} # charging station location decision/ concentrator
    
    obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + alpha*2*cij[0,j]*yjz[j,z] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]
#     obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]

    # Service Constraint
    for i in range_customers:
        model.Add(model.Sum([xij[i,j] for j in range_facilityCandidates]) == nFacility)
    
    # Capacity Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([demands[i] * xij[i,j] for i in range_facilityCandidates]) <= model.Sum([truckCapacityZ[z]*yjz[j,z] for z in range(zRange)]))
    
    # Assignment Constraint
    for i in range_customers:
        for j in range_facilityCandidates:
            model.Add(xij[i,j] <= model.Sum([yjz[j,z] for z in range(zRange)]))
    
    # Maximum Concentratorrs Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for j in range_facilityCandidates for z in range(zRange)]) <= M)
        
    # Total tour length constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([xij[i,j]*cij[i,j] for i in range_facilityCandidates]) <= model.Sum([yjz[j,z]*Rvz[z]*fractionTruckRangeAllowed for z in range(zRange)]))
        
    # Z limitation constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for z in range(zRange)]) <= 1)

    model.Minimize(model.Sum(obj))
    status = model.Solve()

    if status == pywraplp.Solver.OPTIMAL:
        print('Optimal Solution Found')

    resultGDF = cities.copy(deep=True)
    for z in range(2):
        resultGDF[f"Status: Facility Type {z}"] = [yjz[j,z].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 0"] = [yjz[j,0].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 1"] = [yjz[j,1].solution_value() for j in range_facilityCandidates]
    return model,yjz,xij,resultGDF,status

# %%
def assignFacilitiesAndCluster(cities,M = 100,Rvz=[100000,200000],truckCapacityZ = [40000,80000],alpha=75.0,truckCapacity = 80000,fractionTruckRangeAllowed=0.8,nFacility=1,maxTimeLimit=5*60*1000,tourLengthViolationPenalty = 500):
    solver_instance = pywraplp.Solver.CBC_MIXED_INTEGER_PROGRAMMING
#     solver_instance = cp_model.CpModel()
    distances = buildDistanceMatrix_Euclidean(cities)
    cij = distances
    n_customers = cij.shape[0]
    range_customers = range(n_customers)
    n_facilityCandidates = cij.shape[1]
    range_facilityCandidates = range(n_facilityCandidates)
    demands = np.array(cities["demand"])
    demands_sum = demands.sum()
    fiz = facilityCost = cities[["Facility One Cost","Facility Two Cost"]].as_matrix()
    zRange = len(Rvz)
    model = pywraplp.Solver("Capacitated Fixed Charge", solver_instance)
    model.set_time_limit(maxTimeLimit)

#     model.parameters.max_time_in_seconds = 60.0 * 5

    xij = {(i,j): model.IntVar(0,1, 'x[%i,%i]' % (i,j)) for i in range_customers for j in range_facilityCandidates} # which facility is served by which 
    yjz = {(j,z): model.IntVar(0,1, 'y[%i,%i]' % (j,z)) for j in range_facilityCandidates for z in range(zRange)} # charging station location decision/ concentrator
    obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + alpha*2*cij[0,j]*yjz[j,z] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]
#     tourLengthObj = [tourLengthViolationPenalty * model.Sum([yjz[j,z]*Rvz[z]-xij[i,j]*cij[i,j] for i in range_customers for z in range(zRange)]) for j in range_customers]
#     tourLengthObj = [tourLengthViolationPenalty * yjz[j,0]*Rvz[0]+yjz[j,1]*Rvz[1]-xij[i,j]*cij[i,j] for i in range_customers for j in range_facilityCandidates]
#     obj = obj.extend(tourLengthObj)
    obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + alpha*2*cij[0,j]*yjz[j,z] + fiz[i,z] * yjz[j,z] + tourLengthViolationPenalty * (yjz[j,0]*Rvz[0]+yjz[j,1]*Rvz[1]-xij[i,j]*cij[i,j]) for i in range_customers for j in range_facilityCandidates for z in range(zRange)]

    # Service Constraint
    for i in range_customers:
        model.Add(model.Sum([xij[i,j] for j in range_facilityCandidates]) == nFacility)
    
    # Capacity Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([demands[i] * xij[i,j] for i in range_facilityCandidates]) <= model.Sum([truckCapacityZ[z]*yjz[j,z] for z in range(zRange)]))
    
    # Assignment Constraint
    for i in range_customers:
        for j in range_facilityCandidates:
            model.Add(xij[i,j] <= model.Sum([yjz[j,z] for z in range(zRange)]))
    
    # Maximum Concentratorrs Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for j in range_facilityCandidates for z in range(zRange)]) <= M)
        
    # Total tour length constraint
#     for j in range_facilityCandidates:
#         model.Add(model.Sum([xij[i,j]*cij[i,j] for i in range_facilityCandidates]) <= model.Sum([yjz[j,z]*Rvz[z]*fractionTruckRangeAllowed for z in range(zRange)]))
        
    # Z limitation constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for z in range(zRange)]) <= 1)

    model.Minimize(model.Sum(obj))
    status = model.Solve()

    if status == pywraplp.Solver.OPTIMAL:
        print('Optimal Solution Found')

    resultGDF = cities.copy(deep=True)
    for z in range(2):
        resultGDF[f"Status: Facility Type {z}"] = [yjz[j,z].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 0"] = [yjz[j,0].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 1"] = [yjz[j,1].solution_value() for j in range_facilityCandidates]
    return model,yjz,xij,resultGDF,status

# %%
def convertTourToPathDF(tour,resultGDF):
#     tour = list(resultGDF[resultGDF["assignment"]==tour]["City Index"])
    tour.append(tour[0]) # Return to end
    startNodes = []
    endNodes = []
    startCoords = []
    endCoords = []
    lines = [] # https://gis.stackexchange.com/questions/95670/how-to-create-a-shapely-linestring-from-two-points
    for i in range(0,len(tour)):
        currentCity = tour[i]
        if i < len(tour)-1:
            nextCity = tour[i+1]
        else:
            nextCity = tour[0]
        startNodes.append(currentCity)
        endNodes.append(nextCity)
        startPoint = resultGDF[resultGDF["City Index"]==currentCity].geometry
        startCoords.append(startPoint)
        endPoint = resultGDF[resultGDF["City Index"]==nextCity].geometry
        endCoords.append(endPoint)
        line = LineString([(startPoint.x,startPoint.y),(endPoint.x,endPoint.y)])
        lines.append(line)
    gdf = gpd.GeoDataFrame({"Start Node":startNodes,"End Node":endNodes,"geometry":lines})
    return gdf

# %%
# https://developers.google.com/optimization/routing/tsp
"""Simple travelling salesman problem between cities."""

def create_data_model(dfSubset):
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = buildDistanceMatrix_Euclidean(dfSubset.reset_index())
    data['num_vehicles'] = 1
    data['depot'] = 0
    return data


def print_solution(manager, routing, assignment,dfSubset):
    """Prints assignment on console."""
    optimizedRoute = []
#     print(f"Objective: ")
#     print('Objective: {} meters'.format(assignment.ObjectiveValue()))
    index = routing.Start(0)
    plan_output = 'Route for vehicle 0:\n'
    route_distance = 0
    orderedDFSubset = dfSubset.reset_index()
    while not routing.IsEnd(index):
        correctedCityIndex = orderedDFSubset.iloc[manager.IndexToNode(index)][0]
        optimizedRoute.append(correctedCityIndex)
#         print(f"******{correctedCityIndex}")
#         print(f"====>{orderedDFSubset.iloc[manager.IndexToNode(index)]}")
#         plan_output += ' {} ->'.format(manager.IndexToNode(index))
        plan_output += ' {} ->'.format(correctedCityIndex)

        previous_index = index
        index = assignment.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
#     plan_output += ' {}\n'.format(manager.IndexToNode(index))
    correctedCityIndex = orderedDFSubset.iloc[manager.IndexToNode(index)][0]
    plan_output += ' {}\n'.format(correctedCityIndex)
#     print(f"******{correctedCityIndex}")
    optimizedRoute.append(correctedCityIndex)
#     print(f"====>{orderedDFSubset.iloc[manager.IndexToNode(index)]}")
    plan_output += f'Route distance: {route_distance/1000.0} km\n'
    print(plan_output)
    return optimizedRoute,route_distance


def main(dfSubset):
    """Entry point of the program."""
    # Instantiate the data problem.
    data = create_data_model(dfSubset)

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    # Solve the problem.
    assignment = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if assignment:
        route,route_distance = print_solution(manager, routing, assignment,dfSubset)
    return route,route_distance

# %%
def solveAndPlot(illinoisCities,M=20,Rvz=[200000,400000],truckCapacityZ = [40000,80000],alpha=0.001,fractionTruckRangeAllowed=0.75,maxTimeLimit=5*60*1000):
    model,yjz,xij,resultGDF,status = assignFacilitiesAndCluster(illinoisCities,M=M,Rvz=Rvz,truckCapacityZ=truckCapacityZ,alpha=alpha,fractionTruckRangeAllowed=fractionTruckRangeAllowed,maxTimeLimit=maxTimeLimit)
    assignments = np.zeros((nCities,nCities))
    for k,v in xij.items():
        i = k[0]
        j = k[1]
        assignments[i,j] = v.solution_value()
    cluster = []
    for cityNodeID in range(nCities):
        for rootNodeID in range(nCities):
            lookup = assignments[cityNodeID,rootNodeID]
            if lookup == 1:
                cluster.append(rootNodeID)
    resultGDF["assignment"] = cluster
    uniqueClusters = list(set(cluster))


    fig = plt.figure(figsize=(20,20))
    ax1 = fig.add_subplot(1,2,1)
    ax2 = fig.add_subplot(1,2,2)
    fig.tight_layout()

    illinois.plot(ax=ax1,color="blue",alpha=0.1)
    illinois.sort_values("ALAND",ascending=False).reset_index()[0:nCities].plot(ax=ax1,color="red",alpha=0.2)
    # illinois.sort_values("ALAND",ascending=False).reset_index()[0:40].centroid.plot(ax=ax1,color="white",marker='*')

    colors = ['#'+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(len(uniqueClusters))]
    totalCost = 0.0
    subtourRoutingCosts = {}
    subtourConstructionCosts = {}
    subtourDistances = {}
    totalConstructionCost = np.sum(resultGDF["Facility One Cost"] * resultGDF["Status: Facility Type 0"] + resultGDF["Facility Two Cost"] * resultGDF["Status: Facility Type 1"])
    for i in range(0,len(uniqueClusters)):
        dfSubset = resultGDF[resultGDF["assignment"]==uniqueClusters[i]]
        tour,tourLength = main(dfSubset)
        if resultGDF.iloc[uniqueClusters[i]]["Status: Facility Type 0"]==1:
            facilityType = 0
            vehicleType = "Standard range"
        else:
            facilityType = 1
            vehicleType = "Extended range"
        subtourRoutingCosts[i] = alpha * tourLength
        subtourDistances[i] = tourLength
        # check if constraint violated
        label = f"{resultGDF.iloc[uniqueClusters[i]].Name}: {tourLength/1000:,.0f} KM, {vehicleType} vehicle"
        if tourLength > Rvz[facilityType]:
            label += " CONSTRAINT VIOLATED"
        # plot the nodes
        dfSubset.plot(ax=ax1,color=colors[i],markersize=dfSubset["demand"]/100,label=label)
        # plot the tour
        ls = "dashed"
        if facilityType == 1:
            ls = "dotted"
        convertTourToPathDF(tour,resultGDF).plot(ax=ax1,colors=colors[i],ls=ls,alpha=0.75)
        # plot the facilities
        dfFacility = resultGDF[resultGDF["City Index"]==uniqueClusters[i]]
        dfFacility.plot(ax=ax1,markersize=1000,marker="o",alpha=.75,facecolors='none', edgecolors=colors[i])
    totalRoutingCost = np.sum(list(subtourRoutingCosts.values()))
    totalRoutingDistance = np.sum(list(subtourDistances.values()))
    f""
    ax1.set_title(f"Tours organized by cluster\nNode sizes proportional to demand\nConstruction Cost: ${totalConstructionCost:,.2f}, Routing Distance: {totalRoutingDistance/1000:,.0f} KM\n$Total Cost: {totalConstructionCost + totalRoutingCost:,.2f}")
    ax1.legend()
    # Plot assignments
    plt.imshow(assignments)
    ax2.set_title("Assignment of citites to subtours")
    ax2.set_xlabel("Subtour Root (Flag/Concentrator) Node")
    ax2.set_ylabel("City")

# %% [markdown]
# # **2. SET UP CITIES**

# %%
illinoisCitiesPath = "Final Presentation\\tl_2016_17_place\\tl_2016_17_place.shp"
illinoisCitiesPath = "Final Presentation\\illinois_projected.shp"
illinois = gpd.read_file(illinoisCitiesPath)

# %%
nCities = 40
facilityOneBaseCost = 100000
facilityOneBaseSTD = 10000
facilityTwoBaseCost = 1000000
facilityTwoBaseSTD = 100000
baseDemand = 10000
baseDemandSTD = 10000
demands = np.random.normal(baseDemand, baseDemandSTD, nCities)
demands = [np.abs(demand) for demand in demands]
facilityOneCosts = np.random.normal(facilityOneBaseCost, facilityOneBaseSTD, nCities)
facilityOneCosts = [np.abs(facilityOneCost) for facilityOneCost in facilityOneCosts]
facilityTwoCosts = np.random.normal(facilityTwoBaseCost, facilityTwoBaseSTD, nCities)
facilityTwoCosts = [np.abs(facilityTwoCost) for facilityTwoCost in facilityTwoCosts]
cityIndices = range(nCities)
xs = []
ys = []
pts = []
polygons = []
cityNames = []
illinoisGeoms = illinois.sort_values("ALAND",ascending=False).reset_index()
for i,row in illinoisGeoms[0:nCities].iterrows():
    pts.append(row["geometry"].centroid)
    polygons.append(row["geometry"])
    xs.append(row["geometry"].centroid.x)
    ys.append(row["geometry"].centroid.y)
    cityNames.append(row["NAME"])


illinoisCities = gpd.GeoDataFrame({"x":xs,"y":ys,"demand":demands,"geometry":pts,"polygon":polygons,"City Index":cityIndices,"Facility One Cost":facilityOneCosts,"Facility Two Cost":facilityTwoCosts,"Name":cityNames})

# %% [markdown]
# # **3. SOLVE TSP SUB-TOURS**

# %%
solveAndPlot(illinoisCities,M=10,Rvz=[100000,600000],truckCapacityZ=[40000,80000],alpha=0.1,fractionTruckRangeAllowed=0.7,maxTimeLimit=2*60*1000)

# %%
# %prun solveAndPlot(illinoisCities,M=10,Rvz=[100000,600000],truckCapacityZ=[40000,80000],alpha=0.01,fractionTruckRangeAllowed=0.65,maxTimeLimit=2*60*1000)
# Out:
# Route for vehicle 0:
#  2 -> 43 -> 32 -> 8 -> 11 -> 31 -> 13 -> 23 -> 2
# Route distance: 332.548 km
#
# Route for vehicle 0:
#  33 -> 35 -> 33
# Route distance: 20.614 km
#
# Route for vehicle 0:
#  3 -> 29 -> 40 -> 3
# Route distance: 569.66 km
#
# Route for vehicle 0:
#  30 -> 36 -> 30
# Route distance: 65.956 km
#
# Route for vehicle 0:
#  9 -> 42 -> 22 -> 9
# Route distance: 69.529 km
#
# Route for vehicle 0:
#  1 -> 26 -> 14 -> 7 -> 5 -> 41 -> 37 -> 20 -> 49 -> 12 -> 48 -> 1
# Route distance: 385.21 km
#
# Route for vehicle 0:
#  0 -> 18 -> 17 -> 39 -> 47 -> 28 -> 46 -> 38 -> 0
# Route distance: 523.059 km
#
# Route for vehicle 0:
#  15 -> 44 -> 24 -> 15
# Route distance: 78.29 km
#
# Route for vehicle 0:
#  19 -> 34 -> 25 -> 45 -> 19
# Route distance: 85.962 km
#
# Route for vehicle 0:
#  4 -> 21 -> 6 -> 16 -> 10 -> 27 -> 4
# Route distance: 412.365 km
#          6475065 function calls (6412085 primitive calls) in 130.201 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1  117.594  117.594  117.594  117.594 {built-in method ortools.linear_solver._pywraplp.Solver_Solve}
#       528    2.486    0.005    2.589    0.005 {method 'draw_path_collection' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         1    0.476    0.476    1.240    1.240 <ipython-input-36-b849eecaab9b>:21(<listcomp>)
#    535085    0.287    0.000    0.548    0.000 {built-in method builtins.isinstance}
#     17600    0.257    0.000    0.365    0.000 linear_solver_natural_api.py:119(__rmul__)
# 508075/508045    0.225    0.000    0.461    0.000 {built-in method builtins.getattr}
#       918    0.217    0.000    0.217    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
# 68973/68415    0.211    0.000    0.607    0.000 {built-in method numpy.array}
#    170100    0.179    0.000    0.345    0.000 pywraplp.py:419(__getattr__)
#      5865    0.162    0.000    0.272    0.000 coords.py:124(array_interface)
#      3974    0.146    0.000    0.188    0.000 cycler.py:349(by_key)
#     19208    0.132    0.000    0.132    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       352    0.112    0.000    0.115    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#    105983    0.111    0.000    0.142    0.000 __init__.py:810(__getitem__)
#    168341    0.107    0.000    0.136    0.000 generic.py:7(_check)
# 109580/92463    0.103    0.000    0.150    0.000 artist.py:219(stale)
#    132821    0.092    0.000    0.094    0.000 {built-in method _abc._abc_instancecheck}
#     29985    0.085    0.000    0.090    0.000 coords.py:44(_update)
#     26335    0.085    0.000    0.118    0.000 predicates.py:23(__call__)
#     23720    0.084    0.000    0.159    0.000 coords.py:48(__len__)
#      2751    0.078    0.000    0.194    0.000 linear_solver_natural_api.py:95(GetCoeffs)
#      5081    0.073    0.000    1.324    0.000 series.py:152(__init__)
#      2112    0.068    0.000    0.607    0.000 text.py:655(draw)
#    192800    0.066    0.000    0.066    0.000 linear_solver_natural_api.py:164(__init__)
#      1686    0.065    0.000    0.531    0.000 lines.py:273(__init__)
#      5795    0.065    0.000    0.237    0.000 patch.py:33(coding)
#      3154    0.063    0.000    0.099    0.000 {pandas._libs.lib.infer_dtype}
#      2496    0.062    0.000    0.410    0.000 lines.py:751(draw)
#     60501    0.061    0.000    0.108    0.000 {built-in method builtins.hasattr}
#     36126    0.060    0.000    0.121    0.000 common.py:1845(_is_dtype_type)
#      7648    0.060    0.000    0.107    0.000 polygon.py:183(_get_ring)
#      5465    0.059    0.000    0.092    0.000 artist.py:74(__init__)
#     26335    0.057    0.000    0.191    0.000 base.py:640(is_empty)
#      6978    0.056    0.000    0.056    0.000 {built-in method numpy.dot}
# 136136/113946    0.056    0.000    0.158    0.000 {built-in method builtins.len}
#    132821    0.055    0.000    0.150    0.000 abc.py:137(__instancecheck__)
#      1394    0.054    0.000    0.194    0.000 lines.py:667(recache)
#     16001    0.053    0.000    0.363    0.000 colors.py:149(to_rgba)
#      9523    0.052    0.000    0.052    0.000 {built-in method numpy.concatenate}
#       528    0.049    0.000    1.026    0.002 ticker.py:2016(_raw_ticks)
#       832    0.049    0.000    0.056    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     37149    0.047    0.000    0.207    0.000 base.py:75(is_dtype)
#      4443    0.047    0.000    0.699    0.000 construction.py:537(sanitize_array)
#     11572    0.047    0.000    0.047    0.000 base.py:67(geometry_type_name)
#      2836    0.047    0.000    0.091    0.000 topology.py:44(__call__)
#        32    0.046    0.001    0.046    0.001 {method 'clear' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      4926    0.043    0.000    0.212    0.000 cast.py:953(maybe_cast_to_datetime)
#      5848    0.043    0.000    0.236    0.000 base.py:4342(get_value)
#     12430    0.043    0.000    0.141    0.000 fromnumeric.py:69(_wrapreduction)
#      4596    0.041    0.000    0.250    0.000 blocks.py:3034(get_block_type)
#     13292    0.041    0.000    0.098    0.000 dtypes.py:68(find)
#     73696    0.041    0.000    0.041    0.000 path.py:197(vertices)
#     70900    0.040    0.000    0.152    0.000 linear_solver_natural_api.py:52(CastToLinExp)
#     22900    0.039    0.000    0.129    0.000 linear_solver_natural_api.py:174(__init__)
#      9056    0.039    0.000    0.105    0.000 _dtype.py:319(_name_get)
#      9231    0.039    0.000    0.063    0.000 {pandas._libs.lib.is_scalar}
#     11337    0.038    0.000    0.427    0.000 generic.py:5053(__getattr__)
#      9404    0.036    0.000    0.067    0.000 common.py:160(is_sparse)
#   7110/32    0.036    0.000    5.804    0.181 artist.py:30(draw_wrapper)
#         1    0.036    0.036  130.248  130.248 <ipython-input-8-52f7402de033>:1(solveAndPlot)
#        11    0.035    0.003    1.511    0.137 <ipython-input-3-a4e7a57e50e3>:1(buildDistanceMatrix_Euclidean)
#     22700    0.034    0.000    0.461    0.000 pywraplp.py:569(<lambda>)
#     18589    0.034    0.000    0.097    0.000 common.py:131(is_object_dtype)
#      8565    0.034    0.000    0.071    0.000 generic.py:5069(__setattr__)
#      3789    0.034    0.000    0.085    0.000 cast.py:832(maybe_castable)
#    105986    0.031    0.000    0.031    0.000 {function RcParams.__getitem__ at 0x000001D4E5472158}
#      5848    0.031    0.000    0.387    0.000 series.py:865(__getitem__)
#      9056    0.031    0.000    0.066    0.000 numerictypes.py:365(issubdtype)
#      3942    0.030    0.000    0.075    0.000 polygon.py:246(exterior)
# 31223/30676    0.030    0.000    0.561    0.000 numeric.py:469(asarray)
#    114729    0.030    0.000    0.030    0.000 {built-in method builtins.issubclass}
#     17121    0.029    0.000    0.029    0.000 {method 'match' of 're.Pattern' objects}
#     15451    0.029    0.000    0.035    0.000 linear_solver_natural_api.py:214(AddSelfToCoeffMapOrStack)
#      1936    0.029    0.000    0.271    0.000 text.py:852(get_window_extent)
#    140316    0.029    0.000    0.029    0.000 base.py:253(_geom)
#     15451    0.029    0.000    0.121    0.000 linear_solver_natural_api.py:209(<listcomp>)
#      4413    0.029    0.000    0.470    0.000 construction.py:684(_try_cast)
#     15541    0.028    0.000    0.067    0.000 inference.py:253(is_list_like)
#      3048    0.028    0.000    0.118    0.000 artist.py:942(update)
#      2576    0.028    0.000    0.076    0.000 backend_bases.py:718(__init__)
#     24472    0.027    0.000    0.027    0.000 transforms.py:82(__init__)
#       864    0.027    0.000    0.027    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#      7414    0.027    0.000    0.027    0.000 {built-in method numpy.empty}
#     19007    0.026    0.000    0.047    0.000 transforms.py:1683(__init__)
#       264    0.026    0.000    1.422    0.005 axis.py:1074(_update_ticks)
#      2750    0.026    0.000    0.187    0.000 linear_solver_natural_api.py:251(Extract)
#     35148    0.026    0.000    0.026    0.000 linear_solver_natural_api.py:167(AddSelfToCoeffMapOrStack)
#      8493    0.026    0.000    0.026    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      5081    0.025    0.000    0.360    0.000 managers.py:1443(__init__)
#      1983    0.025    0.000    0.465    0.000 patches.py:42(__init__)
#      5330    0.025    0.000    0.040    0.000 font_manager.py:660(__hash__)
#       562    0.025    0.000    0.996    0.002 axis.py:56(__init__)
#       864    0.025    0.000    0.028    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      5848    0.025    0.000    0.035    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#      2966    0.024    0.000    0.104    0.000 cast.py:846(maybe_infer_to_datetimelike)
#     32007    0.024    0.000    0.064    0.000 topology.py:16(_validate)
#    110748    0.024    0.000    0.024    0.000 artist.py:774(get_animated)
#     27011    0.024    0.000    0.070    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#       864    0.024    0.000    0.376    0.000 backend_agg.py:164(draw_text)
#      5692    0.024    0.000    0.056    0.000 blocks.py:78(__init__)
#      6800    0.023    0.000    0.032    0.000 __init__.py:2012(_setattr_cm)
#      2576    0.023    0.000    0.094    0.000 text.py:270(_get_layout)
#      3628    0.023    0.000    0.097    0.000 path.py:96(__init__)
#     16001    0.023    0.000    0.104    0.000 colors.py:115(_is_nth_color)
#      1712    0.023    0.000    0.045    0.000 transforms.py:671(translated)
#     16018    0.023    0.000    0.034    0.000 re.py:271(_compile)
#     43718    0.023    0.000    0.023    0.000 cycler.py:227(<genexpr>)
#     18112    0.022    0.000    0.033    0.000 numerictypes.py:293(issubclass_)
#     11984    0.022    0.000    0.031    0.000 {method 'format' of 'str' objects}
#       528    0.022    0.000    0.081    0.000 ticker.py:764(_set_format)
#     12017    0.022    0.000    0.065    0.000 common.py:1981(pandas_dtype)
#      1971    0.022    0.000    0.631    0.000 patch.py:63(<listcomp>)
#     12458    0.021    0.000    0.088    0.000 common.py:1702(is_extension_array_dtype)
#        32    0.021    0.001    0.022    0.001 {built-in method matplotlib._path.get_path_collection_extents}
# 3912/3234    0.021    0.000    0.082    0.000 transforms.py:2395(get_affine)
#      5692    0.020    0.000    0.339    0.000 blocks.py:3080(make_block)
#     13061    0.020    0.000    0.057    0.000 {pandas._libs.lib.values_from_object}
#      3628    0.020    0.000    0.049    0.000 path.py:188(_update_values)
#     70551    0.020    0.000    0.020    0.000 path.py:211(codes)
#     21130    0.019    0.000    0.024    0.000 base.py:652(__len__)
#      4287    0.019    0.000    0.022    0.000 transforms.py:164(set_children)
#      1856    0.019    0.000    0.019    0.000 {method 'round' of 'numpy.ndarray' objects}
#     15451    0.019    0.000    0.140    0.000 linear_solver_natural_api.py:208(__init__)
# 3962/2656    0.018    0.000    0.021    0.000 transforms.py:137(_invalidate_internal)
#    121282    0.018    0.000    0.018    0.000 {method 'append' of 'list' objects}
#      1686    0.018    0.000    0.035    0.000 lines.py:1145(set_linestyle)
#     16017    0.018    0.000    0.078    0.000 re.py:170(match)
#      5081    0.018    0.000    0.023    0.000 series.py:354(_set_axis)
#     11590    0.018    0.000    0.124    0.000 polygon.py:139(__next__)
#     12476    0.017    0.000    0.025    0.000 base.py:257(_geom)
#      4648    0.017    0.000    0.020    0.000 contextlib.py:81(__init__)
#      3015    0.017    0.000    0.044    0.000 transforms.py:726(__init__)
# 29428/25016    0.017    0.000    0.047    0.000 {built-in method builtins.hash}
#      3047    0.017    0.000    0.960    0.000 frame.py:797(iterrows)
#      1968    0.017    0.000    0.017    0.000 transforms.py:2867(_interval_contains_close)
#     73499    0.017    0.000    0.017    0.000 {method 'pop' of 'list' objects}
#      7648    0.017    0.000    0.017    0.000 {built-in method builtins.repr}
#      1971    0.017    0.000    1.156    0.001 patch.py:29(PolygonPath)
#     15488    0.016    0.000    0.019    0.000 __init__.py:2151(_check_in_list)
#       528    0.016    0.000    0.040    0.000 ticker.py:688(_compute_offset)
#      1968    0.016    0.000    0.027    0.000 ticker.py:576(__call__)
#       632    0.016    0.000    0.379    0.001 ops.py:1660(wrapper)
#      3544    0.016    0.000    0.078    0.000 markers.py:245(_recache)
#      5795    0.016    0.000    0.016    0.000 {built-in method numpy.copyto}
#     12060    0.016    0.000    0.103    0.000 base.py:320(_get_coords)
#      1971    0.016    0.000    0.326    0.000 patch.py:64(<listcomp>)
#      5545    0.016    0.000    0.044    0.000 dtypes.py:973(is_dtype)
#       528    0.016    0.000    2.687    0.005 collections.py:249(draw)
#     22900    0.016    0.000    0.019    0.000 linear_solver_natural_api.py:187(AddSelfToCoeffMapOrStack)
#      8424    0.015    0.000    0.043    0.000 transforms.py:1819(__init__)
#      5849    0.015    0.000    0.042    0.000 base.py:2849(_convert_scalar_indexer)
#      6576    0.015    0.000    0.020    0.000 base.py:3918(__contains__)
#     27764    0.015    0.000    0.015    0.000 managers.py:1488(_block)
#      5755    0.015    0.000    0.019    0.000 blocks.py:199(mgr_locs)
#     25022    0.015    0.000    0.015    0.000 base.py:222(empty)
#        10    0.015    0.002    0.028    0.003 {built-in method ortools.constraint_solver._pywrapcp.RoutingModel_SolveWithParameters}
#      5276    0.015    0.000    0.015    0.000 generic.py:127(__init__)
#      3654    0.015    0.000    0.015    0.000 {built-in method matplotlib._path.affine_transform}
#      7662    0.015    0.000    0.049    0.000 __init__.py:1382(_to_unmasked_float_array)
#      9648    0.015    0.000    0.023    0.000 managers.py:1549(internal_values)
#         1    0.015    0.015  120.706  120.706 <ipython-input-36-b849eecaab9b>:1(assignFacilitiesAndCluster)
#      2576    0.015    0.000    0.059    0.000 text.py:823(get_prop_tup)
#      1971    0.014    0.000    0.405    0.000 patch.py:67(<listcomp>)
#     30884    0.014    0.000    0.021    0.000 common.py:119(<lambda>)
#      3977    0.014    0.000    0.052    0.000 patches.py:277(_set_edgecolor)
#     30884    0.014    0.000    0.014    0.000 common.py:117(classes)
#      1772    0.014    0.000    0.097    0.000 markers.py:292(set_marker)
#      1187    0.014    0.000    0.070    0.000 font_manager.py:620(__init__)
#      6741    0.014    0.000    0.025    0.000 series.py:392(name)
#     69179    0.014    0.000    0.014    0.000 path.py:251(should_simplify)
#     11300    0.014    0.000    0.026    0.000 managers.py:1522(dtype)
#      1189    0.014    0.000    0.015    0.000 font_manager.py:776(set_weight)
#       180    0.014    0.000    0.014    0.000 {method 'acquire' of '_thread.lock' objects}
#       726    0.014    0.000    0.019    0.000 transforms.py:2791(nonsingular)
#     15283    0.013    0.000    0.095    0.000 common.py:434(is_datetime64tz_dtype)
#      2760    0.013    0.000    0.159    0.000 transforms.py:1470(transform_point)
#      3821    0.013    0.000    0.054    0.000 blocks.py:2626(__init__)
#     69179    0.013    0.000    0.013    0.000 path.py:230(simplify_threshold)
#      1728    0.013    0.000    0.013    0.000 {method 'round' of 'numpy.generic' objects}
# 11000/5809    0.013    0.000    0.017    0.000 transforms.py:2357(<lambda>)
#     29171    0.013    0.000    0.013    0.000 impl.py:56(__getitem__)
#      6480    0.013    0.000    0.035    0.000 managers.py:1556(get_values)
#      5865    0.013    0.000    0.371    0.000 linestring.py:84(array_interface)
#      1149    0.013    0.000    0.092    0.000 text.py:121(__init__)
#     20250    0.013    0.000    0.013    0.000 {built-in method ortools.linear_solver._pywraplp.Constraint_SetCoefficient}
#      2828    0.013    0.000    0.133    0.000 transforms.py:1377(transform)
#      4512    0.012    0.000    0.032    0.000 text.py:809(get_unitless_position)
#       472    0.012    0.000    0.012    0.000 {pandas._libs.ops.scalar_compare}
#      1446    0.012    0.000    0.042    0.000 shape_base.py:599(column_stack)
#     13093    0.012    0.000    0.015    0.000 artist.py:338(pchanged)
#       832    0.012    0.000    1.037    0.001 axis.py:289(draw)
#      8551    0.012    0.000    0.045    0.000 artist.py:49(_stale_axes_callback)
#     10787    0.012    0.000    0.083    0.000 common.py:572(is_categorical_dtype)
#      1394    0.012    0.000    0.033    0.000 stride_tricks.py:208(broadcast_arrays)
#       528    0.012    0.000    0.018    0.000 ticker.py:727(_set_order_of_magnitude)
#       218    0.012    0.000    0.021    0.000 managers.py:186(_rebuild_blknos_and_blklocs)
#      4648    0.012    0.000    0.026    0.000 contextlib.py:116(__exit__)
#     12476    0.011    0.000    0.019    0.000 base.py:233(__del__)
#     11572    0.011    0.000    0.061    0.000 base.py:347(geometryType)
#      8551    0.011    0.000    0.093    0.000 common.py:262(is_categorical)
#      1394    0.011    0.000    0.012    0.000 stride_tricks.py:185(_broadcast_shape)
#      5773    0.011    0.000    0.040    0.000 dtypes.py:827(is_dtype)
#      3977    0.011    0.000    0.277    0.000 patches.py:303(_set_facecolor)
#     51931    0.011    0.000    0.011    0.000 {method 'items' of 'dict' objects}
#     11300    0.011    0.000    0.037    0.000 series.py:406(dtype)
#      4667    0.011    0.000    0.068    0.000 fromnumeric.py:54(_wrapfunc)
#     42170    0.011    0.000    0.011    0.000 artist.py:194(axes)
#      4865    0.011    0.000    0.024    0.000 common.py:868(is_integer_dtype)
# 3604/3602    0.010    0.000    0.029    0.000 transforms.py:1776(transform_affine)
#   351/317    0.010    0.000    0.057    0.000 base.py:253(__new__)
#      9813    0.010    0.000    0.075    0.000 {built-in method builtins.next}
#     12430    0.010    0.000    0.010    0.000 fromnumeric.py:70(<dictcomp>)
#      2532    0.010    0.000    0.025    0.000 numeric.py:2656(seterr)
#       918    0.010    0.000    0.041    0.000 font_manager.py:1179(findfont)
#      1937    0.010    0.000    0.011    0.000 {built-in method builtins.sorted}
#     12600    0.010    0.000    0.093    0.000 linear_solver_natural_api.py:223(Sum)
#      1567    0.010    0.000    0.011    0.000 shape_base.py:209(_arrays_for_stack_dispatcher)
#      6320    0.010    0.000    0.046    0.000 common.py:403(is_datetime64_dtype)
#      2021    0.010    0.000    0.062    0.000 transforms.py:1976(scale)
#       340    0.010    0.000    0.015    0.000 collections.py:839(set_sizes)
#      7810    0.010    0.000    0.017    0.000 {method 'view' of 'numpy.ndarray' objects}
#      2532    0.010    0.000    0.010    0.000 numeric.py:2758(geterr)
#      9648    0.010    0.000    0.033    0.000 series.py:476(_values)
#      4648    0.010    0.000    0.029    0.000 contextlib.py:237(helper)
#      5722    0.009    0.000    0.063    0.000 base.py:3975(_can_hold_identifiers_and_holds_name)
#     11590    0.009    0.000    0.009    0.000 polygon.py:31(__init__)
#     23180    0.009    0.000    0.009    0.000 {method 'startswith' of 'str' objects}
#       704    0.009    0.000    0.027    0.000 patches.py:504(_bind_draw_path_function)
# 2256/2248    0.009    0.000    0.016    0.000 spines.py:487(get_spine_transform)
#      1971    0.009    0.000    0.218    0.000 patch.py:68(<listcomp>)
#      2750    0.009    0.000    0.009    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_Constraint}
#       264    0.009    0.000    0.464    0.002 axis.py:2486(get_tick_space)
#      2836    0.009    0.000    0.103    0.000 base.py:434(distance)
#       140    0.009    0.000    0.010    0.000 __init__.py:1673(normalize_kwargs)
#      3942    0.009    0.000    0.009    0.000 polygon.py:150(__len__)
#      3736    0.009    0.000    0.068    0.000 fromnumeric.py:2083(any)
#     20250    0.009    0.000    0.022    0.000 pywraplp.py:458(SetCoefficient)
#      8832    0.009    0.000    0.023    0.000 integer.py:80(construct_from_string)
#      3503    0.009    0.000    0.017    0.000 artist.py:673(set_figure)
#       486    0.009    0.000    0.058    0.000 algorithms.py:1544(take_nd)
#      3372    0.009    0.000    0.015    0.000 lines.py:1112(_split_drawstyle_linestyle)
#       264    0.009    0.000    0.452    0.002 axis.py:2179(get_tick_space)
#      7442    0.009    0.000    0.019    0.000 lines.py:59(_scale_dashes)
#      5574    0.008    0.000    0.013    0.000 series.py:399(name)
#       430    0.008    0.000    0.011    0.000 numerictypes.py:578(_can_coerce_all)
#        80    0.008    0.000    0.008    0.000 socket.py:337(send)
#      1395    0.008    0.000    0.030    0.000 axis.py:617(update_position)
#      2992    0.008    0.000    0.038    0.000 transforms.py:1748(frozen)
#      6719    0.008    0.000    0.013    0.000 artist.py:373(get_transform)
#     27356    0.008    0.000    0.008    0.000 {built-in method _ctypes.byref}
#      3955    0.008    0.000    0.111    0.000 common.py:1643(is_extension_type)
#     16559    0.008    0.000    0.008    0.000 {method 'pop' of 'dict' objects}
#      3799    0.008    0.000    0.013    0.000 <ipython-input-7-e2210c2c3aae>:57(distance_callback)
#      7648    0.008    0.000    0.027    0.000 polygon.py:180(gtag)
#      5795    0.007    0.000    0.042    0.000 numeric.py:175(ones)
#      5784    0.007    0.000    0.052    0.000 common.py:536(is_interval_dtype)
#      8566    0.007    0.000    0.016    0.000 figure.py:49(_stale_figure_callback)
#        28    0.007    0.000    0.031    0.001 axis.py:332(_apply_params)
#       624    0.007    0.000    0.238    0.000 base.py:103(_unary_op)
#      1983    0.007    0.000    0.018    0.000 patches.py:375(set_linestyle)
#      4648    0.007    0.000    0.063    0.000 contextlib.py:107(__enter__)
#      5722    0.007    0.000    0.039    0.000 base.py:1681(is_object)
#     10000    0.007    0.000    0.086    0.000 linear_solver_natural_api.py:104(__add__)
#      5091    0.007    0.000    0.012    0.000 lines.py:1282(set_xdata)
#      1220    0.007    0.000    0.030    0.000 transforms.py:1506(transform_path_non_affine)
#         1    0.007    0.007    0.007    0.007 backend_agg.py:80(__init__)
#     26335    0.007    0.000    0.007    0.000 geos.py:545(errcheck_predicate)
#      1227    0.007    0.000    0.007    0.000 {built-in method numpy.arange}
#      5773    0.007    0.000    0.047    0.000 common.py:503(is_period_dtype)
#       352    0.007    0.000    0.202    0.001 patches.py:563(draw)
#      3721    0.007    0.000    0.009    0.000 lines.py:31(_get_dash_pattern)
#      1863    0.007    0.000    0.008    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      2828    0.007    0.000    0.095    0.000 transforms.py:2371(transform_affine)
#      1189    0.007    0.000    0.009    0.000 font_manager.py:812(set_size)
#       128    0.007    0.000    2.779    0.022 axis.py:1195(draw)
#       891    0.007    0.000    0.007    0.000 text.py:41(get_rotation)
#      4366    0.007    0.000    0.029    0.000 transforms.py:2470(composite_transform_factory)
#      2052    0.006    0.000    0.018    0.000 path.py:159(_fast_from_codes_and_verts)
#      3428    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      3942    0.006    0.000    0.042    0.000 polygon.py:260(interiors)
#      1135    0.006    0.000    0.025    0.000 axis.py:500(update_position)
#      5465    0.006    0.000    0.011    0.000 <string>:1(__new__)
#     13375    0.006    0.000    0.006    0.000 blocks.py:308(dtype)
#      6480    0.006    0.000    0.014    0.000 blocks.py:184(to_dense)
#      2656    0.006    0.000    0.027    0.000 transforms.py:126(invalidate)
#       528    0.006    0.000    0.008    0.000 ticker.py:1828(scale_range)
#      1138    0.006    0.000    0.011    0.000 dtypes.py:786(construct_from_string)
#      1971    0.006    0.000    1.625    0.001 patch.py:73(PolygonPatch)
#       346    0.006    0.000    0.019    0.000 missing.py:183(_isna_ndarraylike)
#       787    0.006    0.000    0.039    0.000 base.py:1117(__iter__)
#        64    0.006    0.000    0.064    0.001 _base.py:2425(handle_single_axis)
#      2496    0.006    0.000    0.015    0.000 lines.py:953(_get_markerfacecolor)
#      4443    0.006    0.000    0.030    0.000 arrays.py:7(extract_array)
#      2526    0.006    0.000    0.059    0.000 patches.py:209(get_transform)
#       190    0.006    0.000    0.011    0.000 colors.py:254(to_rgba_array)
#      4060    0.006    0.000    0.023    0.000 common.py:472(is_timedelta64_dtype)
#      1686    0.006    0.000    0.010    0.000 lines.py:1412(set_solid_capstyle)
#      3584    0.006    0.000    0.044    0.000 fromnumeric.py:2940(around)
#      5692    0.006    0.000    0.006    0.000 blocks.py:89(_check_ndim)
#      1761    0.006    0.000    0.018    0.000 artist.py:946(_update_property)
#      6480    0.006    0.000    0.041    0.000 series.py:490(get_values)
#      1522    0.006    0.000    0.015    0.000 transforms.py:2299(__init__)
#      5508    0.006    0.000    0.011    0.000 font_manager.py:1233(<genexpr>)
#      5871    0.006    0.000    0.011    0.000 lines.py:1294(set_ydata)
#       264    0.006    0.000    0.248    0.001 axis.py:1149(<listcomp>)
#       264    0.006    0.000    0.511    0.002 axis.py:1326(get_minorticklocs)
#      5523    0.006    0.000    0.006    0.000 {built-in method builtins.max}
#      6713    0.006    0.000    0.018    0.000 artist.py:170(convert_xunits)
#       510    0.006    0.000    0.233    0.000 frame.py:2893(__getitem__)
#      1686    0.006    0.000    0.010    0.000 lines.py:1398(set_dash_capstyle)
#      3728    0.006    0.000    0.041    0.000 fromnumeric.py:2512(amin)
#       713    0.005    0.000    0.005    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      1211    0.005    0.000    0.040    0.000 text.py:170(update)
#       111    0.005    0.000    0.038    0.000 managers.py:772(_interleave)
#      8031    0.005    0.000    0.005    0.000 {built-in method __new__ of type object at 0x00007FFF42D56BA0}
#       400    0.005    0.000    0.013    0.000 coords.py:69(__getitem__)
#        32    0.005    0.000    0.074    0.002 plotting.py:8(_flatten_multi_geoms)
#     10951    0.005    0.000    0.005    0.000 transforms.py:1857(get_matrix)
#      6721    0.005    0.000    0.007    0.000 common.py:316(apply_if_callable)
#     12060    0.005    0.000    0.005    0.000 coords.py:41(__init__)
#     14220    0.005    0.000    0.005    0.000 artist.py:858(get_agg_filter)
#       528    0.005    0.000    1.047    0.002 ticker.py:2080(tick_values)
#      3794    0.005    0.000    0.035    0.000 fromnumeric.py:2397(amax)
#      6078    0.005    0.000    0.011    0.000 generic.py:426(_info_axis)
#      3764    0.005    0.000    0.014    0.000 transforms.py:2181(get_affine)
#      1686    0.005    0.000    0.047    0.000 lines.py:1241(set_markerfacecolor)
#      5451    0.005    0.000    0.007    0.000 base.py:5318(ensure_index)
#       528    0.005    0.000    0.024    0.000 collections.py:212(_prepare_points)
#      2052    0.005    0.000    0.011    0.000 transforms.py:2149(transform_non_affine)
#     17905    0.005    0.000    0.005    0.000 {method 'lower' of 'str' objects}
#      1187    0.005    0.000    0.006    0.000 font_manager.py:794(set_stretch)
#      2576    0.005    0.000    0.007    0.000 artist.py:828(_set_gc_clip)
#       632    0.005    0.000    0.043    0.000 ops.py:1615(na_op)
#     10362    0.005    0.000    0.005    0.000 transforms.py:946(get_points)
#       528    0.005    0.000    1.057    0.002 ticker.py:2076(__call__)
#      2946    0.005    0.000    0.005    0.000 {pandas._libs.lib.infer_datetimelike_array}
#     11791    0.005    0.000    0.005    0.000 {built-in method builtins.iter}
#      1686    0.005    0.000    0.011    0.000 lines.py:1095(set_linewidth)
#       528    0.005    0.000    0.010    0.000 _methods.py:151(_ptp)
#       832    0.005    0.000    0.034    0.000 transforms.py:2710(_revalidate)
#       918    0.005    0.000    0.056    0.000 backend_agg.py:241(_get_agg_font)
#      2700    0.005    0.000    0.039    0.000 linear_solver_natural_api.py:143(__le__)
#      7318    0.005    0.000    0.034    0.000 base.py:421(geom_type)
#       283    0.005    0.000    0.129    0.000 axis.py:602(_get_gridline)
#      1686    0.005    0.000    0.008    0.000 lines.py:1061(set_drawstyle)
#      1128    0.005    0.000    0.013    0.000 transforms.py:2654(__init__)
#      3928    0.005    0.000    0.011    0.000 cast.py:1218(construct_1d_ndarray_preserving_na)
#      2176    0.005    0.000    0.017    0.000 axis.py:1881(getter)
#      6837    0.005    0.000    0.011    0.000 artist.py:182(convert_yunits)
#       816    0.005    0.000    0.008    0.000 base.py:894(_get_geom_item)
#      3846    0.005    0.000    0.027    0.000 transforms.py:1236(__add__)
#      7058    0.005    0.000    0.018    0.000 numeric.py:541(asanyarray)
#      4144    0.005    0.000    0.007    0.000 function_base.py:258(iterable)
#      3978    0.005    0.000    0.006    0.000 cycler.py:225(__iter__)
#       264    0.005    0.000    0.006    0.000 spines.py:254(_adjust_location)
#      2828    0.005    0.000    0.016    0.000 transforms.py:2375(transform_non_affine)
#     13600    0.005    0.000    0.005    0.000 artist.py:770(get_visible)
#      2823    0.005    0.000    0.006    0.000 range.py:510(__len__)
#       528    0.005    0.000    0.005    0.000 {method 'clip' of 'numpy.ndarray' objects}
#      1495    0.005    0.000    0.007    0.000 __init__.py:1373(is_math_text)
#      5081    0.005    0.000    0.005    0.000 series.py:382(_set_subtyp)
#        68    0.005    0.000    0.056    0.001 _base.py:2503(_update_title_position)
#      3942    0.004    0.000    0.005    0.000 polygon.py:129(__init__)
#      1993    0.004    0.000    0.010    0.000 patches.py:355(set_linewidth)
#      1686    0.004    0.000    0.008    0.000 lines.py:1352(set_dash_joinstyle)
#      1983    0.004    0.000    0.117    0.000 patches.py:409(set_fill)
#       313    0.004    0.000    0.063    0.000 series.py:3600(_reduce)
#       278    0.004    0.000    0.095    0.000 transforms.py:697(union)
#      2894    0.004    0.000    0.011    0.000 artist.py:360(set_transform)
#        10    0.004    0.000    0.734    0.073 <ipython-input-6-4ad955854af3>:1(convertTourToPathDF)
#     14220    0.004    0.000    0.004    0.000 artist.py:838(get_rasterized)
#       779    0.004    0.000    0.004    0.000 core.py:3349(dtype)
#       406    0.004    0.000    0.032    0.000 managers.py:318(apply)
#      7704    0.004    0.000    0.004    0.000 {method 'update' of 'dict' objects}
#      3458    0.004    0.000    0.006    0.000 __init__.py:1916(_str_lower_equal)
#       510    0.004    0.000    0.242    0.000 geodataframe.py:465(__getitem__)
#      2100    0.004    0.000    0.011    0.000 ticker.py:567(fix_minus)
#      1971    0.004    0.000    0.463    0.000 patches.py:942(__init__)
#       528    0.004    0.000    0.143    0.000 ticker.py:677(set_locs)
#      1772    0.004    0.000    0.116    0.000 markers.py:223(__init__)
#      1754    0.004    0.000    0.020    0.000 transforms.py:362(ymax)
#      1511    0.004    0.000    0.005    0.000 transforms.py:377(intervalx)
#        32    0.004    0.000    8.077    0.252 plotting.py:214(plot_series)
#     96/32    0.004    0.000    5.768    0.180 image.py:117(_draw_list_compositing_images)
#     11742    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#       279    0.004    0.000    0.114    0.000 axis.py:458(_get_tick1line)
#      1579    0.004    0.000    0.008    0.000 dtypes.py:672(construct_from_string)
#      3978    0.004    0.000    0.004    0.000 cycler.py:138(keys)
#      1686    0.004    0.000    0.013    0.000 lines.py:648(set_data)
#       486    0.004    0.000    0.013    0.000 algorithms.py:1417(_get_take_nd_function)
#      2432    0.004    0.000    0.012    0.000 {built-in method builtins.all}
#       283    0.004    0.000    0.111    0.000 axis.py:573(_get_tick1line)
#       283    0.004    0.000    0.060    0.000 axis.py:543(_get_text1)
#        10    0.004    0.000    0.004    0.000 {built-in method ortools.constraint_solver._pywrapcp.new_RoutingModel}
#      3400    0.004    0.000    0.005    0.000 __init__.py:2017(<listcomp>)
#      4296    0.004    0.000    0.005    0.000 inference.py:438(is_hashable)
#   335/334    0.004    0.000    0.007    0.000 transforms.py:413(bounds)
#       528    0.004    0.000    0.031    0.000 ticker.py:259(<listcomp>)
#      7948    0.004    0.000    0.004    0.000 cycler.py:371(<genexpr>)
#       279    0.004    0.000    0.065    0.000 axis.py:425(_get_text1)
#      2576    0.004    0.000    0.079    0.000 backend_bases.py:654(new_gc)
#      5195    0.004    0.000    0.004    0.000 transforms.py:1671(<lambda>)
#      1511    0.004    0.000    0.005    0.000 transforms.py:386(intervaly)
#      1686    0.004    0.000    0.008    0.000 lines.py:1367(set_solid_joinstyle)
#      5798    0.004    0.000    0.007    0.000 transforms.py:178(<lambda>)
#      1772    0.004    0.000    0.014    0.000 markers.py:267(set_fillstyle)
#       192    0.004    0.000    0.029    0.000 generic.py:5948(fillna)
#      6082    0.004    0.000    0.004    0.000 artist.py:199(axes)
#      1162    0.004    0.000    0.006    0.000 text.py:1122(set_verticalalignment)
#      3942    0.004    0.000    0.013    0.000 polygon.py:134(__iter__)
#      4736    0.004    0.000    0.008    0.000 common.py:1809(_get_dtype)
#       162    0.004    0.000    0.007    0.000 indexing.py:2575(maybe_convert_indices)
#        80    0.004    0.000    0.018    0.000 managers.py:868(fast_xs)
#      1358    0.004    0.000    0.013    0.000 common.py:1578(is_bool_dtype)
#      3584    0.004    0.000    0.048    0.000 fromnumeric.py:3373(round_)
#       313    0.004    0.000    0.039    0.000 nanops.py:203(_get_values)
#      1664    0.004    0.000    0.004    0.000 lines.py:521(get_fillstyle)
#       279    0.004    0.000    0.122    0.000 axis.py:484(_get_gridline)
#      1484    0.004    0.000    0.020    0.000 transforms.py:347(xmin)
#      1991    0.004    0.000    0.006    0.000 patches.py:431(set_capstyle)
#       832    0.004    0.000    0.009    0.000 transforms.py:2694(__init__)
#       918    0.004    0.000    0.004    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#      1187    0.004    0.000    0.007    0.000 font_manager.py:757(set_style)
#      1686    0.004    0.000    0.011    0.000 lines.py:733(set_transform)
#      9648    0.004    0.000    0.004    0.000 blocks.py:165(internal_values)
#      2810    0.004    0.000    0.016    0.000 axis.py:325(_set_artist_props)
# 3472/3470    0.004    0.000    0.032    0.000 transforms.py:1696(transform)
#      1688    0.004    0.000    0.021    0.000 transforms.py:352(ymin)
#      7658    0.004    0.000    0.006    0.000 pywrapcp.py:2820(IndexToNode)
#       485    0.004    0.000    0.013    0.000 cast.py:255(maybe_promote)
# 2515/1395    0.003    0.000    0.010    0.000 _base.py:660(get_xaxis_transform)
# 2551/1415    0.003    0.000    0.012    0.000 _base.py:736(get_yaxis_transform)
#      2750    0.003    0.000    0.191    0.000 pywraplp.py:258(Add)
#      1138    0.003    0.000    0.005    0.000 dtypes.py:929(construct_from_string)
#      1686    0.003    0.000    0.025    0.000 lines.py:1255(set_markerfacecoloralt)
#      2544    0.003    0.000    0.011    0.000 transforms.py:2133(<lambda>)
#       624    0.003    0.000    0.036    0.000 base.py:106(<listcomp>)
#      4254    0.003    0.000    0.036    0.000 base.py:350(type)
#      3942    0.003    0.000    0.082    0.000 patch.py:16(exterior)
#      3942    0.003    0.000    0.049    0.000 patch.py:21(interiors)
#      2102    0.003    0.000    0.003    0.000 dtypes.py:452(construct_from_string)
#      8625    0.003    0.000    0.003    0.000 blocks.py:195(mgr_locs)
#       373    0.003    0.000    0.006    0.000 base.py:504(_simple_new)
#      4573    0.003    0.000    0.005    0.000 __init__.py:1906(_str_equal)
#      1567    0.003    0.000    0.015    0.000 shape_base.py:220(_warn_for_nonsequence)
#      1846    0.003    0.000    0.007    0.000 geodataframe.py:60(__setattr__)
#       666    0.003    0.000    0.009    0.000 _dtype.py:46(__str__)
#      2532    0.003    0.000    0.003    0.000 {built-in method numpy.seterrobj}
#      3264    0.003    0.000    0.008    0.000 backend_bases.py:918(set_foreground)
#       374    0.003    0.000    0.021    0.000 base.py:786(array)
#       918    0.003    0.000    0.006    0.000 backend_agg.py:49(get_hinting_flag)
#       162    0.003    0.000    0.150    0.001 managers.py:1329(take)
#       412    0.003    0.000    0.008    0.000 cast.py:1193(construct_1d_object_array_from_listlike)
#   520/260    0.003    0.000    0.033    0.000 transforms.py:2320(frozen)
#      1484    0.003    0.000    0.016    0.000 transforms.py:357(xmax)
#      2600    0.003    0.000    0.003    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_IntVar}
#      3152    0.003    0.000    0.013    0.000 transforms.py:2047(transform)
#       891    0.003    0.000    0.009    0.000 text.py:1178(_preprocess_math)
#      2907    0.003    0.000    0.008    0.000 artist.py:905(set_visible)
#       602    0.003    0.000    0.006    0.000 __init__.py:968(get_siblings)
#       159    0.003    0.000    0.034    0.000 patches.py:728(_update_patch_transform)
#       832    0.003    0.000    0.014    0.000 lines.py:709(_transform_path)
#      1156    0.003    0.000    0.020    0.000 fromnumeric.py:2171(all)
#        50    0.003    0.000    0.003    0.000 <ipython-input-36-b849eecaab9b>:39(<listcomp>)
#       186    0.003    0.000    0.010    0.000 transforms.py:1914(rotate)
#       161    0.003    0.000    0.003    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#      5242    0.003    0.000    0.004    0.000 common.py:127(<lambda>)
#       283    0.003    0.000    0.101    0.000 axis.py:588(_get_tick2line)
#       130    0.003    0.000    0.026    0.000 _base.py:1446(apply_aspect)
#       484    0.003    0.000    0.068    0.000 blocks.py:1217(take_nd)
#      1007    0.003    0.000    0.009    0.000 managers.py:139(shape)
#      1686    0.003    0.000    0.004    0.000 lines.py:1212(set_markeredgecolor)
#       279    0.003    0.000    0.103    0.000 axis.py:469(_get_tick2line)
#       918    0.003    0.000    0.003    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#      2576    0.003    0.000    0.004    0.000 backend_bases.py:976(get_hatch_path)
#      5242    0.003    0.000    0.003    0.000 common.py:122(classes_and_not_datetimelike)
#         2    0.003    0.001    1.628    0.814 plotting.py:103(<listcomp>)
#       191    0.003    0.000    0.028    0.000 cast.py:1072(find_common_type)
#      2568    0.003    0.000    0.009    0.000 scale.py:101(get_transform)
#       161    0.003    0.000    0.174    0.001 generic.py:3323(_take)
#      1686    0.003    0.000    0.008    0.000 lines.py:1269(set_markersize)
#      2451    0.003    0.000    0.022    0.000 {method 'max' of 'numpy.ndarray' objects}
#      1166    0.003    0.000    0.026    0.000 missing.py:105(_isna_new)
#       283    0.003    0.000    0.054    0.000 axis.py:558(_get_text2)
#       714    0.003    0.000    0.013    0.000 common.py:93(is_bool_indexer)
#      3048    0.003    0.000    0.021    0.000 artist.py:974(<listcomp>)
#       726    0.003    0.000    0.003    0.000 getlimits.py:365(__new__)
#      1056    0.003    0.000    0.003    0.000 ticker.py:1857(closeto)
#   935/934    0.003    0.000    0.010    0.000 transforms.py:1025(get_points)
#      2942    0.003    0.000    0.009    0.000 text.py:1089(set_x)
#      5500    0.003    0.000    0.004    0.000 pywraplp.py:215(infinity)
#     12980    0.003    0.000    0.003    0.000 {built-in method builtins.id}
#      1686    0.003    0.000    0.004    0.000 lines.py:635(axes)
#      1983    0.003    0.000    0.005    0.000 patches.py:450(set_joinstyle)
#       374    0.003    0.000    0.006    0.000 numpy_.py:35(__init__)
#         2    0.003    0.001    0.018    0.009 collections.py:1810(<listcomp>)
#      6778    0.003    0.000    0.003    0.000 font_manager.py:724(get_size_in_points)
#      5246    0.003    0.000    0.003    0.000 text.py:1136(set_text)
#    654/96    0.003    0.000    0.004    0.000 arrayprint.py:716(recurser)
#      2750    0.003    0.000    0.004    0.000 six.py:588(iteritems)
#      2600    0.003    0.000    0.029    0.000 linear_solver_natural_api.py:110(__sub__)
#       562    0.003    0.000    0.004    0.000 axis.py:198(_set_labelrotation)
#       528    0.003    0.000    0.013    0.000 fromnumeric.py:2324(ptp)
#       832    0.003    0.000    0.003    0.000 markers.py:258(__bool__)
#      3462    0.003    0.000    0.008    0.000 text.py:1100(set_y)
#       134    0.003    0.000    0.006    0.000 numeric.py:2508(within_tol)
#       541    0.003    0.000    0.018    0.000 fromnumeric.py:41(_wrapit)
#       279    0.003    0.000    0.013    0.000 _base.py:684(get_xaxis_text1_transform)
#      1184    0.003    0.000    0.003    0.000 backend_bases.py:868(set_antialiased)
#      3869    0.003    0.000    0.003    0.000 numerictypes.py:587(<listcomp>)
#      1686    0.003    0.000    0.004    0.000 lines.py:1038(set_antialiased)
#      1149    0.003    0.000    0.005    0.000 text.py:918(set_color)
#      1187    0.003    0.000    0.005    0.000 font_manager.py:767(set_variant)
#      1266    0.003    0.000    0.013    0.000 numeric.py:3063(__exit__)
#      2990    0.002    0.000    0.002    0.000 {method 'count' of 'str' objects}
#       332    0.002    0.000    0.011    0.000 core.py:3663(filled)
#       160    0.002    0.000    0.004    0.000 core.py:1425(getmaskarray)
#       140    0.002    0.000    0.209    0.001 geoseries.py:58(x)
#       283    0.002    0.000    0.013    0.000 _base.py:760(get_yaxis_text1_transform)
#      5330    0.002    0.000    0.002    0.000 font_manager.py:676(get_family)
#      1266    0.002    0.000    0.003    0.000 numeric.py:3054(__init__)
#       140    0.002    0.000    0.204    0.001 geoseries.py:67(y)
#       465    0.002    0.000    0.014    0.000 generic.py:5122(_protect_consolidate)
#       528    0.002    0.000    0.112    0.000 ticker.py:256(format_ticks)
# 2708/2705    0.002    0.000    0.005    0.000 transforms.py:2573(get_matrix)
#      2836    0.002    0.000    0.004    0.000 transforms.py:1687(__array__)
#      1686    0.002    0.000    0.005    0.000 lines.py:1227(set_markeredgewidth)
#      2851    0.002    0.000    0.059    0.000 pywraplp.py:267(Sum)
#      1266    0.002    0.000    0.017    0.000 numeric.py:3058(__enter__)
#      7658    0.002    0.000    0.002    0.000 {built-in method ortools.constraint_solver._pywrapcp.RoutingIndexManager_IndexToNode}
#      1968    0.002    0.000    0.014    0.000 axis.py:301(set_label1)
#       279    0.002    0.000    0.501    0.002 axis.py:1928(_get_tick)
#       279    0.002    0.000    0.053    0.000 axis.py:442(_get_text2)
#       528    0.002    0.000    0.004    0.000 artist.py:163(have_units)
#      5000    0.002    0.000    0.002    0.000 {built-in method builtins.abs}
#       832    0.002    0.000    0.004    0.000 lines.py:928(get_markeredgecolor)
#      6859    0.002    0.000    0.002    0.000 {built-in method builtins.setattr}
#      4182    0.002    0.000    0.002    0.000 stride_tricks.py:261(<genexpr>)
#      1664    0.002    0.000    0.002    0.000 backend_agg.py:254(points_to_pixels)
#      1394    0.002    0.000    0.004    0.000 stride_tricks.py:257(<listcomp>)
#      1216    0.002    0.000    0.003    0.000 backend_bases.py:851(set_alpha)
#       512    0.002    0.000    0.002    0.000 ticker.py:712(<genexpr>)
#      2599    0.002    0.000    0.002    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetCoefficient}
#      2500    0.002    0.000    0.002    0.000 <ipython-input-36-b849eecaab9b>:35(<listcomp>)
#      2080    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      2750    0.002    0.000    0.011    0.000 pywraplp.py:170(Constraint)
#      1327    0.002    0.000    0.013    0.000 {method 'any' of 'numpy.ndarray' objects}
#        64    0.002    0.000    5.766    0.090 _base.py:2573(draw)
#         1    0.002    0.002    0.082    0.082 pywraplp.py:274(Minimize)
#       279    0.002    0.000    0.006    0.000 axis.py:411(apply_tickdir)
#       352    0.002    0.000    0.118    0.000 backend_agg.py:119(draw_path)
#       360    0.002    0.000    0.057    0.000 indexing.py:2205(_getitem_axis)
#       283    0.002    0.000    0.012    0.000 _base.py:786(get_yaxis_text2_transform)
#      1126    0.002    0.000    0.015    0.000 blocks.py:225(make_block_same_class)
#      5819    0.002    0.000    0.002    0.000 text.py:841(get_text)
#      2993    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#       666    0.002    0.000    0.016    0.000 blocks.py:312(ftype)
#      1151    0.002    0.000    0.004    0.000 text.py:934(set_horizontalalignment)
#      1968    0.002    0.000    0.014    0.000 axis.py:314(set_label2)
#        32    0.002    0.000    0.003    0.000 {pandas._libs.lib.map_infer_mask}
#      1840    0.002    0.000    0.002    0.000 {built-in method math.log10}
#       161    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#      2367    0.002    0.000    0.006    0.000 patches.py:223(get_patch_transform)
#      3728    0.002    0.000    0.002    0.000 figure.py:462(_get_dpi)
#      2600    0.002    0.000    0.002    0.000 {built-in method ortools.linear_solver._pywraplp.Variable_solution_value}
#      1336    0.002    0.000    0.049    0.000 generic.py:178(_validate_dtype)
#        32    0.002    0.000    5.803    0.181 figure.py:1661(draw)
#      5064    0.002    0.000    0.002    0.000 {built-in method numpy.geterrobj}
#       188    0.002    0.000    0.007    0.000 managers.py:963(iget)
#       195    0.002    0.000    0.023    0.000 geodataframe.py:44(__init__)
#       852    0.002    0.000    0.013    0.000 markers.py:321(get_transform)
#      6811    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_float}
#      1971    0.002    0.000    0.003    0.000 patch.py:10(__init__)
#      1178    0.002    0.000    0.005    0.000 artist.py:1005(set_zorder)
#       283    0.002    0.000    0.500    0.002 axis.py:2217(_get_tick)
#       943    0.002    0.000    0.003    0.000 generic.py:363(_get_axis_name)
#       541    0.002    0.000    0.006    0.000 transforms.py:2415(__init__)
#        20    0.002    0.000    0.110    0.005 _axes.py:4312(scatter)
#        66    0.002    0.000    0.479    0.007 axis.py:2298(_update_label_position)
#       281    0.002    0.000    0.045    0.000 base.py:584(_shallow_copy_with_infer)
#       263    0.002    0.000    0.003    0.000 core.py:2905(_update_from)
#      8484    0.002    0.000    0.002    0.000 {built-in method builtins.callable}
#      2750    0.002    0.000    0.013    0.000 pywraplp.py:271(RowConstraint)
#       312    0.002    0.000    0.065    0.000 generic.py:11018(logical_func)
#      1107    0.002    0.000    0.007    0.000 common.py:1198(is_datetime_or_timedelta_dtype)
#       160    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#        66    0.002    0.000    0.398    0.006 axis.py:2004(_update_label_position)
#        32    0.002    0.000    0.002    0.000 axis.py:842(reset_ticks)
#      1993    0.002    0.000    0.027    0.000 patches.py:292(set_edgecolor)
#       562    0.002    0.000    0.090    0.000 lines.py:1021(get_path)
#       206    0.002    0.000    0.046    0.000 managers.py:97(__init__)
#         2    0.002    0.001    1.715    0.858 plotting.py:48(plot_polygon_collection)
#      2304    0.002    0.000    0.009    0.000 axis.py:792(get_transform)
#       674    0.002    0.000    0.002    0.000 generic.py:349(_get_axis_number)
#       215    0.002    0.000    0.014    0.000 numerictypes.py:602(find_common_type)
#       787    0.002    0.000    0.021    0.000 common.py:702(is_datetimelike)
#       162    0.002    0.000    0.002    0.000 _base.py:4248(get_children)
#      2760    0.002    0.000    0.002    0.000 transforms.py:2668(get_matrix)
#      2700    0.002    0.000    0.014    0.000 linear_solver_natural_api.py:116(__mul__)
#       257    0.002    0.000    0.007    0.000 numeric.py:34(__new__)
#       528    0.002    0.000    0.004    0.000 ticker.py:1867(le)
#       314    0.002    0.000    0.026    0.000 base.py:3940(__getitem__)
# 2264/2248    0.002    0.000    0.004    0.000 spines.py:208(_ensure_position_is_set)
# ...
#         1    0.000    0.000    0.000    0.000 warnings.py:130(filterwarnings)
#         1    0.000    0.000    0.000    0.000 range.py:184(_get_data_as_items)
#         2    0.000    0.000    0.000    0.000 pyplot.py:908(gca)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#         1    0.000    0.000    0.000    0.000 generic.py:1546(_is_label_reference)
#         1    0.000    0.000    0.000    0.000 generic.py:10910(stat_func)
#         2    0.000    0.000    0.000    0.000 axis.py:1582(set_label_text)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:29(_get_top)
#         1    0.000    0.000    0.000    0.000 image.py:827(__init__)
#         4    0.000    0.000    0.000    0.000 generic.py:450(ndim)
#        14    0.000    0.000    0.000    0.000 gridspec.py:457(get_gridspec)
#         2    0.000    0.000    0.000    0.000 figure.py:1888(gca)
#         1    0.000    0.000    0.000    0.000 legend.py:1250(_parse_legend_args)
#         1    0.000    0.000    0.000    0.000 managers.py:694(<listcomp>)
#         1    0.000    0.000    0.000    0.000 cm.py:386(autoscale_None)
#         1    0.000    0.000    0.007    0.007 tight_layout.py:217(get_renderer)
#         4    0.000    0.000    0.000    0.000 six.py:184(find_module)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#         2    0.000    0.000    0.000    0.000 mathtext.py:3333(__init__)
#        20    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        60    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#         1    0.000    0.000    0.000    0.000 nanops.py:403(nansum)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:147(__enter__)
#         2    0.000    0.000    0.000    0.000 missing.py:71(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 core.py:5686(max)
#         2    0.000    0.000    0.000    0.000 base.py:4459(_maybe_promote)
#         2    0.000    0.000    0.018    0.009 collections.py:1809(set_paths)
#         2    0.000    0.000    0.000    0.000 gridspec.py:144(_normalize)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:150(__init__)
#         1    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         2    0.000    0.000    0.000    0.000 figure.py:100(_entry_from_axes)
#         2    0.000    0.000    0.000    0.000 gridspec.py:519(__eq__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:311(<listcomp>)
#         1    0.000    0.000    0.000    0.000 shape_base.py:1154(tile)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:21(_get_right)
#       3/1    0.000    0.000    0.000    0.000 {built-in method builtins.__import__}
#         1    0.000    0.000    0.000    0.000 textpath.py:25(__init__)
#         2    0.000    0.000    0.000    0.000 generic.py:1576(<genexpr>)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:188(<genexpr>)
#        10    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 tight_layout.py:25(_get_bottom)
#         1    0.000    0.000    0.000    0.000 legend.py:978(set_title)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_swiginit}
#         1    0.000    0.000    0.000    0.000 tight_layout.py:156(<listcomp>)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#         2    0.000    0.000    0.000    0.000 inspect.py:3010(bind)
#         2    0.000    0.000    0.000    0.000 text.py:1027(set_fontsize)
#         3    0.000    0.000    0.000    0.000 base.py:1672(is_integer)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#         1    0.000    0.000    0.000    0.000 __init__.py:1221(getLogger)
#         2    0.000    0.000    0.000    0.000 transforms.py:886(x0)
#         6    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         2    0.000    0.000    0.000    0.000 _base.py:846(set_position)
#         8    0.000    0.000    0.000    0.000 axis.py:1462(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:355(SetMinimization)
#         1    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#         1    0.000    0.000    0.000    0.000 nanops.py:1052(_maybe_null_out)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:530(__hash__)
#         2    0.000    0.000    0.000    0.000 figure.py:160(__contains__)
#         1    0.000    0.000    0.000    0.000 base.py:2965(_convert_listlike_indexer)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:337(Clear)
#         1    0.000    0.000    0.000    0.000 patches.py:337(set_alpha)
#        10    0.000    0.000    0.000    0.000 collections.py:827(get_sizes)
#         1    0.000    0.000    0.000    0.000 __init__.py:23(find_module)
#         2    0.000    0.000    0.000    0.000 core.py:291(_extremum_fill_value)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetOffset}
#         2    0.000    0.000    0.000    0.000 patches.py:2214(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:891(y0)
#         2    0.000    0.000    0.000    0.000 gridspec.py:310(locally_modified_subplot_params)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2500(notify_axes_change)
#         4    0.000    0.000    0.000    0.000 nanops.py:71(<genexpr>)
#         3    0.000    0.000    0.000    0.000 generic.py:3205(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 generic.py:3461(xs)
#         1    0.000    0.000    0.000    0.000 image.py:768(set_resample)
#         1    0.000    0.000    0.000    0.000 legend.py:598(_set_artist_props)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:859(__exit__)
#         1    0.000    0.000    0.000    0.000 managers.py:2015(_preprocess_slice_or_indexer)
#         1    0.000    0.000    0.000    0.000 __init__.py:2065(add)
#         2    0.000    0.000    0.000    0.000 _base.py:3027(set_axis_on)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:238(obj2sctype)
#         2    0.000    0.000    0.000    0.000 core.py:293(_scalar_fill_value)
#         1    0.000    0.000    0.000    0.000 _validators.py:114(_check_for_invalid_keys)
#         2    0.000    0.000    0.000    0.000 gridspec.py:77(set_height_ratios)
#         2    0.000    0.000    0.000    0.000 widgets.py:33(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_Clear}
#       3/1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:438(__getitem__)
#         1    0.000    0.000    0.001    0.001 base.py:4447(get_indexer_for)
#         2    0.000    0.000    0.000    0.000 frame.py:474(axes)
#         2    0.000    0.000    0.000    0.000 figure.py:101(<dictcomp>)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         1    0.000    0.000    0.000    0.000 __init__.py:1930(getLogger)
#         1    0.000    0.000    0.000    0.000 image.py:736(set_interpolation)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#         1    0.000    0.000    0.000    0.000 warnings.py:453(__init__)
#         1    0.000    0.000    0.000    0.000 cm.py:413(changed)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#         1    0.000    0.000    0.000    0.000 _axes.py:223(set_xlabel)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:237(set_time_limit)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         2    0.000    0.000    0.000    0.000 core.py:211(_recursive_fill_value)
#         2    0.000    0.000    0.000    0.000 gridspec.py:509(get_topmost_subplotspec)
#         1    0.000    0.000    0.000    0.000 figure.py:2034(add_axobserver)
#         1    0.000    0.000    0.000    0.000 _base.py:1783(_sci)
#         2    0.000    0.000    0.000    0.000 six.py:180(find_module)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 base.py:802(_assert_take_fillable)
#         2    0.000    0.000    0.000    0.000 transforms.py:307(x1)
#         2    0.000    0.000    0.000    0.000 transforms.py:896(x1)
#         1    0.000    0.000    0.000    0.000 image.py:910(get_extent)
#         2    0.000    0.000    0.000    0.000 figure.py:1075(fixitems)
#         1    0.000    0.000    0.000    0.000 legend.py:609(_set_loc)
#         1    0.000    0.000    0.000    0.000 types.py:164(__get__)
#         2    0.000    0.000    0.000    0.000 text.py:1044(set_fontweight)
#         2    0.000    0.000    0.000    0.000 transforms.py:317(y1)
#         1    0.000    0.000    0.000    0.000 pyplot.py:3053(sci)
#         2    0.000    0.000    0.000    0.000 offsetbox.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#         2    0.000    0.000    0.000    0.000 core.py:226(_get_dtype_of)
#         2    0.000    0.000    0.000    0.000 transforms.py:901(y1)
#         1    0.000    0.000    0.000    0.000 _validators.py:130(validate_kwargs)
#         2    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#         1    0.000    0.000    0.000    0.000 image.py:246(changed)
#         1    0.000    0.000    0.000    0.000 weakref.py:73(__eq__)
#         3    0.000    0.000    0.000    0.000 nanops.py:63(check)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 text.py:1199(set_fontproperties)
#         2    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         1    0.000    0.000    0.000    0.000 base.py:2999(_convert_arr_indexer)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#         1    0.000    0.000    0.000    0.000 nanops.py:276(_wrap_results)
#         3    0.000    0.000    0.000    0.000 base.py:4698(_validate_indexer)
#         1    0.000    0.000    0.000    0.000 base.py:1237(_get_names)
#         1    0.000    0.000    0.000    0.000 image.py:228(get_size)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.can_cast}
#         1    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         1    0.000    0.000    0.000    0.000 image.py:803(set_filterrad)
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 warnings.py:493(__exit__)
#         1    0.000    0.000    0.000    0.000 image.py:786(set_filternorm)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         2    0.000    0.000    0.000    0.000 inspect.py:2609(__init__)
#         1    0.000    0.000    0.000    0.000 core.py:306(minimum_fill_value)
#         1    0.000    0.000    0.000    0.000 _validators.py:32(_check_for_default_values)
#         2    0.000    0.000    0.000    0.000 base.py:2915(is_int)
#         1    0.000    0.000    0.000    0.000 base.py:3035(_convert_list_indexer)
#         1    0.000    0.000    0.000    0.000 indexing.py:2676(is_nested_tuple)
#         2    0.000    0.000    0.000    0.000 gridspec.py:68(set_width_ratios)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:255(SetNumThreads)
#         1    0.000    0.000    0.000    0.000 __init__.py:227(itervalues)
#         1    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 image.py:235(set_alpha)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         2    0.000    0.000    0.000    0.000 core.py:1821(_check_mask_axis)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:160(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:164(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:168(<listcomp>)
#         1    0.000    0.000    0.000    0.000 legend.py:1046(set_bbox_to_anchor)
#         2    0.000    0.000    0.000    0.000 inspect.py:2835(parameters)
#         1    0.000    0.000    0.000    0.000 _validators.py:10(_check_arg_length)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         2    0.000    0.000    0.000    0.000 legend.py:706(get_default_handler_map)
#         1    0.000    0.000    0.000    0.000 legend.py:727(get_legend_handler_map)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_set_time_limit}
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_SetNumThreads}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         2    0.000    0.000    0.000    0.000 patches.py:1927(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:5381(_ensure_has_len)
#         1    0.000    0.000    0.000    0.000 generic.py:1693(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:93(<listcomp>)
#         1    0.000    0.000    0.000    0.000 re.py:232(compile)
#         1    0.000    0.000    0.000    0.000 enum.py:628(value)
#         1    0.000    0.000    0.000    0.000 core.py:357(maximum_fill_value)
#         1    0.000    0.000    0.000    0.000 managers.py:706(nblocks)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:755(set_minimumdescent)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:94(<listcomp>)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:173(set_offset)
#         2    0.000    0.000    0.000    0.000 shape_base.py:1226(<genexpr>)
#         1    0.000    0.000    0.000    0.000 generic.py:1567(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetMinimization}
#         2    0.000    0.000    0.000    0.000 patches.py:1928(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:1627(<listcomp>)
#         1    0.000    0.000    0.000    0.000 artist.py:545(set_url)
#         1    0.000    0.000    0.000    0.000 artist.py:580(set_snap)
#         2    0.000    0.000    0.000    0.000 legend.py:675(_approx_text_height)
#         1    0.000    0.000    0.000    0.000 legend.py:958(get_frame)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#         1    0.000    0.000    0.000    0.000 indexing.py:937(_convert_for_reindex)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}

# %%
# %prun solveAndPlot(illinoisCities,M=10,Rvz=[100000,600000],truckCapacityZ=[40000,80000],alpha=0.01,fractionTruckRangeAllowed=0.6,maxTimeLimit=2*60*1000)
# Out:
# Route for vehicle 0:
#  19 -> 34 -> 31 -> 19
# Route distance: 85.498 km
#
# Route for vehicle 0:
#  33 -> 35 -> 33
# Route distance: 20.614 km
#
# Route for vehicle 0:
#  4 -> 21 -> 40 -> 29 -> 4
# Route distance: 521.061 km
#
# Route for vehicle 0:
#  30 -> 36 -> 30
# Route distance: 65.956 km
#
# Route for vehicle 0:
#  2 -> 37 -> 23 -> 13 -> 11 -> 8 -> 41 -> 45 -> 32 -> 2
# Route distance: 352.417 km
#
# Route for vehicle 0:
#  0 -> 47 -> 26 -> 12 -> 49 -> 20 -> 43 -> 5 -> 7 -> 0
# Route distance: 415.202 km
#
# Route for vehicle 0:
#  6 -> 16 -> 28 -> 27 -> 10 -> 6
# Route distance: 416.773 km
#
# Route for vehicle 0:
#  1 -> 48 -> 39 -> 46 -> 38 -> 18 -> 17 -> 14 -> 1
# Route distance: 146.998 km
#
# Route for vehicle 0:
#  25 -> 25
# Route distance: 0.0 km
#
# Route for vehicle 0:
#  3 -> 9 -> 42 -> 24 -> 15 -> 44 -> 22 -> 3
# Route distance: 391.083 km
#          6474128 function calls (6411158 primitive calls) in 128.485 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1  117.585  117.585  117.585  117.585 {built-in method ortools.linear_solver._pywraplp.Solver_Solve}
#       522    2.088    0.004    2.176    0.004 {method 'draw_path_collection' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#         1    0.500    0.500    1.177    1.177 <ipython-input-36-b849eecaab9b>:21(<listcomp>)
# 507983/507953    0.254    0.000    0.470    0.000 {built-in method builtins.getattr}
#    535004    0.240    0.000    0.481    0.000 {built-in method builtins.isinstance}
#    170100    0.204    0.000    0.400    0.000 pywraplp.py:419(__getattr__)
#       918    0.186    0.000    0.186    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
# 68985/68427    0.178    0.000    0.538    0.000 {built-in method numpy.array}
#      5865    0.138    0.000    0.243    0.000 coords.py:124(array_interface)
#     17600    0.130    0.000    0.237    0.000 linear_solver_natural_api.py:119(__rmul__)
#     19208    0.116    0.000    0.116    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    105995    0.098    0.000    0.125    0.000 __init__.py:810(__getitem__)
#      2751    0.098    0.000    0.247    0.000 linear_solver_natural_api.py:95(GetCoeffs)
# 109580/92463    0.093    0.000    0.137    0.000 artist.py:219(stale)
#    168281    0.093    0.000    0.116    0.000 generic.py:7(_check)
#       352    0.089    0.000    0.091    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#    132805    0.086    0.000    0.088    0.000 {built-in method _abc._abc_instancecheck}
#     29985    0.085    0.000    0.091    0.000 coords.py:44(_update)
#     23720    0.079    0.000    0.149    0.000 coords.py:48(__len__)
#     26335    0.078    0.000    0.111    0.000 predicates.py:23(__call__)
#    192800    0.073    0.000    0.073    0.000 linear_solver_natural_api.py:164(__init__)
#      5079    0.067    0.000    1.050    0.000 series.py:152(__init__)
#      7648    0.060    0.000    0.105    0.000 polygon.py:183(_get_ring)
#      1686    0.060    0.000    0.452    0.000 lines.py:273(__init__)
#    132805    0.056    0.000    0.143    0.000 abc.py:137(__instancecheck__)
#      5465    0.054    0.000    0.082    0.000 artist.py:74(__init__)
#      3974    0.054    0.000    0.094    0.000 cycler.py:349(by_key)
#     26335    0.054    0.000    0.180    0.000 base.py:640(is_empty)
#     36114    0.052    0.000    0.109    0.000 common.py:1845(_is_dtype_type)
#      5795    0.052    0.000    0.219    0.000 patch.py:33(coding)
#     60501    0.051    0.000    0.088    0.000 {built-in method builtins.hasattr}
#     16007    0.049    0.000    0.248    0.000 colors.py:149(to_rgba)
#      2112    0.048    0.000    0.498    0.000 text.py:655(draw)
#      6978    0.047    0.000    0.047    0.000 {built-in method numpy.dot}
#        32    0.046    0.001    0.046    0.001 {method 'clear' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
# 136150/113970    0.045    0.000    0.136    0.000 {built-in method builtins.len}
#      9523    0.044    0.000    0.044    0.000 {built-in method numpy.concatenate}
#      2496    0.044    0.000    0.328    0.000 lines.py:751(draw)
#      3152    0.044    0.000    0.069    0.000 {pandas._libs.lib.infer_dtype}
#     70900    0.043    0.000    0.163    0.000 linear_solver_natural_api.py:52(CastToLinExp)
#       528    0.042    0.000    0.922    0.002 ticker.py:2016(_raw_ticks)
#     37137    0.041    0.000    0.178    0.000 base.py:75(is_dtype)
#      1394    0.041    0.000    0.152    0.000 lines.py:667(recache)
#     15451    0.039    0.000    0.047    0.000 linear_solver_natural_api.py:214(AddSelfToCoeffMapOrStack)
#     12430    0.039    0.000    0.130    0.000 fromnumeric.py:69(_wrapreduction)
#     22900    0.039    0.000    0.132    0.000 linear_solver_natural_api.py:174(__init__)
#       838    0.039    0.000    0.045    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      4441    0.039    0.000    0.531    0.000 construction.py:537(sanitize_array)
#     22700    0.037    0.000    0.350    0.000 pywraplp.py:569(<lambda>)
#     13290    0.037    0.000    0.088    0.000 dtypes.py:68(find)
#     11570    0.035    0.000    0.035    0.000 base.py:67(geometry_type_name)
#     35148    0.034    0.000    0.034    0.000 linear_solver_natural_api.py:167(AddSelfToCoeffMapOrStack)
#      2750    0.034    0.000    0.242    0.000 linear_solver_natural_api.py:251(Extract)
#     73600    0.034    0.000    0.034    0.000 path.py:197(vertices)
#      2834    0.033    0.000    0.066    0.000 topology.py:44(__call__)
#      9052    0.033    0.000    0.075    0.000 _dtype.py:319(_name_get)
#      4924    0.032    0.000    0.165    0.000 cast.py:953(maybe_cast_to_datetime)
#   7110/32    0.032    0.000    4.932    0.154 artist.py:30(draw_wrapper)
#      4594    0.031    0.000    0.203    0.000 blocks.py:3034(get_block_type)
#     15451    0.030    0.000    0.131    0.000 linear_solver_natural_api.py:209(<listcomp>)
#      9227    0.029    0.000    0.048    0.000 {pandas._libs.lib.is_scalar}
#      8563    0.029    0.000    0.058    0.000 generic.py:5069(__setattr__)
#      5844    0.029    0.000    0.194    0.000 base.py:4342(get_value)
#     15451    0.027    0.000    0.158    0.000 linear_solver_natural_api.py:208(__init__)
#    105998    0.027    0.000    0.027    0.000 {function RcParams.__getitem__ at 0x000001D4E5472158}
#      3942    0.027    0.000    0.068    0.000 polygon.py:246(exterior)
#     11331    0.026    0.000    0.325    0.000 generic.py:5053(__getattr__)
#    140306    0.026    0.000    0.026    0.000 base.py:253(_geom)
#     18579    0.025    0.000    0.074    0.000 common.py:131(is_object_dtype)
#      7414    0.025    0.000    0.025    0.000 {built-in method numpy.empty}
#       864    0.024    0.000    0.028    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1983    0.024    0.000    0.349    0.000 patches.py:42(__init__)
#      3787    0.024    0.000    0.059    0.000 cast.py:832(maybe_castable)
#    114687    0.024    0.000    0.024    0.000 {built-in method builtins.issubclass}
#     17121    0.024    0.000    0.024    0.000 {method 'match' of 're.Pattern' objects}
#       864    0.024    0.000    0.024    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#      5844    0.024    0.000    0.311    0.000 series.py:865(__getitem__)
#     32003    0.023    0.000    0.052    0.000 topology.py:16(_validate)
#      8511    0.023    0.000    0.023    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     19025    0.023    0.000    0.040    0.000 transforms.py:1683(__init__)
#      3634    0.023    0.000    0.088    0.000 path.py:96(__init__)
#     43718    0.023    0.000    0.023    0.000 cycler.py:227(<genexpr>)
#        11    0.022    0.002    1.114    0.101 <ipython-input-3-a4e7a57e50e3>:1(buildDistanceMatrix_Euclidean)
#      4411    0.022    0.000    0.354    0.000 construction.py:684(_try_cast)
#      5330    0.022    0.000    0.035    0.000 font_manager.py:660(__hash__)
#       264    0.022    0.000    1.289    0.005 axis.py:1074(_update_ticks)
#    110748    0.022    0.000    0.022    0.000 artist.py:774(get_animated)
#     24496    0.022    0.000    0.022    0.000 transforms.py:82(__init__)
#     73499    0.022    0.000    0.022    0.000 {method 'pop' of 'list' objects}
#         1    0.022    0.022  120.415  120.415 <ipython-input-36-b849eecaab9b>:1(assignFacilitiesAndCluster)
#       562    0.022    0.000    0.854    0.002 axis.py:56(__init__)
#     27009    0.022    0.000    0.060    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#      9400    0.022    0.000    0.046    0.000 common.py:160(is_sparse)
#      3048    0.021    0.000    0.099    0.000 artist.py:942(update)
#     16018    0.021    0.000    0.029    0.000 re.py:271(_compile)
#      1712    0.021    0.000    0.040    0.000 transforms.py:671(translated)
#      2576    0.020    0.000    0.060    0.000 backend_bases.py:718(__init__)
#       528    0.020    0.000    0.070    0.000 ticker.py:764(_set_format)
#      5079    0.020    0.000    0.294    0.000 managers.py:1443(__init__)
#      5690    0.020    0.000    0.049    0.000 blocks.py:78(__init__)
#     11984    0.020    0.000    0.027    0.000 {method 'format' of 'str' objects}
#      1971    0.020    0.000    0.586    0.000 patch.py:63(<listcomp>)
#     15533    0.020    0.000    0.050    0.000 inference.py:253(is_list_like)
#    121282    0.020    0.000    0.020    0.000 {method 'append' of 'list' objects}
#     12015    0.020    0.000    0.061    0.000 common.py:1981(pandas_dtype)
#     22900    0.020    0.000    0.024    0.000 linear_solver_natural_api.py:187(AddSelfToCoeffMapOrStack)
#     16007    0.020    0.000    0.088    0.000 colors.py:115(_is_nth_color)
# 31235/30688    0.019    0.000    0.495    0.000 numeric.py:469(asarray)
#      1936    0.019    0.000    0.228    0.000 text.py:852(get_window_extent)
#        32    0.019    0.001    0.021    0.001 {built-in method matplotlib._path.get_path_collection_extents}
#     12456    0.019    0.000    0.078    0.000 common.py:1702(is_extension_array_dtype)
#      3634    0.019    0.000    0.046    0.000 path.py:188(_update_values)
#       864    0.018    0.000    0.319    0.000 backend_agg.py:164(draw_text)
#     11590    0.018    0.000    0.123    0.000 polygon.py:139(__next__)
#      2964    0.018    0.000    0.073    0.000 cast.py:846(maybe_infer_to_datetimelike)
# 3912/3234    0.018    0.000    0.067    0.000 transforms.py:2395(get_affine)
#     20250    0.018    0.000    0.018    0.000 {built-in method ortools.linear_solver._pywraplp.Constraint_SetCoefficient}
#      9052    0.017    0.000    0.043    0.000 numerictypes.py:365(issubdtype)
#     70455    0.017    0.000    0.017    0.000 path.py:211(codes)
#      5844    0.017    0.000    0.026    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#      5690    0.017    0.000    0.278    0.000 blocks.py:3080(make_block)
#      6800    0.017    0.000    0.024    0.000 __init__.py:2012(_setattr_cm)
#      4287    0.017    0.000    0.019    0.000 transforms.py:164(set_children)
#     18104    0.017    0.000    0.024    0.000 numerictypes.py:293(issubclass_)
#     12476    0.017    0.000    0.024    0.000 base.py:257(_geom)
#      5795    0.016    0.000    0.016    0.000 {built-in method numpy.copyto}
#      5753    0.016    0.000    0.019    0.000 blocks.py:199(mgr_locs)
#     12060    0.016    0.000    0.098    0.000 base.py:320(_get_coords)
#      1856    0.016    0.000    0.016    0.000 {method 'round' of 'numpy.ndarray' objects}
#      4648    0.016    0.000    0.018    0.000 contextlib.py:81(__init__)
#      1971    0.016    0.000    1.083    0.001 patch.py:29(PolygonPath)
#     16017    0.016    0.000    0.066    0.000 re.py:170(match)
#      1971    0.016    0.000    0.299    0.000 patch.py:64(<listcomp>)
#      2576    0.016    0.000    0.085    0.000 text.py:270(_get_layout)
#      1968    0.015    0.000    0.015    0.000 transforms.py:2867(_interval_contains_close)
#       528    0.015    0.000    0.038    0.000 ticker.py:688(_compute_offset)
#     15488    0.015    0.000    0.018    0.000 __init__.py:2151(_check_in_list)
#      7648    0.015    0.000    0.015    0.000 {built-in method builtins.repr}
#      1968    0.015    0.000    0.024    0.000 ticker.py:576(__call__)
#      2750    0.015    0.000    0.015    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_Constraint}
#     25022    0.015    0.000    0.015    0.000 base.py:222(empty)
#      1971    0.015    0.000    0.382    0.000 patch.py:67(<listcomp>)
# 29422/25010    0.014    0.000    0.041    0.000 {built-in method builtins.hash}
#       632    0.014    0.000    0.343    0.001 ops.py:1660(wrapper)
#      8442    0.014    0.000    0.037    0.000 transforms.py:1819(__init__)
#         1    0.014    0.014  128.558  128.558 <ipython-input-8-52f7402de033>:1(solveAndPlot)
#      3021    0.014    0.000    0.037    0.000 transforms.py:726(__init__)
#     13053    0.014    0.000    0.041    0.000 {pandas._libs.lib.values_from_object}
#      5079    0.014    0.000    0.018    0.000 series.py:354(_set_axis)
#      1189    0.013    0.000    0.015    0.000 font_manager.py:776(set_weight)
#      1187    0.013    0.000    0.066    0.000 font_manager.py:620(__init__)
#        10    0.013    0.001    0.023    0.002 {built-in method ortools.constraint_solver._pywrapcp.RoutingModel_SolveWithParameters}
#       528    0.013    0.000    2.259    0.004 collections.py:249(draw)
#       180    0.013    0.000    0.013    0.000 {method 'acquire' of '_thread.lock' objects}
#      3977    0.013    0.000    0.047    0.000 patches.py:277(_set_edgecolor)
#      1394    0.013    0.000    0.013    0.000 stride_tricks.py:185(_broadcast_shape)
#      7668    0.013    0.000    0.037    0.000 __init__.py:1382(_to_unmasked_float_array)
#      5543    0.013    0.000    0.040    0.000 dtypes.py:973(is_dtype)
#      5274    0.013    0.000    0.013    0.000 generic.py:127(__init__)
#     15279    0.013    0.000    0.084    0.000 common.py:434(is_datetime64tz_dtype)
#       726    0.012    0.000    0.017    0.000 transforms.py:2791(nonsingular)
#     21120    0.012    0.000    0.016    0.000 base.py:652(__len__)
#     69083    0.012    0.000    0.012    0.000 path.py:251(should_simplify)
#      2576    0.012    0.000    0.051    0.000 text.py:823(get_prop_tup)
#     11296    0.012    0.000    0.032    0.000 series.py:406(dtype)
#     30874    0.012    0.000    0.018    0.000 common.py:119(<lambda>)
#      5865    0.012    0.000    0.341    0.000 linestring.py:84(array_interface)
# 11000/5809    0.012    0.000    0.015    0.000 transforms.py:2357(<lambda>)
#     29169    0.012    0.000    0.012    0.000 impl.py:56(__getitem__)
#      1686    0.012    0.000    0.027    0.000 lines.py:1145(set_linestyle)
#     69083    0.012    0.000    0.012    0.000 path.py:230(simplify_threshold)
#      1149    0.012    0.000    0.081    0.000 text.py:121(__init__)
#      3654    0.012    0.000    0.012    0.000 {built-in method matplotlib._path.affine_transform}
#      5845    0.012    0.000    0.031    0.000 base.py:2849(_convert_scalar_indexer)
#      6572    0.011    0.000    0.015    0.000 base.py:3918(__contains__)
# 3962/2656    0.011    0.000    0.013    0.000 transforms.py:137(_invalidate_internal)
#     30874    0.011    0.000    0.011    0.000 common.py:117(classes)
#       528    0.011    0.000    0.018    0.000 ticker.py:727(_set_order_of_magnitude)
#     12476    0.011    0.000    0.019    0.000 base.py:233(__del__)
#      3045    0.011    0.000    0.703    0.000 frame.py:797(iterrows)
#      2532    0.011    0.000    0.025    0.000 numeric.py:2656(seterr)
#     11296    0.011    0.000    0.019    0.000 managers.py:1522(dtype)
#      6739    0.011    0.000    0.020    0.000 series.py:392(name)
#      1446    0.011    0.000    0.029    0.000 shape_base.py:599(column_stack)
#     13093    0.011    0.000    0.013    0.000 artist.py:338(pchanged)
#       472    0.011    0.000    0.011    0.000 {pandas._libs.ops.scalar_compare}
#      9644    0.011    0.000    0.018    0.000 managers.py:1549(internal_values)
#     20250    0.011    0.000    0.028    0.000 pywraplp.py:458(SetCoefficient)
#     12600    0.011    0.000    0.106    0.000 linear_solver_natural_api.py:223(Sum)
#      5771    0.011    0.000    0.035    0.000 dtypes.py:827(is_dtype)
#       832    0.011    0.000    0.839    0.001 axis.py:289(draw)
#      2828    0.011    0.000    0.108    0.000 transforms.py:1377(transform)
#      1728    0.011    0.000    0.011    0.000 {method 'round' of 'numpy.generic' objects}
#      3977    0.010    0.000    0.177    0.000 patches.py:303(_set_facecolor)
#      1772    0.010    0.000    0.083    0.000 markers.py:292(set_marker)
#      8551    0.010    0.000    0.044    0.000 artist.py:49(_stale_axes_callback)
#      4512    0.010    0.000    0.026    0.000 text.py:809(get_unitless_position)
#      6476    0.010    0.000    0.026    0.000 managers.py:1556(get_values)
#     27752    0.010    0.000    0.010    0.000 managers.py:1488(_block)
#     51931    0.010    0.000    0.010    0.000 {method 'items' of 'dict' objects}
#     10783    0.010    0.000    0.067    0.000 common.py:572(is_categorical_dtype)
#        80    0.010    0.000    0.010    0.000 socket.py:337(send)
#      2760    0.010    0.000    0.128    0.000 transforms.py:1470(transform_point)
#     11570    0.010    0.000    0.047    0.000 base.py:347(geometryType)
#      3819    0.009    0.000    0.040    0.000 blocks.py:2626(__init__)
#     42170    0.009    0.000    0.009    0.000 artist.py:194(axes)
#   351/317    0.009    0.000    0.051    0.000 base.py:253(__new__)
# 3604/3602    0.009    0.000    0.024    0.000 transforms.py:1776(transform_affine)
#     12430    0.009    0.000    0.009    0.000 fromnumeric.py:70(<dictcomp>)
#      8566    0.009    0.000    0.017    0.000 figure.py:49(_stale_figure_callback)
#      1971    0.009    0.000    0.206    0.000 patch.py:68(<listcomp>)
#      2532    0.009    0.000    0.010    0.000 numeric.py:2758(geterr)
#       918    0.009    0.000    0.037    0.000 font_manager.py:1179(findfont)
#      2021    0.009    0.000    0.053    0.000 transforms.py:1976(scale)
#      4648    0.009    0.000    0.022    0.000 contextlib.py:116(__exit__)
#     11590    0.009    0.000    0.009    0.000 polygon.py:31(__init__)
#      6320    0.009    0.000    0.042    0.000 common.py:403(is_datetime64_dtype)
#      1394    0.009    0.000    0.030    0.000 stride_tricks.py:208(broadcast_arrays)
#       218    0.009    0.000    0.017    0.000 managers.py:186(_rebuild_blknos_and_blklocs)
#      9813    0.009    0.000    0.060    0.000 {built-in method builtins.next}
#      4863    0.009    0.000    0.020    0.000 common.py:868(is_integer_dtype)
#      1937    0.008    0.000    0.009    0.000 {built-in method builtins.sorted}
#      5795    0.008    0.000    0.043    0.000 numeric.py:175(ones)
#      3942    0.008    0.000    0.008    0.000 polygon.py:150(__len__)
#       264    0.008    0.000    0.430    0.002 axis.py:2179(get_tick_space)
#      8832    0.008    0.000    0.022    0.000 integer.py:80(construct_from_string)
#       486    0.008    0.000    0.054    0.000 algorithms.py:1544(take_nd)
#      3372    0.008    0.000    0.014    0.000 lines.py:1112(_split_drawstyle_linestyle)
#         1    0.008    0.008    0.008    0.008 backend_agg.py:80(__init__)
# 2256/2248    0.008    0.000    0.012    0.000 spines.py:487(get_spine_transform)
#       340    0.008    0.000    0.012    0.000 collections.py:839(set_sizes)
#      2834    0.008    0.000    0.075    0.000 base.py:434(distance)
#      7442    0.008    0.000    0.016    0.000 lines.py:59(_scale_dashes)
#      9644    0.008    0.000    0.025    0.000 series.py:476(_values)
#      8547    0.008    0.000    0.070    0.000 common.py:262(is_categorical)
#       704    0.008    0.000    0.023    0.000 patches.py:504(_bind_draw_path_function)
#      4667    0.008    0.000    0.045    0.000 fromnumeric.py:54(_wrapfunc)
#      3736    0.008    0.000    0.061    0.000 fromnumeric.py:2083(any)
#      4648    0.008    0.000    0.026    0.000 contextlib.py:237(helper)
#       264    0.008    0.000    0.406    0.002 axis.py:2486(get_tick_space)
#      3544    0.008    0.000    0.061    0.000 markers.py:245(_recache)
#     23180    0.008    0.000    0.008    0.000 {method 'startswith' of 'str' objects}
#     27354    0.007    0.000    0.007    0.000 {built-in method _ctypes.byref}
#      7648    0.007    0.000    0.025    0.000 polygon.py:180(gtag)
#      7806    0.007    0.000    0.011    0.000 {method 'view' of 'numpy.ndarray' objects}
#      1395    0.007    0.000    0.026    0.000 axis.py:617(update_position)
#     10000    0.007    0.000    0.093    0.000 linear_solver_natural_api.py:104(__add__)
#     26335    0.007    0.000    0.007    0.000 geos.py:545(errcheck_predicate)
#      5718    0.007    0.000    0.044    0.000 base.py:3975(_can_hold_identifiers_and_holds_name)
#      1983    0.007    0.000    0.017    0.000 patches.py:375(set_linestyle)
#      6719    0.007    0.000    0.012    0.000 artist.py:373(get_transform)
#      2700    0.007    0.000    0.052    0.000 linear_solver_natural_api.py:143(__le__)
#      3004    0.007    0.000    0.035    0.000 transforms.py:1748(frozen)
#       430    0.007    0.000    0.009    0.000 numerictypes.py:578(_can_coerce_all)
#      5572    0.007    0.000    0.010    0.000 series.py:399(name)
#     16559    0.007    0.000    0.007    0.000 {method 'pop' of 'dict' objects}
#      1189    0.007    0.000    0.009    0.000 font_manager.py:812(set_size)
#      5091    0.007    0.000    0.012    0.000 lines.py:1282(set_xdata)
#       624    0.007    0.000    0.224    0.000 base.py:103(_unary_op)
#      3721    0.006    0.000    0.008    0.000 lines.py:31(_get_dash_pattern)
#      5771    0.006    0.000    0.042    0.000 common.py:503(is_period_dtype)
#      4648    0.006    0.000    0.050    0.000 contextlib.py:107(__enter__)
#      4372    0.006    0.000    0.027    0.000 transforms.py:2470(composite_transform_factory)
#      3953    0.006    0.000    0.080    0.000 common.py:1643(is_extension_type)
#      3503    0.006    0.000    0.013    0.000 artist.py:673(set_figure)
#      1864    0.006    0.000    0.007    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      1135    0.006    0.000    0.027    0.000 axis.py:500(update_position)
#      3942    0.006    0.000    0.040    0.000 polygon.py:260(interiors)
#       128    0.006    0.000    2.404    0.019 axis.py:1195(draw)
#      1971    0.006    0.000    1.440    0.001 patch.py:73(PolygonPatch)
#      3428    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       528    0.006    0.000    0.007    0.000 ticker.py:1828(scale_range)
#      2052    0.006    0.000    0.015    0.000 path.py:159(_fast_from_codes_and_verts)
#      1227    0.006    0.000    0.006    0.000 {built-in method numpy.arange}
#      2828    0.006    0.000    0.075    0.000 transforms.py:2371(transform_affine)
#       352    0.006    0.000    0.161    0.000 patches.py:563(draw)
#       264    0.005    0.000    0.472    0.002 axis.py:1326(get_minorticklocs)
#      5782    0.005    0.000    0.046    0.000 common.py:536(is_interval_dtype)
#       787    0.005    0.000    0.034    0.000 base.py:1117(__iter__)
#      3756    0.005    0.000    0.010    0.000 <ipython-input-7-e2210c2c3aae>:57(distance_callback)
#     13371    0.005    0.000    0.005    0.000 blocks.py:308(dtype)
#       891    0.005    0.000    0.006    0.000 text.py:41(get_rotation)
#      5718    0.005    0.000    0.027    0.000 base.py:1681(is_object)
#      1761    0.005    0.000    0.018    0.000 artist.py:946(_update_property)
#       400    0.005    0.000    0.014    0.000 coords.py:69(__getitem__)
#      3728    0.005    0.000    0.036    0.000 fromnumeric.py:2512(amin)
#      1138    0.005    0.000    0.009    0.000 dtypes.py:786(construct_from_string)
#      5508    0.005    0.000    0.010    0.000 font_manager.py:1233(<genexpr>)
#      1686    0.005    0.000    0.010    0.000 lines.py:1398(set_dash_capstyle)
#      2656    0.005    0.000    0.018    0.000 transforms.py:126(invalidate)
#      2526    0.005    0.000    0.049    0.000 patches.py:209(get_transform)
#      1220    0.005    0.000    0.021    0.000 transforms.py:1506(transform_path_non_affine)
#       346    0.005    0.000    0.016    0.000 missing.py:183(_isna_ndarraylike)
#      5871    0.005    0.000    0.010    0.000 lines.py:1294(set_ydata)
#       510    0.005    0.000    0.211    0.000 frame.py:2893(__getitem__)
#       632    0.005    0.000    0.040    0.000 ops.py:1615(na_op)
#      1522    0.005    0.000    0.013    0.000 transforms.py:2299(__init__)
#      6713    0.005    0.000    0.014    0.000 artist.py:170(convert_xunits)
#      1187    0.005    0.000    0.006    0.000 font_manager.py:794(set_stretch)
#      3794    0.005    0.000    0.033    0.000 fromnumeric.py:2397(amax)
#       264    0.005    0.000    0.211    0.001 axis.py:1149(<listcomp>)
#     10374    0.005    0.000    0.005    0.000 transforms.py:946(get_points)
#       528    0.005    0.000    0.010    0.000 _methods.py:151(_ptp)
#      4060    0.005    0.000    0.026    0.000 common.py:472(is_timedelta64_dtype)
#      2750    0.005    0.000    0.248    0.000 pywraplp.py:258(Add)
#      5523    0.005    0.000    0.005    0.000 {built-in method builtins.max}
#      1128    0.005    0.000    0.013    0.000 transforms.py:2654(__init__)
#      8031    0.005    0.000    0.005    0.000 {built-in method __new__ of type object at 0x00007FFF42D56BA0}
#      4441    0.005    0.000    0.023    0.000 arrays.py:7(extract_array)
#      6476    0.005    0.000    0.010    0.000 blocks.py:184(to_dense)
#      3584    0.005    0.000    0.037    0.000 fromnumeric.py:2940(around)
#     12060    0.005    0.000    0.005    0.000 coords.py:41(__init__)
#      5465    0.005    0.000    0.008    0.000 <string>:1(__new__)
#     11791    0.005    0.000    0.005    0.000 {built-in method builtins.iter}
#     14220    0.005    0.000    0.005    0.000 artist.py:858(get_agg_filter)
#       528    0.005    0.000    0.130    0.000 ticker.py:677(set_locs)
#       111    0.005    0.000    0.028    0.000 managers.py:772(_interleave)
#      2576    0.005    0.000    0.006    0.000 artist.py:828(_set_gc_clip)
#      1686    0.005    0.000    0.042    0.000 lines.py:1241(set_markerfacecolor)
#       528    0.004    0.000    0.941    0.002 ticker.py:2080(tick_values)
#       313    0.004    0.000    0.058    0.000 series.py:3600(_reduce)
#      6476    0.004    0.000    0.031    0.000 series.py:490(get_values)
#     17905    0.004    0.000    0.004    0.000 {method 'lower' of 'str' objects}
#      5690    0.004    0.000    0.004    0.000 blocks.py:89(_check_ndim)
#      3942    0.004    0.000    0.005    0.000 polygon.py:129(__init__)
#      2600    0.004    0.000    0.004    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_IntVar}
#      1993    0.004    0.000    0.010    0.000 patches.py:355(set_linewidth)
#      6837    0.004    0.000    0.010    0.000 artist.py:182(convert_yunits)
#     10975    0.004    0.000    0.004    0.000 transforms.py:1857(get_matrix)
#       918    0.004    0.000    0.049    0.000 backend_agg.py:241(_get_agg_font)
#      1686    0.004    0.000    0.009    0.000 lines.py:1095(set_linewidth)
#      3978    0.004    0.000    0.005    0.000 cycler.py:225(__iter__)
#      1211    0.004    0.000    0.033    0.000 text.py:170(update)
#      7059    0.004    0.000    0.015    0.000 numeric.py:541(asanyarray)
#      5449    0.004    0.000    0.007    0.000 base.py:5318(ensure_index)
#      7318    0.004    0.000    0.031    0.000 base.py:421(geom_type)
#      2176    0.004    0.000    0.015    0.000 axis.py:1881(getter)
#        64    0.004    0.000    0.052    0.001 _base.py:2425(handle_single_axis)
#       528    0.004    0.000    0.949    0.002 ticker.py:2076(__call__)
#        50    0.004    0.000    0.004    0.000 <ipython-input-36-b849eecaab9b>:39(<listcomp>)
#      1754    0.004    0.000    0.019    0.000 transforms.py:362(ymax)
#      1983    0.004    0.000    0.107    0.000 patches.py:409(set_fill)
#      4144    0.004    0.000    0.006    0.000 function_base.py:258(iterable)
#       528    0.004    0.000    0.018    0.000 collections.py:212(_prepare_points)
#     11742    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#      3852    0.004    0.000    0.024    0.000 transforms.py:1236(__add__)
#      2894    0.004    0.000    0.010    0.000 artist.py:360(set_transform)
#       406    0.004    0.000    0.031    0.000 managers.py:318(apply)
#      2828    0.004    0.000    0.014    0.000 transforms.py:2375(transform_non_affine)
#      3926    0.004    0.000    0.009    0.000 cast.py:1218(construct_1d_ndarray_preserving_na)
#      1579    0.004    0.000    0.008    0.000 dtypes.py:672(construct_from_string)
#      2496    0.004    0.000    0.010    0.000 lines.py:953(_get_markerfacecolor)
#       486    0.004    0.000    0.011    0.000 algorithms.py:1417(_get_take_nd_function)
#      2823    0.004    0.000    0.005    0.000 range.py:510(__len__)
#        10    0.004    0.000    0.687    0.069 <ipython-input-6-4ad955854af3>:1(convertTourToPathDF)
#      1495    0.004    0.000    0.006    0.000 __init__.py:1373(is_math_text)
#       278    0.004    0.000    0.090    0.000 transforms.py:697(union)
#      2100    0.004    0.000    0.010    0.000 ticker.py:567(fix_minus)
#      1846    0.004    0.000    0.008    0.000 geodataframe.py:60(__setattr__)
#      5079    0.004    0.000    0.004    0.000 series.py:382(_set_subtyp)
#     13600    0.004    0.000    0.004    0.000 artist.py:770(get_visible)
#       832    0.004    0.000    0.026    0.000 transforms.py:2710(_revalidate)
#      6074    0.004    0.000    0.007    0.000 generic.py:426(_info_axis)
#       140    0.004    0.000    0.005    0.000 __init__.py:1673(normalize_kwargs)
#       279    0.004    0.000    0.060    0.000 axis.py:425(_get_text1)
#     14220    0.004    0.000    0.004    0.000 artist.py:838(get_rasterized)
#      6717    0.004    0.000    0.005    0.000 common.py:316(apply_if_callable)
#      2500    0.004    0.000    0.004    0.000 <ipython-input-36-b849eecaab9b>:35(<listcomp>)
#      1686    0.004    0.000    0.007    0.000 lines.py:1352(set_dash_joinstyle)
#      1971    0.004    0.000    0.351    0.000 patches.py:942(__init__)
#       279    0.004    0.000    0.102    0.000 axis.py:458(_get_tick1line)
#      1511    0.004    0.000    0.005    0.000 transforms.py:377(intervalx)
#      1686    0.004    0.000    0.012    0.000 lines.py:648(set_data)
#      3942    0.004    0.000    0.012    0.000 polygon.py:134(__iter__)
#      1772    0.004    0.000    0.093    0.000 markers.py:223(__init__)
#         1    0.004    0.004    0.009    0.009 <ipython-input-36-b849eecaab9b>:18(<dictcomp>)
#        32    0.004    0.000    6.928    0.216 plotting.py:214(plot_series)
#      3458    0.004    0.000    0.005    0.000 __init__.py:1916(_str_lower_equal)
#      2600    0.004    0.000    0.039    0.000 linear_solver_natural_api.py:110(__sub__)
#       264    0.004    0.000    0.005    0.000 spines.py:254(_adjust_location)
#      7704    0.004    0.000    0.004    0.000 {method 'update' of 'dict' objects}
#   335/334    0.004    0.000    0.006    0.000 transforms.py:413(bounds)
#      1686    0.004    0.000    0.007    0.000 lines.py:1061(set_drawstyle)
#      6082    0.004    0.000    0.004    0.000 artist.py:199(axes)
#      1484    0.003    0.000    0.020    0.000 transforms.py:347(xmin)
#       485    0.003    0.000    0.013    0.000 cast.py:255(maybe_promote)
#       528    0.003    0.000    0.028    0.000 ticker.py:259(<listcomp>)
#      7948    0.003    0.000    0.003    0.000 cycler.py:371(<genexpr>)
#      1187    0.003    0.000    0.006    0.000 font_manager.py:757(set_style)
#      2750    0.003    0.000    0.006    0.000 six.py:588(iteritems)
#      3978    0.003    0.000    0.003    0.000 cycler.py:138(keys)
#       283    0.003    0.000    0.059    0.000 axis.py:543(_get_text1)
#        68    0.003    0.000    0.043    0.001 _base.py:2503(_update_title_position)
#       283    0.003    0.000    0.096    0.000 axis.py:573(_get_tick1line)
#      3400    0.003    0.000    0.005    0.000 __init__.py:2017(<listcomp>)
#       510    0.003    0.000    0.221    0.000 geodataframe.py:465(__getitem__)
#        80    0.003    0.000    0.016    0.000 managers.py:868(fast_xs)
#       279    0.003    0.000    0.102    0.000 axis.py:484(_get_gridline)
#      1772    0.003    0.000    0.006    0.000 markers.py:267(set_fillstyle)
#        10    0.003    0.000    0.003    0.000 {built-in method ortools.constraint_solver._pywrapcp.new_RoutingModel}
#      3584    0.003    0.000    0.041    0.000 fromnumeric.py:3373(round_)
#      5500    0.003    0.000    0.005    0.000 pywraplp.py:215(infinity)
#      4736    0.003    0.000    0.004    0.000 common.py:1809(_get_dtype)
# 2551/1415    0.003    0.000    0.009    0.000 _base.py:736(get_yaxis_transform)
#      5195    0.003    0.000    0.003    0.000 transforms.py:1671(<lambda>)
#       192    0.003    0.000    0.027    0.000 generic.py:5948(fillna)
#      1688    0.003    0.000    0.017    0.000 transforms.py:352(ymin)
#      1991    0.003    0.000    0.005    0.000 patches.py:431(set_capstyle)
#      5798    0.003    0.000    0.006    0.000 transforms.py:178(<lambda>)
#      2810    0.003    0.000    0.013    0.000 axis.py:325(_set_artist_props)
# 2515/1395    0.003    0.000    0.008    0.000 _base.py:660(get_xaxis_transform)
#   520/260    0.003    0.000    0.032    0.000 transforms.py:2320(frozen)
#      2851    0.003    0.000    0.067    0.000 pywraplp.py:267(Sum)
#       162    0.003    0.000    0.006    0.000 indexing.py:2575(maybe_convert_indices)
#       283    0.003    0.000    0.101    0.000 axis.py:602(_get_gridline)
#      4294    0.003    0.000    0.004    0.000 inference.py:438(is_hashable)
#      2750    0.003    0.000    0.018    0.000 pywraplp.py:170(Constraint)
#      3942    0.003    0.000    0.047    0.000 patch.py:21(interiors)
#      2576    0.003    0.000    0.064    0.000 backend_bases.py:654(new_gc)
#      3152    0.003    0.000    0.012    0.000 transforms.py:2047(transform)
#       918    0.003    0.000    0.003    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#      1686    0.003    0.000    0.025    0.000 lines.py:1255(set_markerfacecoloralt)
#      1511    0.003    0.000    0.004    0.000 transforms.py:386(intervaly)
#      1358    0.003    0.000    0.012    0.000 common.py:1578(is_bool_dtype)
#      2944    0.003    0.000    0.003    0.000 {pandas._libs.lib.infer_datetimelike_array}
#      2102    0.003    0.000    0.003    0.000 dtypes.py:452(construct_from_string)
#      1686    0.003    0.000    0.007    0.000 lines.py:1412(set_solid_capstyle)
#       313    0.003    0.000    0.035    0.000 nanops.py:203(_get_values)
# 3472/3470    0.003    0.000    0.026    0.000 transforms.py:1696(transform)
#      2432    0.003    0.000    0.010    0.000 {built-in method builtins.all}
#      5240    0.003    0.000    0.004    0.000 common.py:127(<lambda>)
#      3764    0.003    0.000    0.010    0.000 transforms.py:2181(get_affine)
#      3942    0.003    0.000    0.075    0.000 patch.py:16(exterior)
#      1162    0.003    0.000    0.006    0.000 text.py:1122(set_verticalalignment)
#      1138    0.003    0.000    0.005    0.000 dtypes.py:929(construct_from_string)
#      1686    0.003    0.000    0.006    0.000 lines.py:1367(set_solid_joinstyle)
#      1686    0.003    0.000    0.010    0.000 lines.py:733(set_transform)
#      1484    0.003    0.000    0.015    0.000 transforms.py:357(xmax)
#      1567    0.003    0.000    0.005    0.000 shape_base.py:220(_warn_for_nonsequence)
#       283    0.003    0.000    0.082    0.000 axis.py:588(_get_tick2line)
#      2907    0.003    0.000    0.008    0.000 artist.py:905(set_visible)
#      4567    0.003    0.000    0.004    0.000 __init__.py:1906(_str_equal)
#       162    0.003    0.000    0.135    0.001 managers.py:1329(take)
#       624    0.003    0.000    0.033    0.000 base.py:106(<listcomp>)
#       161    0.003    0.000    0.003    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#      8623    0.003    0.000    0.003    0.000 blocks.py:195(mgr_locs)
#       279    0.003    0.000    0.082    0.000 axis.py:469(_get_tick2line)
#        32    0.003    0.000    0.049    0.002 plotting.py:8(_flatten_multi_geoms)
#      2532    0.003    0.000    0.003    0.000 {built-in method numpy.seterrobj}
#       484    0.003    0.000    0.064    0.000 blocks.py:1217(take_nd)
#       832    0.003    0.000    0.007    0.000 transforms.py:2694(__init__)
#      1156    0.003    0.000    0.019    0.000 fromnumeric.py:2171(all)
#      2544    0.003    0.000    0.010    0.000 transforms.py:2133(<lambda>)
#      2750    0.003    0.000    0.021    0.000 pywraplp.py:271(RowConstraint)
#       666    0.003    0.000    0.007    0.000 _dtype.py:46(__str__)
#      9644    0.003    0.000    0.003    0.000 blocks.py:165(internal_values)
#       374    0.003    0.000    0.016    0.000 base.py:786(array)
#       891    0.003    0.000    0.008    0.000 text.py:1178(_preprocess_math)
#       130    0.003    0.000    0.022    0.000 _base.py:1446(apply_aspect)
#       159    0.003    0.000    0.025    0.000 patches.py:728(_update_patch_transform)
#     96/32    0.003    0.000    4.899    0.153 image.py:117(_draw_list_compositing_images)
#       602    0.003    0.000    0.005    0.000 __init__.py:968(get_siblings)
#      1007    0.003    0.000    0.008    0.000 managers.py:139(shape)
#       918    0.003    0.000    0.004    0.000 backend_agg.py:49(get_hinting_flag)
#      1983    0.003    0.000    0.004    0.000 patches.py:450(set_joinstyle)
#       832    0.003    0.000    0.011    0.000 lines.py:709(_transform_path)
#         2    0.003    0.001    0.018    0.009 collections.py:1810(<listcomp>)
#      1686    0.003    0.000    0.003    0.000 lines.py:635(axes)
#       412    0.003    0.000    0.006    0.000 cast.py:1193(construct_1d_object_array_from_listlike)
#      3270    0.003    0.000    0.007    0.000 backend_bases.py:918(set_foreground)
#         2    0.003    0.001    1.443    0.721 plotting.py:103(<listcomp>)
#       186    0.003    0.000    0.005    0.000 transforms.py:1914(rotate)
#       562    0.003    0.000    0.004    0.000 axis.py:198(_set_labelrotation)
#       161    0.003    0.000    0.157    0.001 generic.py:3323(_take)
#      1266    0.003    0.000    0.013    0.000 numeric.py:3063(__exit__)
#      2990    0.003    0.000    0.003    0.000 {method 'count' of 'str' objects}
#      2942    0.003    0.000    0.008    0.000 text.py:1089(set_x)
#      2600    0.003    0.000    0.016    0.000 linear_solver_natural_api.py:128(__neg__)
#       726    0.003    0.000    0.003    0.000 getlimits.py:365(__new__)
#   935/934    0.002    0.000    0.009    0.000 transforms.py:1025(get_points)
#       714    0.002    0.000    0.012    0.000 common.py:93(is_bool_indexer)
#      1149    0.002    0.000    0.005    0.000 text.py:918(set_color)
#      3048    0.002    0.000    0.020    0.000 artist.py:974(<listcomp>)
#      1686    0.002    0.000    0.004    0.000 lines.py:1269(set_markersize)
#      1166    0.002    0.000    0.023    0.000 missing.py:105(_isna_new)
#       528    0.002    0.000    0.012    0.000 fromnumeric.py:2324(ptp)
#     12980    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#      7572    0.002    0.000    0.004    0.000 pywrapcp.py:2820(IndexToNode)
#      2052    0.002    0.000    0.009    0.000 transforms.py:2149(transform_non_affine)
#      3462    0.002    0.000    0.007    0.000 text.py:1100(set_y)
#      2576    0.002    0.000    0.003    0.000 backend_bases.py:976(get_hatch_path)
#      2568    0.002    0.000    0.007    0.000 scale.py:101(get_transform)
#       918    0.002    0.000    0.002    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#      5246    0.002    0.000    0.002    0.000 text.py:1136(set_text)
#       374    0.002    0.000    0.006    0.000 numpy_.py:35(__init__)
#      1968    0.002    0.000    0.015    0.000 axis.py:301(set_label1)
#       373    0.002    0.000    0.005    0.000 base.py:504(_simple_new)
#       283    0.002    0.000    0.012    0.000 _base.py:760(get_yaxis_text1_transform)
#       134    0.002    0.000    0.006    0.000 numeric.py:2508(within_tol)
#       541    0.002    0.000    0.007    0.000 fromnumeric.py:41(_wrapit)
#       279    0.002    0.000    0.013    0.000 _base.py:684(get_xaxis_text1_transform)
#      2451    0.002    0.000    0.017    0.000 {method 'max' of 'numpy.ndarray' objects}
#      1266    0.002    0.000    0.016    0.000 numeric.py:3058(__enter__)
#    654/96    0.002    0.000    0.004    0.000 arrayprint.py:716(recurser)
#       832    0.002    0.000    0.003    0.000 markers.py:258(__bool__)
#       528    0.002    0.000    0.103    0.000 ticker.py:256(format_ticks)
#      1993    0.002    0.000    0.026    0.000 patches.py:292(set_edgecolor)
#      5240    0.002    0.000    0.002    0.000 common.py:122(classes_and_not_datetimelike)
#       528    0.002    0.000    0.002    0.000 {method 'clip' of 'numpy.ndarray' objects}
#      1686    0.002    0.000    0.004    0.000 lines.py:1227(set_markeredgewidth)
#       279    0.002    0.000    0.049    0.000 axis.py:442(_get_text2)
#      2842    0.002    0.000    0.003    0.000 transforms.py:1687(__array__)
#       190    0.002    0.000    0.007    0.000 colors.py:254(to_rgba_array)
#      1266    0.002    0.000    0.003    0.000 numeric.py:3054(__init__)
#      3869    0.002    0.000    0.002    0.000 numerictypes.py:587(<listcomp>)
#         1    0.002    0.002    0.105    0.105 pywraplp.py:274(Minimize)
#       832    0.002    0.000    0.004    0.000 lines.py:928(get_markeredgecolor)
#      4252    0.002    0.000    0.023    0.000 base.py:350(type)
#      1056    0.002    0.000    0.002    0.000 ticker.py:1857(closeto)
#        64    0.002    0.000    4.898    0.077 _base.py:2573(draw)
#       283    0.002    0.000    0.043    0.000 axis.py:558(_get_text2)
#       541    0.002    0.000    0.006    0.000 transforms.py:2415(__init__)
#      1394    0.002    0.000    0.004    0.000 stride_tricks.py:257(<listcomp>)
#      5000    0.002    0.000    0.002    0.000 {built-in method builtins.abs}
#      4182    0.002    0.000    0.002    0.000 stride_tricks.py:261(<genexpr>)
# 2708/2705    0.002    0.000    0.005    0.000 transforms.py:2573(get_matrix)
#       279    0.002    0.000    0.438    0.002 axis.py:1928(_get_tick)
#      1187    0.002    0.000    0.004    0.000 font_manager.py:767(set_variant)
#       283    0.002    0.000    0.421    0.001 axis.py:2217(_get_tick)
#       140    0.002    0.000    0.198    0.001 geoseries.py:58(x)
#      1178    0.002    0.000    0.004    0.000 artist.py:1005(set_zorder)
#       140    0.002    0.000    0.192    0.001 geoseries.py:67(y)
#      1971    0.002    0.000    0.003    0.000 patch.py:10(__init__)
#      1968    0.002    0.000    0.013    0.000 axis.py:314(set_label2)
#      1126    0.002    0.000    0.013    0.000 blocks.py:225(make_block_same_class)
#      1686    0.002    0.000    0.004    0.000 lines.py:1038(set_antialiased)
#       816    0.002    0.000    0.004    0.000 base.py:894(_get_geom_item)
#       191    0.002    0.000    0.021    0.000 cast.py:1072(find_common_type)
#      2993    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#      1151    0.002    0.000    0.004    0.000 text.py:934(set_horizontalalignment)
#      5819    0.002    0.000    0.002    0.000 text.py:841(get_text)
#      1327    0.002    0.000    0.011    0.000 {method 'any' of 'numpy.ndarray' objects}
#      1336    0.002    0.000    0.046    0.000 generic.py:178(_validate_dtype)
#      6859    0.002    0.000    0.002    0.000 {built-in method builtins.setattr}
#      2080    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       161    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#         2    0.002    0.001    1.507    0.754 plotting.py:48(plot_polygon_collection)
#        32    0.002    0.000    4.932    0.154 figure.py:1661(draw)
#      1216    0.002    0.000    0.002    0.000 backend_bases.py:851(set_alpha)
#        32    0.002    0.000    6.938    0.217 plotting.py:317(plot_dataframe)
#      2367    0.002    0.000    0.006    0.000 patches.py:223(get_patch_transform)
#      3728    0.002    0.000    0.002    0.000 figure.py:462(_get_dpi)
#      1840    0.002    0.000    0.002    0.000 {built-in method math.log10}
#       183    0.002    0.000    0.005    0.000 managers.py:306(_verify_integrity)
#        66    0.002    0.000    0.416    0.006 axis.py:2004(_update_label_position)
#       279    0.002    0.000    0.005    0.000 axis.py:411(apply_tickdir)
#       312    0.002    0.000    0.059    0.000 generic.py:11018(logical_func)
#       512    0.002    0.000    0.002    0.000 ticker.py:712(<genexpr>)
#      1107    0.002    0.000    0.007    0.000 common.py:1198(is_datetime_or_timedelta_dtype)
#       360    0.002    0.000    0.053    0.000 indexing.py:2205(_getitem_axis)
#      2750    0.002    0.000    0.002    0.000 linear_solver_natural_api.py:232(__init__)
#       263    0.002    0.000    0.003    0.000 core.py:2905(_update_from)
#      7572    0.002    0.000    0.002    0.000 {built-in method ortools.constraint_solver._pywrapcp.RoutingIndexManager_IndexToNode}
#       281    0.002    0.000    0.042    0.000 base.py:584(_shallow_copy_with_infer)
#       206    0.002    0.000    0.037    0.000 managers.py:97(__init__)
#      6778    0.002    0.000    0.002    0.000 font_manager.py:724(get_size_in_points)
#      5064    0.002    0.000    0.002    0.000 {built-in method numpy.geterrobj}
#      2700    0.002    0.000    0.014    0.000 linear_solver_natural_api.py:116(__mul__)
#       188    0.002    0.000    0.006    0.000 managers.py:963(iget)
#       313    0.002    0.000    0.002    0.000 {built-in method numpy.putmask}
#      2304    0.002    0.000    0.008    0.000 axis.py:792(get_transform)
#      5330    0.002    0.000    0.002    0.000 font_manager.py:676(get_family)
#       160    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#       674    0.002    0.000    0.002    0.000 generic.py:349(_get_axis_number)
#        66    0.002    0.000    0.405    0.006 axis.py:2298(_update_label_position)
#      3021    0.002    0.000    0.006    0.000 managers.py:141(<genexpr>)
#      1190    0.002    0.000    0.002    0.000 backend_bases.py:868(set_antialiased)
#       314    0.002    0.000    0.023    0.000 base.py:3940(__getitem__)
#       943    0.002    0.000    0.002    0.000 generic.py:363(_get_axis_name)
#       257    0.002    0.000    0.007    0.000 numeric.py:34(__new__)
#       148    0.002    0.000    0.007    0.000 path.py:497(get_extents)
#      1983    0.002    0.000    0.003    0.000 patches.py:469(set_hatch)
#       352    0.002    0.000    0.093    0.000 backend_agg.py:119(draw_path)
#         1    0.002    0.002  128.560  128.560 <string>:1(<module>)
#       528    0.002    0.000    0.003    0.000 artist.py:163(have_units)
#      8480    0.002    0.000    0.002    0.000 {built-in method builtins.callable}
#        32    0.002    0.000    0.002    0.000 {pandas._libs.lib.map_infer_mask}
#       279    0.002    0.000    0.010    0.000 _base.py:710(get_xaxis_text2_transform)
#       741    0.002    0.000    0.004    0.000 ops.py:43(get_op_result_name)
#      1686    0.002    0.000    0.003    0.000 lines.py:1212(set_markeredgecolor)
#      1050    0.002    0.000    0.003    0.000 collections.py:683(get_edgecolor)
#       486    0.002    0.000    0.003    0.000 blocks.py:3100(_extend_blocks)
#        20    0.002    0.000    0.091    0.005 _axes.py:4312(scatter)
#       186    0.002    0.000    0.007    0.000 transforms.py:1930(rotate_deg)
#      1149    0.002    0.000    0.004    0.000 text.py:1212(set_usetex)
#       787    0.002    0.000    0.018    0.000 common.py:702(is_datetimelike)
#       562    0.002    0.000    0.064    0.000 lines.py:1021(get_path)
#       808    0.002    0.000    0.004    0.000 common.py:1545(is_float_dtype)
# 2264/2248    0.002    0.000    0.002    0.000 spines.py:208(_ensure_position_is_set)
#       283    0.002    0.000    0.005    0.000 axis.py:528(apply_tickdir)
#       296    0.002    0.000    0.013    0.000 markers.py:748(_set_tickleft)
#      1126    0.002    0.000    0.004    0.000 common.py:746(is_dtype_equal)
#       332    0.002    0.000    0.009    0.000 core.py:3663(filled)
#       836    0.002    0.000    0.002    0.000 {built-in method _abc._abc_subclasscheck}
# ...
#         1    0.000    0.000    0.000    0.000 types.py:164(__get__)
#         2    0.000    0.000    0.000    0.000 pyplot.py:908(gca)
#         1    0.000    0.000    0.000    0.000 image.py:827(__init__)
#        40    0.000    0.000    0.000    0.000 inspect.py:2517(name)
#         6    0.000    0.000    0.000    0.000 index_tricks.py:729(__getitem__)
#         1    0.000    0.000    0.000    0.000 _validators.py:114(_check_for_invalid_keys)
#         4    0.000    0.000    0.000    0.000 six.py:184(find_module)
#         2    0.000    0.000    0.000    0.000 __init__.py:2053(__init__)
#        20    0.000    0.000    0.000    0.000 artist.py:778(get_in_layout)
#         1    0.000    0.000    0.000    0.000 managers.py:2015(_preprocess_slice_or_indexer)
#        10    0.000    0.000    0.000    0.000 collections.py:827(get_sizes)
#         1    0.000    0.000    0.000    0.000 figure.py:512(set_constrained_layout)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:31(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:1072(_make_key)
#         2    0.000    0.000    0.000    0.000 axis.py:1582(set_label_text)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_swiginit}
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         2    0.000    0.000    0.000    0.000 gridspec.py:311(<listcomp>)
#         1    0.000    0.000    0.000    0.000 shape_base.py:1154(tile)
#         1    0.000    0.000    0.000    0.000 legend.py:978(set_title)
#         1    0.000    0.000    0.000    0.000 core.py:5686(max)
#        32    0.000    0.000    0.000    0.000 scale.py:31(__init__)
#        20    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#        10    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 base.py:1672(is_integer)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:3254(new_figure_manager_given_figure)
#         2    0.000    0.000    0.000    0.000 figure.py:1888(gca)
#         1    0.000    0.000    0.000    0.000 warnings.py:453(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:48(get_projection_class)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#       3/1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#         2    0.000    0.000    0.000    0.000 frame.py:474(axes)
#         5    0.000    0.000    0.000    0.000 colors.py:249(<genexpr>)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:110(set_active)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:2141(mpl_connect)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:151(__exit__)
#         1    0.000    0.000    0.000    0.000 _validators.py:130(validate_kwargs)
#         1    0.000    0.000    0.000    0.000 figure.py:1882(_set_artist_props)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#         3    0.000    0.000    0.000    0.000 nanops.py:63(check)
#         2    0.000    0.000    0.000    0.000 figure.py:779(set_canvas)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:17(_get_left)
#         1    0.000    0.000    0.000    0.000 __init__.py:23(find_module)
#         1    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#         1    0.000    0.000    0.000    0.000 base.py:2965(_convert_listlike_indexer)
#         1    0.000    0.000    0.000    0.000 range.py:184(_get_data_as_items)
#         5    0.000    0.000    0.000    0.000 __init__.py:76(__init__)
#         2    0.000    0.000    0.000    0.000 patches.py:2214(__init__)
#         1    0.000    0.000    0.001    0.001 base.py:4447(get_indexer_for)
#         1    0.000    0.000    0.000    0.000 cm.py:386(autoscale_None)
#         2    0.000    0.000    0.000    0.000 inspect.py:3010(bind)
#         2    0.000    0.000    0.000    0.000 text.py:1027(set_fontsize)
#         2    0.000    0.000    0.018    0.009 collections.py:1809(set_paths)
#         2    0.000    0.000    0.000    0.000 gridspec.py:310(locally_modified_subplot_params)
#         1    0.000    0.000    0.000    0.000 figure.py:70(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:486(set_tight_layout)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         1    0.000    0.000    0.000    0.000 warnings.py:493(__exit__)
#         1    0.000    0.000    0.000    0.000 patches.py:337(set_alpha)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetOffset}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#         1    0.000    0.000    0.000    0.000 figure.py:543(set_constrained_layout_pads)
#         2    0.000    0.000    0.000    0.000 transforms.py:770(null)
#         8    0.000    0.000    0.000    0.000 axis.py:1462(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#         1    0.000    0.000    0.000    0.000 base.py:802(_assert_take_fillable)
#         2    0.000    0.000    0.000    0.000 core.py:293(_scalar_fill_value)
#         2    0.000    0.000    0.000    0.000 gridspec.py:509(get_topmost_subplotspec)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         1    0.000    0.000    0.000    0.000 nanops.py:276(_wrap_results)
#         2    0.000    0.000    0.000    0.000 transforms.py:2616(__init__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:530(__hash__)
#         2    0.000    0.000    0.000    0.000 figure.py:100(_entry_from_axes)
#         4    0.000    0.000    0.000    0.000 __init__.py:715(clear)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:337(Clear)
#         1    0.000    0.000    0.000    0.000 enum.py:628(value)
#         1    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#         1    0.000    0.000    0.000    0.000 legend.py:598(_set_artist_props)
#         2    0.000    0.000    0.000    0.000 missing.py:530(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 cm.py:413(changed)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:25(_get_bottom)
#         2    0.000    0.000    0.000    0.000 _base.py:846(set_position)
#         2    0.000    0.000    0.000    0.000 core.py:291(_extremum_fill_value)
#         3    0.000    0.000    0.000    0.000 generic.py:3205(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 __init__.py:2065(add)
#         2    0.000    0.000    0.000    0.000 gridspec.py:427(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:160(__contains__)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:355(SetMinimization)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_Clear}
#         2    0.000    0.000    0.000    0.000 numerictypes.py:238(obj2sctype)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:438(__getitem__)
#         2    0.000    0.000    0.000    0.000 transforms.py:886(x0)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:21(_get_right)
#         1    0.000    0.000    0.000    0.000 image.py:736(set_interpolation)
#         1    0.000    0.000    0.000    0.000 _axes.py:223(set_xlabel)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:255(SetNumThreads)
#         2    0.000    0.000    0.000    0.000 text.py:1044(set_fontweight)
#         2    0.000    0.000    0.000    0.000 core.py:211(_recursive_fill_value)
#         2    0.000    0.000    0.000    0.000 core.py:226(_get_dtype_of)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         6    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         2    0.000    0.000    0.000    0.000 _base.py:898(set_axes_locator)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:237(set_time_limit)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#         2    0.000    0.000    0.000    0.000 weakref.py:51(_cb)
#         2    0.000    0.000    0.000    0.000 transforms.py:891(y0)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2500(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 figure.py:168(__init__)
#         1    0.000    0.000    0.000    0.000 legend.py:609(_set_loc)
#         2    0.000    0.000    0.000    0.000 _base.py:3027(set_axis_on)
#         2    0.000    0.000    0.000    0.000 six.py:180(find_module)
#         1    0.000    0.000    0.000    0.000 _validators.py:32(_check_for_default_values)
#         1    0.000    0.000    0.000    0.000 generic.py:1567(<listcomp>)
#         1    0.000    0.000    0.000    0.000 image.py:910(get_extent)
#         1    0.000    0.000    0.000    0.000 _base.py:1783(_sci)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_SetNumThreads}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.000    0.000    0.000    0.000 _validators.py:10(_check_arg_length)
#         1    0.000    0.000    0.000    0.000 base.py:2999(_convert_arr_indexer)
#         2    0.000    0.000    0.000    0.000 transforms.py:307(x1)
#         1    0.000    0.000    0.000    0.000 pyplot.py:3053(sci)
#         2    0.000    0.000    0.000    0.000 figure.py:101(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 image.py:246(changed)
#         2    0.000    0.000    0.000    0.000 offsetbox.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:227(itervalues)
#         1    0.000    0.000    0.000    0.000 base.py:1237(_get_names)
#         6    0.000    0.000    0.000    0.000 collections.py:425(get_hatch)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:317(y1)
#         2    0.000    0.000    0.000    0.000 transforms.py:896(x1)
#         2    0.000    0.000    0.000    0.000 gridspec.py:144(_normalize)
#         2    0.000    0.000    0.000    0.000 widgets.py:33(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         1    0.000    0.000    0.000    0.000 text.py:1199(set_fontproperties)
#         1    0.000    0.000    0.000    0.000 re.py:232(compile)
#         2    0.000    0.000    0.000    0.000 inspect.py:2609(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:901(y1)
#         1    0.000    0.000    0.000    0.000 image.py:228(get_size)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         1    0.000    0.000    0.000    0.000 image.py:803(set_filterrad)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#         2    0.000    0.000    0.000    0.000 figure.py:1075(fixitems)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_set_time_limit}
#         2    0.000    0.000    0.000    0.000 inspect.py:2835(parameters)
#         3    0.000    0.000    0.000    0.000 base.py:4698(_validate_indexer)
#         2    0.000    0.000    0.000    0.000 missing.py:71(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 generic.py:1693(<listcomp>)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:188(<genexpr>)
#         1    0.000    0.000    0.000    0.000 image.py:786(set_filternorm)
#         1    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         1    0.000    0.000    0.000    0.000 indexing.py:2676(is_nested_tuple)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:93(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         2    0.000    0.000    0.000    0.000 core.py:1821(_check_mask_axis)
#         1    0.000    0.000    0.000    0.000 managers.py:706(nblocks)
#         1    0.000    0.000    0.000    0.000 core.py:306(minimum_fill_value)
#         2    0.000    0.000    0.000    0.000 base.py:2915(is_int)
#         2    0.000    0.000    0.000    0.000 gridspec.py:77(set_height_ratios)
#         1    0.000    0.000    0.000    0.000 image.py:235(set_alpha)
#         1    0.000    0.000    0.000    0.000 image.py:768(set_resample)
#         1    0.000    0.000    0.000    0.000 legend.py:727(get_legend_handler_map)
#         1    0.000    0.000    0.000    0.000 legend.py:1046(set_bbox_to_anchor)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 weakref.py:73(__eq__)
#         1    0.000    0.000    0.000    0.000 core.py:357(maximum_fill_value)
#         1    0.000    0.000    0.000    0.000 base.py:5381(_ensure_has_len)
#         2    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:94(<listcomp>)
#         2    0.000    0.000    0.000    0.000 legend.py:706(get_default_handler_map)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         1    0.000    0.000    0.000    0.000 base.py:3035(_convert_list_indexer)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:156(<listcomp>)
#         1    0.000    0.000    0.000    0.000 figure.py:2034(add_axobserver)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         2    0.000    0.000    0.000    0.000 shape_base.py:1226(<genexpr>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:164(<listcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:1627(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:168(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetMinimization}
#         2    0.000    0.000    0.000    0.000 patches.py:1928(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 gridspec.py:68(set_width_ratios)
#         2    0.000    0.000    0.000    0.000 legend.py:675(_approx_text_height)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:755(set_minimumdescent)
#         1    0.000    0.000    0.000    0.000 artist.py:545(set_url)
#         1    0.000    0.000    0.000    0.000 artist.py:580(set_snap)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:160(<listcomp>)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:173(set_offset)
#         2    0.000    0.000    0.000    0.000 patches.py:1927(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 legend.py:958(get_frame)
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 indexing.py:937(_convert_for_reindex)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
