# %% [markdown]
# # **GROUP PROJECT**

# %% [markdown]
# https://link.springer.com/referenceworkentry/10.1007%2F978-0-387-74759-0_345

# %%
from __future__ import print_function
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import geopandas as gpd
import random
import pyproj
from shapely.geometry import Point, LineString
import matplotlib.pyplot as plt
import seaborn as sns
import ortools as ort
import datetime as dt
# pysal submodule imports
from pysal.lib import cg, examples
from pysal.explore import spaghetti as spgh

import geopandas as gpd
from shapely.geometry import Point
from ortools.linear_solver import pywraplp
import copy, sys, warnings
from collections import OrderedDict

import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
from matplotlib.colors import ListedColormap

try:
    from IPython.display import set_matplotlib_formats
    set_matplotlib_formats('retina')
except ImportError:
    pass

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp
from ortools.sat.python import cp_model
# %load_ext line_profiler
# Out:
# C:\Users\Noah\Anaconda3\lib\site-packages\pysal\model\spvcm\abstracts.py:10: UserWarning: The `dill` module is required to use the sqlite backend fully.
#   from .sqlite import head_to_sql, start_sql

# %% [markdown]
# # **1. FUNCTIONS**

# %%
def buildCityDF(nCities,gridX=100,gridY=100):
    xs = np.random.randint(0,gridX,nCities)
    ys = np.random.randint(0,gridY,nCities)
    pts = [Point(xs[i],ys[i]) for i in range(0,nCities)]
    demands = np.random.randint(0,101,nCities)
    facilityOneCosts = np.random.randint(0,101,nCities)
    facilityTwoCosts = np.random.randint(100,201,nCities)
    cityIndices = range(0,nCities)
    cities = gpd.GeoDataFrame({"x":xs,"y":ys,"demand":demands,"geometry":pts,"City Index":cityIndices,"Facility One Cost":facilityOneCosts,"Facility Two Cost":facilityTwoCosts})
    return cities

# %%
def buildDistanceMatrix_Euclidean(cities):
    distances = np.zeros((len(cities),len(cities)))
    for i,row in cities.iterrows():
        for j,row2 in cities.iterrows():
            distances[j,i] = row.geometry.distance(row2.geometry)
    return distances

# %%
def assignFacilitiesAndCluster(cities,M = 100,Rvz=[100000,200000],truckCapacityZ = [40000,80000],alpha=75.0,truckCapacity = 80000,fractionTruckRangeAllowed=0.8,nFacility=1,maxTimeLimit=5*60*1000):
    solver_instance = pywraplp.Solver.CBC_MIXED_INTEGER_PROGRAMMING
#     solver_instance = cp_model.CpModel()
    distances = buildDistanceMatrix_Euclidean(cities)
    cij = distances
    n_customers = cij.shape[0]
    range_customers = range(n_customers)
    n_facilityCandidates = cij.shape[1]
    range_facilityCandidates = range(n_facilityCandidates)
    demands = np.array(cities["demand"])
    demands_sum = demands.sum()
    fiz = facilityCost = cities[["Facility One Cost","Facility Two Cost"]].as_matrix()
    zRange = len(Rvz)
    model = pywraplp.Solver("Capacitated Fixed Charge", solver_instance)
    model.set_time_limit(maxTimeLimit)

#     model.parameters.max_time_in_seconds = 60.0 * 5

    xij = {(i,j): model.IntVar(0,1, 'x[%i,%i]' % (i,j)) for i in range_customers for j in range_facilityCandidates} # which facility is served by which 
    yjz = {(j,z): model.IntVar(0,1, 'y[%i,%i]' % (j,z)) for j in range_facilityCandidates for z in range(zRange)} # charging station location decision/ concentrator
    
    obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + alpha*2*cij[0,j]*yjz[j,z] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]
#     obj = [alpha * (cij[0,j]+cij[i,j]+cij[i,0]) * xij[i,j] + fiz[i,z] * yjz[j,z] for i in range_customers for j in range_facilityCandidates for z in range(zRange)]

    # Service Constraint
    for i in range_customers:
        model.Add(model.Sum([xij[i,j] for j in range_facilityCandidates]) == nFacility)
    
    # Capacity Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([demands[i] * xij[i,j] for i in range_facilityCandidates]) <= model.Sum([truckCapacityZ[z]*yjz[j,z] for z in range(zRange)]))
    
    # Assignment Constraint
    for i in range_customers:
        for j in range_facilityCandidates:
            model.Add(xij[i,j] <= model.Sum([yjz[j,z] for z in range(zRange)]))
    
    # Maximum Concentratorrs Constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for j in range_facilityCandidates for z in range(zRange)]) <= M)
        
    # Total tour length constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([xij[i,j]*cij[i,j] for i in range_facilityCandidates]) <= model.Sum([yjz[j,z]*Rvz[z]*fractionTruckRangeAllowed for z in range(zRange)]))
        
    # Z limitation constraint
    for j in range_facilityCandidates:
        model.Add(model.Sum([yjz[j,z] for z in range(zRange)]) <= 1)

    model.Minimize(model.Sum(obj))
    status = model.Solve()

    if status == pywraplp.Solver.OPTIMAL:
        print('Optimal Solution Found')

    resultGDF = cities.copy(deep=True)
    for z in range(2):
        resultGDF[f"Status: Facility Type {z}"] = [yjz[j,z].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 0"] = [yjz[j,0].solution_value() for j in range_facilityCandidates]
#     resultGDF["Status: Facility Type 1"] = [yjz[j,1].solution_value() for j in range_facilityCandidates]
    return model,yjz,xij,resultGDF,status

# %%
def convertTourToPathDF(tour,resultGDF):
#     tour = list(resultGDF[resultGDF["assignment"]==tour]["City Index"])
    tour.append(tour[0]) # Return to end
    startNodes = []
    endNodes = []
    startCoords = []
    endCoords = []
    lines = [] # https://gis.stackexchange.com/questions/95670/how-to-create-a-shapely-linestring-from-two-points
    for i in range(0,len(tour)):
        currentCity = tour[i]
        if i < len(tour)-1:
            nextCity = tour[i+1]
        else:
            nextCity = tour[0]
        startNodes.append(currentCity)
        endNodes.append(nextCity)
        startPoint = resultGDF[resultGDF["City Index"]==currentCity].geometry
        startCoords.append(startPoint)
        endPoint = resultGDF[resultGDF["City Index"]==nextCity].geometry
        endCoords.append(endPoint)
        line = LineString([(startPoint.x,startPoint.y),(endPoint.x,endPoint.y)])
        lines.append(line)
    gdf = gpd.GeoDataFrame({"Start Node":startNodes,"End Node":endNodes,"geometry":lines})
    return gdf

# %%
# https://developers.google.com/optimization/routing/tsp
"""Simple travelling salesman problem between cities."""

def create_data_model(dfSubset):
    """Stores the data for the problem."""
    data = {}
    data['distance_matrix'] = buildDistanceMatrix_Euclidean(dfSubset.reset_index())
    data['num_vehicles'] = 1
    data['depot'] = 0
    return data


def print_solution(manager, routing, assignment,dfSubset):
    """Prints assignment on console."""
    optimizedRoute = []
#     print(f"Objective: ")
#     print('Objective: {} meters'.format(assignment.ObjectiveValue()))
    index = routing.Start(0)
    plan_output = 'Route for vehicle 0:\n'
    route_distance = 0
    orderedDFSubset = dfSubset.reset_index()
    while not routing.IsEnd(index):
        correctedCityIndex = orderedDFSubset.iloc[manager.IndexToNode(index)][0]
        optimizedRoute.append(correctedCityIndex)
#         print(f"******{correctedCityIndex}")
#         print(f"====>{orderedDFSubset.iloc[manager.IndexToNode(index)]}")
#         plan_output += ' {} ->'.format(manager.IndexToNode(index))
        plan_output += ' {} ->'.format(correctedCityIndex)

        previous_index = index
        index = assignment.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
#     plan_output += ' {}\n'.format(manager.IndexToNode(index))
    correctedCityIndex = orderedDFSubset.iloc[manager.IndexToNode(index)][0]
    plan_output += ' {}\n'.format(correctedCityIndex)
#     print(f"******{correctedCityIndex}")
    optimizedRoute.append(correctedCityIndex)
#     print(f"====>{orderedDFSubset.iloc[manager.IndexToNode(index)]}")
    plan_output += f'Route distance: {route_distance/1000.0} km\n'
    print(plan_output)
    return optimizedRoute,route_distance


def main(dfSubset):
    """Entry point of the program."""
    # Instantiate the data problem.
    data = create_data_model(dfSubset)

    # Create the routing index manager.
    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']),
                                           data['num_vehicles'], data['depot'])

    # Create Routing Model.
    routing = pywrapcp.RoutingModel(manager)


    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Setting first solution heuristic.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    # Solve the problem.
    assignment = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if assignment:
        route,route_distance = print_solution(manager, routing, assignment,dfSubset)
    return route,route_distance

# %%
def solveAndPlot(illinoisCities,M=20,Rvz=[200000,400000],truckCapacityZ = [40000,80000],alpha=0.001,fractionTruckRangeAllowed=0.75,maxTimeLimit=5*60*1000):
    model,yjz,xij,resultGDF,status = assignFacilitiesAndCluster(illinoisCities,M=M,Rvz=Rvz,truckCapacityZ=truckCapacityZ,alpha=alpha,fractionTruckRangeAllowed=fractionTruckRangeAllowed,maxTimeLimit=maxTimeLimit)
    assignments = np.zeros((nCities,nCities))
    for k,v in xij.items():
        i = k[0]
        j = k[1]
        assignments[i,j] = v.solution_value()
    cluster = []
    for cityNodeID in range(nCities):
        for rootNodeID in range(nCities):
            lookup = assignments[cityNodeID,rootNodeID]
            if lookup == 1:
                cluster.append(rootNodeID)
    resultGDF["assignment"] = cluster
    uniqueClusters = list(set(cluster))


    fig = plt.figure(figsize=(20,20))
    ax1 = fig.add_subplot(1,2,1)
    ax2 = fig.add_subplot(1,2,2)
    fig.tight_layout()

    illinois.plot(ax=ax1,color="blue",alpha=0.1)
    illinois.sort_values("ALAND",ascending=False).reset_index()[0:nCities].plot(ax=ax1,color="red",alpha=0.2)
    # illinois.sort_values("ALAND",ascending=False).reset_index()[0:40].centroid.plot(ax=ax1,color="white",marker='*')

    colors = ['#'+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(len(uniqueClusters))]
    totalCost = 0.0
    subtourRoutingCosts = {}
    subtourConstructionCosts = {}
    subtourDistances = {}
    totalConstructionCost = np.sum(resultGDF["Facility One Cost"] * resultGDF["Status: Facility Type 0"] + resultGDF["Facility Two Cost"] * resultGDF["Status: Facility Type 1"])
    for i in range(0,len(uniqueClusters)):
        dfSubset = resultGDF[resultGDF["assignment"]==uniqueClusters[i]]
        tour,tourLength = main(dfSubset)
        if resultGDF.iloc[uniqueClusters[i]]["Status: Facility Type 0"]==1:
            facilityType = 0
            vehicleType = "Standard range"
        else:
            facilityType = 1
            vehicleType = "Extended range"
        subtourRoutingCosts[i] = alpha * tourLength
        subtourDistances[i] = tourLength
        # check if constraint violated
        label = f"{resultGDF.iloc[uniqueClusters[i]].Name}: {tourLength/1000:,.0f} KM, {vehicleType} vehicle"
        if tourLength > Rvz[facilityType]:
            label += " CONSTRAINT VIOLATED"
        # plot the nodes
        dfSubset.plot(ax=ax1,color=colors[i],markersize=dfSubset["demand"]/100,label=label)
        # plot the tour
        ls = "dashed"
        if facilityType == 1:
            ls = "dotted"
        convertTourToPathDF(tour,resultGDF).plot(ax=ax1,colors=colors[i],ls=ls,alpha=0.75)
        # plot the facilities
        dfFacility = resultGDF[resultGDF["City Index"]==uniqueClusters[i]]
        dfFacility.plot(ax=ax1,markersize=1000,marker="o",alpha=.75,facecolors='none', edgecolors=colors[i])
    totalRoutingCost = np.sum(list(subtourRoutingCosts.values()))
    totalRoutingDistance = np.sum(list(subtourDistances.values()))
    f""
    ax1.set_title(f"Tours organized by cluster\nNode sizes proportional to demand\nConstruction Cost: ${totalConstructionCost:,.2f}, Routing Distance: {totalRoutingDistance/1000:,.0f} KM\n$Total Cost: {totalConstructionCost + totalRoutingCost:,.2f}")
    ax1.legend()
    # Plot assignments
    plt.imshow(assignments)
    ax2.set_title("Assignment of citites to subtours")
    ax2.set_xlabel("Subtour Root (Flag/Concentrator) Node")
    ax2.set_ylabel("City")

# %% [markdown]
# # **2. SET UP CITIES**

# %%
illinoisCitiesPath = "Final Presentation\\tl_2016_17_place\\tl_2016_17_place.shp"
illinoisCitiesPath = "Final Presentation\\illinois_projected.shp"
illinois = gpd.read_file(illinoisCitiesPath)

# %%
nCities = 30
facilityOneBaseCost = 100000
facilityOneBaseSTD = 10000
facilityTwoBaseCost = 1000000
facilityTwoBaseSTD = 100000
baseDemand = 10000
baseDemandSTD = 10000
demands = np.random.normal(baseDemand, baseDemandSTD, nCities)
demands = [np.abs(demand) for demand in demands]
facilityOneCosts = np.random.normal(facilityOneBaseCost, facilityOneBaseSTD, nCities)
facilityOneCosts = [np.abs(facilityOneCost) for facilityOneCost in facilityOneCosts]
facilityTwoCosts = np.random.normal(facilityTwoBaseCost, facilityTwoBaseSTD, nCities)
facilityTwoCosts = [np.abs(facilityTwoCost) for facilityTwoCost in facilityTwoCosts]
cityIndices = range(nCities)
xs = []
ys = []
pts = []
polygons = []
cityNames = []
illinoisGeoms = illinois.sort_values("ALAND",ascending=False).reset_index()
for i,row in illinoisGeoms[0:nCities].iterrows():
    pts.append(row["geometry"].centroid)
    polygons.append(row["geometry"])
    xs.append(row["geometry"].centroid.x)
    ys.append(row["geometry"].centroid.y)
    cityNames.append(row["NAME"])


illinoisCities = gpd.GeoDataFrame({"x":xs,"y":ys,"demand":demands,"geometry":pts,"polygon":polygons,"City Index":cityIndices,"Facility One Cost":facilityOneCosts,"Facility Two Cost":facilityTwoCosts,"Name":cityNames})

# %% [markdown]
# # **3. SOLVE TSP SUB-TOURS**

# %%
# %prun solveAndPlot(illinoisCities,M=20,Rvz=[300000,600000],truckCapacityZ=[40000,80000],alpha=0.001,fractionTruckRangeAllowed=0.75,maxTimeLimit=5*60*1000)
# Out:
# Route for vehicle 0:
#  0 -> 5 -> 13 -> 0
# Route distance: 252.955 km
#
# Route for vehicle 0:
#  3 -> 6 -> 9 -> 3
# Route distance: 406.445 km
#
# Route for vehicle 0:
#  4 -> 10 -> 21 -> 29 -> 4
# Route distance: 343.338 km
#
# Route for vehicle 0:
#  1 -> 12 -> 23 -> 7 -> 1
# Route distance: 219.132 km
#
# Route for vehicle 0:
#  15 -> 24 -> 22 -> 15
# Route distance: 91.189 km
#
# Route for vehicle 0:
#  8 -> 14 -> 17 -> 8
# Route distance: 155.737 km
#
# Route for vehicle 0:
#  18 -> 26 -> 27 -> 18
# Route distance: 421.564 km
#
# Route for vehicle 0:
#  2 -> 11 -> 19 -> 25 -> 20 -> 2
# Route distance: 301.809 km
#
# Route for vehicle 0:
#  16 -> 28 -> 16
# Route distance: 147.526 km
#          4445562 function calls (4397779 primitive calls) in 307.326 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1  298.714  298.714  298.714  298.714 {built-in method ortools.linear_solver._pywraplp.Solver_Solve}
#       435    1.817    0.004    1.898    0.004 {method 'draw_path_collection' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      5548    0.215    0.000    0.310    0.000 coords.py:124(array_interface)
#         1    0.195    0.195    0.413    0.413 <ipython-input-4-4f2ee41fde16>:22(<listcomp>)
#    324061    0.192    0.000    0.347    0.000 {built-in method builtins.isinstance}
#       839    0.169    0.000    0.169    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
# 56154/55710    0.160    0.000    0.575    0.000 {built-in method numpy.array}
# 265253/265226    0.137    0.000    0.325    0.000 {built-in method builtins.getattr}
#     17304    0.097    0.000    0.097    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     98699    0.089    0.000    0.114    0.000 __init__.py:810(__getitem__)
#       319    0.086    0.000    0.088    0.000 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
# 101225/85679    0.084    0.000    0.124    0.000 artist.py:219(stale)
#     61260    0.083    0.000    0.161    0.000 pywraplp.py:419(__getattr__)
#     22366    0.074    0.000    0.137    0.000 coords.py:48(__len__)
#     25028    0.072    0.000    0.102    0.000 predicates.py:23(__call__)
#     28184    0.071    0.000    0.076    0.000 coords.py:44(_update)
#     92747    0.056    0.000    0.092    0.000 generic.py:7(_check)
#      1542    0.052    0.000    0.398    0.000 lines.py:273(__init__)
#      3863    0.051    0.000    0.089    0.000 cycler.py:349(by_key)
#      7168    0.050    0.000    0.088    0.000 polygon.py:183(_get_ring)
#     25028    0.050    0.000    0.165    0.000 base.py:640(is_empty)
#      1051    0.049    0.000    0.134    0.000 linear_solver_natural_api.py:95(GetCoeffs)
#      5114    0.046    0.000    0.072    0.000 artist.py:74(__init__)
#     15114    0.045    0.000    0.231    0.000 colors.py:149(to_rgba)
#     54296    0.044    0.000    0.046    0.000 {built-in method _abc._abc_instancecheck}
#      9162    0.044    0.000    0.044    0.000 {built-in method numpy.concatenate}
#        29    0.043    0.001    0.043    0.001 {method 'clear' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1914    0.043    0.000    0.450    0.000 text.py:655(draw)
#      5500    0.041    0.000    0.188    0.000 patch.py:33(coding)
#      2262    0.040    0.000    0.300    0.000 lines.py:751(draw)
#      6329    0.039    0.000    0.039    0.000 {built-in method numpy.dot}
#     43050    0.039    0.000    0.066    0.000 {built-in method builtins.hasattr}
#       480    0.039    0.000    0.817    0.002 ticker.py:2016(_raw_ticks)
#      2748    0.038    0.000    0.740    0.000 series.py:152(__init__)
#      1268    0.038    0.000    0.138    0.000 lines.py:667(recache)
#     20135    0.037    0.000    0.078    0.000 common.py:1845(_is_dtype_type)
# 94190/83261    0.035    0.000    0.113    0.000 {built-in method builtins.len}
#       754    0.034    0.000    0.040    0.000 {method 'draw_markers' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#     11407    0.034    0.000    0.110    0.000 fromnumeric.py:69(_wrapreduction)
#     69480    0.034    0.000    0.034    0.000 linear_solver_natural_api.py:164(__init__)
#     64775    0.032    0.000    0.032    0.000 path.py:197(vertices)
#     54296    0.032    0.000    0.078    0.000 abc.py:137(__instancecheck__)
#      5671    0.029    0.000    0.082    0.000 linear_solver_natural_api.py:209(<listcomp>)
#      1731    0.029    0.000    0.054    0.000 cast.py:832(maybe_castable)
#        29    0.028    0.001    0.030    0.001 {built-in method matplotlib._path.get_path_collection_extents}
#      1264    0.028    0.000    0.043    0.000 {pandas._libs.lib.infer_dtype}
#   6371/29    0.027    0.000    4.378    0.151 artist.py:30(draw_wrapper)
#     25740    0.026    0.000    0.079    0.000 linear_solver_natural_api.py:52(CastToLinExp)
#     21125    0.026    0.000    0.169    0.000 base.py:75(is_dtype)
#      9398    0.026    0.000    0.026    0.000 base.py:67(geometry_type_name)
#      8897    0.026    0.000    0.065    0.000 dtypes.py:68(find)
#      3832    0.025    0.000    0.066    0.000 polygon.py:246(exterior)
#     98702    0.025    0.000    0.025    0.000 {function RcParams.__getitem__ at 0x0000023FA73D4158}
#      2200    0.024    0.000    0.395    0.000 construction.py:537(sanitize_array)
#     17463    0.024    0.000    0.040    0.000 transforms.py:1683(__init__)
#      1006    0.024    0.000    0.041    0.000 topology.py:44(__call__)
#     26699    0.023    0.000    0.023    0.000 {method 'pop' of 'list' objects}
#    124852    0.023    0.000    0.023    0.000 base.py:253(_geom)
#         1    0.023    0.023  300.203  300.203 <ipython-input-4-4f2ee41fde16>:1(assignFacilitiesAndCluster)
#      4744    0.022    0.000    0.038    0.000 {pandas._libs.lib.is_scalar}
#      5671    0.022    0.000    0.104    0.000 linear_solver_natural_api.py:208(__init__)
#      1928    0.022    0.000    0.331    0.000 patches.py:42(__init__)
#      3408    0.021    0.000    0.078    0.000 path.py:96(__init__)
#     15974    0.021    0.000    0.021    0.000 {method 'match' of 're.Pattern' objects}
#    102240    0.021    0.000    0.021    0.000 artist.py:774(get_animated)
#     42497    0.021    0.000    0.021    0.000 cycler.py:227(<genexpr>)
#      6706    0.021    0.000    0.021    0.000 {built-in method numpy.empty}
#      4604    0.021    0.000    0.053    0.000 _dtype.py:319(_name_get)
#      7611    0.021    0.000    0.021    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     22461    0.020    0.000    0.020    0.000 transforms.py:82(__init__)
#       514    0.020    0.000    0.748    0.001 axis.py:56(__init__)
#      2514    0.020    0.000    0.112    0.000 cast.py:953(maybe_cast_to_datetime)
#      2801    0.020    0.000    0.087    0.000 artist.py:942(update)
#      4856    0.020    0.000    0.032    0.000 font_manager.py:660(__hash__)
#      2339    0.019    0.000    0.142    0.000 blocks.py:3034(get_block_type)
#       783    0.019    0.000    0.019    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
#     15129    0.019    0.000    0.027    0.000 re.py:271(_compile)
#       240    0.019    0.000    1.139    0.005 axis.py:1074(_update_ticks)
#      5367    0.019    0.000    0.038    0.000 generic.py:5069(__setattr__)
#     15114    0.019    0.000    0.082    0.000 colors.py:115(_is_nth_color)
#     27040    0.019    0.000    0.036    0.000 topology.py:16(_validate)
#      1916    0.019    0.000    0.620    0.000 patch.py:63(<listcomp>)
#      2291    0.019    0.000    0.053    0.000 backend_bases.py:718(__init__)
#      7800    0.018    0.000    0.049    0.000 common.py:1981(pandas_dtype)
#      8220    0.018    0.000    0.119    0.000 pywraplp.py:569(<lambda>)
#      1556    0.018    0.000    0.036    0.000 transforms.py:671(translated)
#       783    0.018    0.000    0.021    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      1762    0.018    0.000    0.204    0.000 text.py:852(get_window_extent)
#       480    0.018    0.000    0.062    0.000 ticker.py:764(_set_format)
#      1050    0.018    0.000    0.133    0.000 linear_solver_natural_api.py:251(Extract)
# 28558/28124    0.018    0.000    0.536    0.000 numeric.py:469(asarray)
#       783    0.017    0.000    0.287    0.000 backend_agg.py:164(draw_text)
#     62543    0.017    0.000    0.017    0.000 {built-in method builtins.issubclass}
#     12688    0.017    0.000    0.017    0.000 linear_solver_natural_api.py:167(AddSelfToCoeffMapOrStack)
# 3552/2937    0.016    0.000    0.061    0.000 transforms.py:2395(get_affine)
#      3408    0.016    0.000    0.039    0.000 path.py:188(_update_values)
#      5671    0.016    0.000    0.019    0.000 linear_solver_natural_api.py:214(AddSelfToCoeffMapOrStack)
#     61924    0.016    0.000    0.016    0.000 path.py:211(codes)
#      8255    0.016    0.000    0.050    0.000 common.py:131(is_object_dtype)
#      9179    0.016    0.000    0.021    0.000 {method 'format' of 'str' objects}
#      5227    0.015    0.000    0.180    0.000 generic.py:5053(__getattr__)
#      2894    0.015    0.000    0.015    0.000 generic.py:127(__init__)
#      2156    0.015    0.000    0.102    0.000 base.py:4342(get_value)
#     16794    0.015    0.000    0.043    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#     15128    0.015    0.000    0.061    0.000 re.py:170(match)
#      3894    0.015    0.000    0.017    0.000 transforms.py:164(set_children)
#      8340    0.015    0.000    0.054    0.000 linear_solver_natural_api.py:174(__init__)
#      9208    0.015    0.000    0.020    0.000 numerictypes.py:293(issubclass_)
#     14179    0.015    0.000    0.018    0.000 __init__.py:2151(_check_in_list)
#     11815    0.015    0.000    0.021    0.000 base.py:257(_geom)
#      1916    0.015    0.000    1.061    0.001 patch.py:29(PolygonPath)
#     11318    0.014    0.000    0.088    0.000 base.py:320(_get_coords)
#      2173    0.014    0.000    0.279    0.000 construction.py:684(_try_cast)
#      6240    0.014    0.000    0.020    0.000 __init__.py:2012(_setattr_cm)
#     11000    0.014    0.000    0.102    0.000 polygon.py:139(__next__)
#      1688    0.014    0.000    0.014    0.000 {method 'round' of 'numpy.ndarray' objects}
#        10    0.014    0.001    0.713    0.071 <ipython-input-3-a4e7a57e50e3>:1(buildDistanceMatrix_Euclidean)
#       480    0.014    0.000    0.034    0.000 ticker.py:688(_compute_offset)
#      1788    0.014    0.000    0.022    0.000 ticker.py:576(__call__)
#      8234    0.014    0.000    0.057    0.000 common.py:1702(is_extension_array_dtype)
#      2755    0.014    0.000    0.035    0.000 transforms.py:726(__init__)
#      5500    0.014    0.000    0.014    0.000 {built-in method numpy.copyto}
#     23678    0.014    0.000    0.014    0.000 base.py:222(empty)
#      2748    0.013    0.000    0.196    0.000 managers.py:1443(__init__)
#      2339    0.013    0.000    0.072    0.000 text.py:270(_get_layout)
#      1788    0.013    0.000    0.013    0.000 transforms.py:2867(_interval_contains_close)
#      3210    0.013    0.000    0.030    0.000 blocks.py:78(__init__)
#      1916    0.013    0.000    0.265    0.000 patch.py:64(<listcomp>)
#      7594    0.013    0.000    0.035    0.000 transforms.py:1819(__init__)
#     74259    0.013    0.000    0.013    0.000 {method 'append' of 'list' objects}
#      7168    0.013    0.000    0.013    0.000 {built-in method builtins.repr}
#      4778    0.013    0.000    0.029    0.000 common.py:160(is_sparse)
#      7180    0.013    0.000    0.031    0.000 inference.py:253(is_list_like)
#      3867    0.013    0.000    0.045    0.000 patches.py:277(_set_edgecolor)
#      1916    0.012    0.000    0.335    0.000 patch.py:67(<listcomp>)
# 21917/17900    0.012    0.000    0.036    0.000 {built-in method builtins.hash}
#      7076    0.012    0.000    0.034    0.000 __init__.py:1382(_to_unmasked_float_array)
#      5548    0.012    0.000    0.399    0.000 linestring.py:84(array_interface)
#      1091    0.012    0.000    0.055    0.000 font_manager.py:620(__init__)
#      2156    0.012    0.000    0.199    0.000 series.py:865(__getitem__)
#      4251    0.012    0.000    0.014    0.000 contextlib.py:81(__init__)
#     60680    0.012    0.000    0.012    0.000 path.py:251(should_simplify)
#      4604    0.011    0.000    0.032    0.000 numerictypes.py:365(issubdtype)
#       435    0.011    0.000    1.966    0.005 collections.py:249(draw)
#         1    0.011    0.011  307.371  307.371 <ipython-input-7-52f7402de033>:1(solveAndPlot)
#      1050    0.011    0.000    0.011    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_Constraint}
#       480    0.011    0.000    0.253    0.001 ops.py:1660(wrapper)
#       660    0.011    0.000    0.015    0.000 transforms.py:2791(nonsingular)
# 3797/2437    0.011    0.000    0.013    0.000 transforms.py:137(_invalidate_internal)
#      1093    0.011    0.000    0.050    0.000 cast.py:846(maybe_infer_to_datetimelike)
#     60680    0.011    0.000    0.011    0.000 path.py:230(simplify_threshold)
#      1542    0.011    0.000    0.025    0.000 lines.py:1145(set_linestyle)
#      2156    0.011    0.000    0.020    0.000 {method 'get_value' of 'pandas._libs.index.IndexEngine' objects}
#      3210    0.011    0.000    0.189    0.000 blocks.py:3080(make_block)
#         9    0.011    0.001    0.012    0.001 {built-in method ortools.constraint_solver._pywrapcp.RoutingModel_SolveWithParameters}
#      2339    0.011    0.000    0.046    0.000 text.py:823(get_prop_tup)
#     26034    0.011    0.000    0.011    0.000 impl.py:56(__getitem__)
#        72    0.011    0.000    0.011    0.000 socket.py:337(send)
#      1316    0.010    0.000    0.027    0.000 shape_base.py:599(column_stack)
#      3359    0.010    0.000    0.010    0.000 {built-in method matplotlib._path.affine_transform}
#     11815    0.010    0.000    0.017    0.000 base.py:233(__del__)
#      7782    0.010    0.000    0.038    0.000 artist.py:49(_stale_axes_callback)
#      1626    0.010    0.000    0.076    0.000 markers.py:292(set_marker)
#      1052    0.010    0.000    0.071    0.000 text.py:121(__init__)
#      4101    0.010    0.000    0.025    0.000 text.py:809(get_unitless_position)
#       162    0.010    0.000    0.010    0.000 {method 'acquire' of '_thread.lock' objects}
# 9894/5228    0.010    0.000    0.013    0.000 transforms.py:2357(<lambda>)
#      2598    0.010    0.000    0.098    0.000 transforms.py:1377(transform)
#       480    0.010    0.000    0.016    0.000 ticker.py:727(_set_order_of_magnitude)
#      3867    0.010    0.000    0.166    0.000 patches.py:303(_set_facecolor)
#     12001    0.010    0.000    0.012    0.000 artist.py:338(pchanged)
#      8340    0.010    0.000    0.012    0.000 linear_solver_natural_api.py:187(AddSelfToCoeffMapOrStack)
#      1566    0.010    0.000    0.010    0.000 {method 'round' of 'numpy.generic' objects}
#     46098    0.010    0.000    0.010    0.000 {method 'items' of 'dict' objects}
#       754    0.010    0.000    0.762    0.001 axis.py:289(draw)
#      2508    0.009    0.000    0.117    0.000 transforms.py:1470(transform_point)
#     38356    0.009    0.000    0.009    0.000 artist.py:194(axes)
#      3077    0.009    0.000    0.046    0.000 dtypes.py:973(is_dtype)
#      1268    0.009    0.000    0.009    0.000 stride_tricks.py:185(_broadcast_shape)
#      2748    0.009    0.000    0.012    0.000 series.py:354(_set_axis)
#      6187    0.009    0.000    0.014    0.000 artist.py:373(get_transform)
#       348    0.009    0.000    0.042    0.000 algorithms.py:1544(take_nd)
#      5333    0.008    0.000    0.028    0.000 {pandas._libs.lib.values_from_object}
#      1845    0.008    0.000    0.046    0.000 transforms.py:1976(scale)
#       366    0.008    0.000    0.008    0.000 {pandas._libs.ops.scalar_compare}
#     17302    0.008    0.000    0.012    0.000 common.py:119(<lambda>)
#      6360    0.008    0.000    0.051    0.000 linear_solver_natural_api.py:119(__rmul__)
#     11407    0.008    0.000    0.008    0.000 fromnumeric.py:70(<dictcomp>)
#      9398    0.008    0.000    0.037    0.000 base.py:347(geometryType)
#      4251    0.008    0.000    0.020    0.000 contextlib.py:116(__exit__)
#      9073    0.008    0.000    0.089    0.000 common.py:434(is_datetime64tz_dtype)
# 3312/3310    0.008    0.000    0.021    0.000 transforms.py:1776(transform_affine)
#      1916    0.008    0.000    0.171    0.000 patch.py:68(<listcomp>)
#   288/257    0.008    0.000    0.046    0.000 base.py:253(__new__)
#     11000    0.008    0.000    0.008    0.000 polygon.py:31(__init__)
#      8973    0.008    0.000    0.053    0.000 {built-in method builtins.next}
#      3832    0.008    0.000    0.008    0.000 polygon.py:150(__len__)
#      3267    0.008    0.000    0.009    0.000 blocks.py:199(mgr_locs)
#       839    0.008    0.000    0.033    0.000 font_manager.py:1179(findfont)
#      1093    0.008    0.000    0.009    0.000 font_manager.py:776(set_weight)
#      1773    0.008    0.000    0.008    0.000 {built-in method builtins.sorted}
#       167    0.008    0.000    0.015    0.000 managers.py:186(_rebuild_blknos_and_blklocs)
#      3084    0.008    0.000    0.012    0.000 lines.py:1112(_split_drawstyle_linestyle)
#      7350    0.008    0.000    0.008    0.000 {built-in method ortools.linear_solver._pywraplp.Constraint_SetCoefficient}
#      3719    0.008    0.000    0.012    0.000 {method 'view' of 'numpy.ndarray' objects}
#      1729    0.008    0.000    0.026    0.000 blocks.py:2626(__init__)
#      4391    0.008    0.000    0.008    0.000 {built-in method builtins.callable}
#      7035    0.007    0.000    0.015    0.000 lines.py:59(_scale_dashes)
#     10153    0.007    0.000    0.009    0.000 base.py:652(__len__)
#      4161    0.007    0.000    0.013    0.000 series.py:392(name)
#      1268    0.007    0.000    0.025    0.000 stride_tricks.py:208(broadcast_arrays)
#      6326    0.007    0.000    0.016    0.000 managers.py:1522(dtype)
#      1928    0.007    0.000    0.017    0.000 patches.py:375(set_linestyle)
#      1926    0.007    0.000    0.018    0.000 numeric.py:2656(seterr)
#      2678    0.007    0.000    0.010    0.000 base.py:3918(__contains__)
#       279    0.007    0.000    0.011    0.000 collections.py:839(set_sizes)
#       638    0.007    0.000    0.020    0.000 patches.py:504(_bind_draw_path_function)
#      1136    0.007    0.000    0.480    0.000 frame.py:797(iterrows)
#      4240    0.007    0.000    0.041    0.000 fromnumeric.py:54(_wrapfunc)
#      7870    0.007    0.000    0.007    0.000 blocks.py:308(dtype)
#      3252    0.007    0.000    0.054    0.000 markers.py:245(_recache)
#     17302    0.007    0.000    0.007    0.000 common.py:117(classes)
#      1926    0.007    0.000    0.007    0.000 numeric.py:2758(geterr)
#       240    0.007    0.000    0.362    0.002 axis.py:2486(get_tick_space)
#       240    0.007    0.000    0.374    0.002 axis.py:2179(get_tick_space)
# 2064/2056    0.007    0.000    0.010    0.000 spines.py:487(get_spine_transform)
#      5500    0.007    0.000    0.035    0.000 numeric.py:175(ones)
#      4951    0.007    0.000    0.011    0.000 managers.py:1549(internal_values)
#      1269    0.007    0.000    0.026    0.000 axis.py:617(update_position)
#      7350    0.007    0.000    0.014    0.000 pywraplp.py:458(SetCoefficient)
#      3221    0.007    0.000    0.022    0.000 dtypes.py:827(is_dtype)
#     20879    0.007    0.000    0.007    0.000 {method 'startswith' of 'str' objects}
#      7764    0.007    0.000    0.014    0.000 figure.py:49(_stale_figure_callback)
#      4633    0.007    0.000    0.032    0.000 common.py:403(is_datetime64_dtype)
#      3417    0.006    0.000    0.050    0.000 fromnumeric.py:2083(any)
#      4251    0.006    0.000    0.020    0.000 contextlib.py:237(helper)
#      5940    0.006    0.000    0.043    0.000 common.py:572(is_categorical_dtype)
#     25028    0.006    0.000    0.006    0.000 geos.py:545(errcheck_predicate)
#      7168    0.006    0.000    0.021    0.000 polygon.py:180(gtag)
#     14218    0.006    0.000    0.006    0.000 managers.py:1488(_block)
#      6768    0.006    0.000    0.016    0.000 integer.py:80(construct_from_string)
#      2644    0.006    0.000    0.030    0.000 transforms.py:1748(frozen)
#      2423    0.006    0.000    0.055    0.000 patches.py:209(get_transform)
#      3517    0.006    0.000    0.008    0.000 lines.py:31(_get_dash_pattern)
#     23912    0.006    0.000    0.006    0.000 {built-in method _ctypes.byref}
#      3832    0.006    0.000    0.038    0.000 polygon.py:260(interiors)
#      1033    0.006    0.000    0.022    0.000 axis.py:500(update_position)
#      5349    0.006    0.000    0.010    0.000 lines.py:1294(set_ydata)
#     13619    0.006    0.000    0.006    0.000 {method 'pop' of 'dict' objects}
#      3206    0.006    0.000    0.012    0.000 artist.py:673(set_figure)
#      6326    0.006    0.000    0.022    0.000 series.py:406(dtype)
#      4077    0.006    0.000    0.024    0.000 transforms.py:2470(composite_transform_factory)
#      1093    0.005    0.000    0.007    0.000 font_manager.py:812(set_size)
#      2636    0.005    0.000    0.019    0.000 managers.py:1556(get_values)
#      2157    0.005    0.000    0.016    0.000 base.py:2849(_convert_scalar_indexer)
#      4251    0.005    0.000    0.043    0.000 contextlib.py:107(__enter__)
#       298    0.005    0.000    0.007    0.000 numerictypes.py:578(_can_coerce_all)
#      9524    0.005    0.000    0.005    0.000 {built-in method builtins.iter}
#      2598    0.005    0.000    0.068    0.000 transforms.py:2371(transform_affine)
#      4641    0.005    0.000    0.009    0.000 lines.py:1282(set_xdata)
#       442    0.005    0.000    0.157    0.000 base.py:103(_unary_op)
#       480    0.005    0.000    0.006    0.000 ticker.py:1828(scale_range)
#       116    0.005    0.000    2.151    0.019 axis.py:1195(draw)
#      1916    0.005    0.000    1.398    0.001 patch.py:73(PolygonPatch)
#         1    0.005    0.005    0.005    0.005 backend_agg.py:80(__init__)
#      3156    0.005    0.000    0.005    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      1022    0.005    0.000    0.005    0.000 {built-in method numpy.arange}
#       319    0.005    0.000    0.154    0.000 patches.py:563(draw)
#      1820    0.005    0.000    0.082    0.000 common.py:1643(is_extension_type)
#      1602    0.005    0.000    0.005    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       811    0.005    0.000    0.006    0.000 text.py:41(get_rotation)
#      1611    0.005    0.000    0.017    0.000 artist.py:946(_update_property)
#      7411    0.005    0.000    0.005    0.000 {built-in method __new__ of type object at 0x00007FFF42D56BA0}
#      4159    0.005    0.000    0.042    0.000 common.py:262(is_categorical)
#      1860    0.005    0.000    0.013    0.000 path.py:159(_fast_from_codes_and_verts)
#      1542    0.005    0.000    0.009    0.000 lines.py:1398(set_dash_capstyle)
#      2521    0.005    0.000    0.012    0.000 common.py:868(is_integer_dtype)
#      9905    0.005    0.000    0.005    0.000 transforms.py:1857(get_matrix)
#       839    0.005    0.000    0.045    0.000 backend_agg.py:241(_get_agg_font)
#      5034    0.005    0.000    0.009    0.000 font_manager.py:1233(<genexpr>)
#      3404    0.005    0.000    0.031    0.000 fromnumeric.py:2512(amin)
#       270    0.005    0.000    0.010    0.000 coords.py:69(__getitem__)
#       240    0.005    0.000    0.418    0.002 axis.py:1326(get_minorticklocs)
#       480    0.005    0.000    0.834    0.002 ticker.py:2080(tick_values)
#      1106    0.005    0.000    0.019    0.000 transforms.py:1506(transform_path_non_affine)
# 2299/1275    0.005    0.000    0.009    0.000 _base.py:660(get_xaxis_transform)
#      6108    0.005    0.000    0.013    0.000 artist.py:170(convert_xunits)
#      1396    0.005    0.000    0.012    0.000 transforms.py:2299(__init__)
#      2437    0.004    0.000    0.017    0.000 transforms.py:126(invalidate)
#      3254    0.004    0.000    0.034    0.000 fromnumeric.py:2940(around)
#       559    0.004    0.000    0.026    0.000 base.py:1117(__iter__)
#      1091    0.004    0.000    0.006    0.000 font_manager.py:794(set_stretch)
#      1050    0.004    0.000    0.016    0.000 pywraplp.py:170(Constraint)
#      3464    0.004    0.000    0.029    0.000 fromnumeric.py:2397(amax)
#      4951    0.004    0.000    0.016    0.000 series.py:476(_values)
#       370    0.004    0.000    0.161    0.000 frame.py:2893(__getitem__)
#      3195    0.004    0.000    0.006    0.000 series.py:399(name)
#      4679    0.004    0.000    0.004    0.000 {built-in method builtins.max}
#      3867    0.004    0.000    0.005    0.000 cycler.py:225(__iter__)
#      1938    0.004    0.000    0.009    0.000 patches.py:355(set_linewidth)
#       877    0.004    0.000    0.007    0.000 dtypes.py:786(construct_from_string)
#      3633    0.004    0.000    0.023    0.000 transforms.py:1236(__add__)
#      3832    0.004    0.000    0.005    0.000 polygon.py:129(__init__)
#       240    0.004    0.000    0.187    0.001 axis.py:1149(<listcomp>)
#       480    0.004    0.000    0.009    0.000 _methods.py:151(_ptp)
#      4560    0.004    0.000    0.058    0.000 linear_solver_natural_api.py:223(Sum)
#      1928    0.004    0.000    0.103    0.000 patches.py:409(set_fill)
#     16416    0.004    0.000    0.004    0.000 {method 'lower' of 'str' objects}
#         9    0.004    0.000    0.004    0.000 {built-in method ortools.constraint_solver._pywrapcp.new_RoutingModel}
#     11318    0.004    0.000    0.004    0.000 coords.py:41(__init__)
#      6220    0.004    0.000    0.010    0.000 artist.py:182(convert_yunits)
#      2057    0.004    0.000    0.025    0.000 base.py:3975(_can_hold_identifiers_and_holds_name)
#      9480    0.004    0.000    0.004    0.000 transforms.py:946(get_points)
#      1006    0.004    0.000    0.046    0.000 base.py:434(distance)
#      3002    0.004    0.000    0.017    0.000 common.py:472(is_timedelta64_dtype)
#      1114    0.004    0.000    0.029    0.000 text.py:170(update)
#      5114    0.004    0.000    0.008    0.000 <string>:1(__new__)
#      2650    0.004    0.000    0.009    0.000 artist.py:360(set_transform)
#      3584    0.004    0.000    0.005    0.000 common.py:1809(_get_dtype)
#       480    0.004    0.000    0.841    0.002 ticker.py:2076(__call__)
#      6429    0.004    0.000    0.014    0.000 numeric.py:541(asanyarray)
#      2262    0.004    0.000    0.010    0.000 lines.py:953(_get_markerfacecolor)
#        58    0.004    0.000    0.046    0.001 _base.py:2425(handle_single_axis)
#      1542    0.004    0.000    0.008    0.000 lines.py:1095(set_linewidth)
#      1542    0.004    0.000    0.035    0.000 lines.py:1241(set_markerfacecolor)
#      3263    0.004    0.000    0.050    0.000 common.py:536(is_interval_dtype)
#       140    0.004    0.000    0.004    0.000 __init__.py:1673(normalize_kwargs)
#       960    0.004    0.000    0.010    0.000 linear_solver_natural_api.py:128(__neg__)
#      2291    0.004    0.000    0.005    0.000 artist.py:828(_set_gc_clip)
#      6994    0.004    0.000    0.028    0.000 base.py:421(geom_type)
#      7726    0.004    0.000    0.004    0.000 cycler.py:371(<genexpr>)
#     12742    0.004    0.000    0.004    0.000 artist.py:838(get_rasterized)
#      2598    0.004    0.000    0.012    0.000 transforms.py:2375(transform_non_affine)
#      3134    0.004    0.000    0.005    0.000 __init__.py:1916(_str_lower_equal)
#        62    0.004    0.000    0.043    0.001 _base.py:2503(_update_title_position)
#       252    0.004    0.000    0.013    0.000 missing.py:183(_isna_ndarraylike)
#       754    0.004    0.000    0.023    0.000 transforms.py:2710(_revalidate)
#      1626    0.004    0.000    0.085    0.000 markers.py:223(__init__)
#       960    0.004    0.000    0.004    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_IntVar}
#      3832    0.004    0.000    0.011    0.000 polygon.py:134(__iter__)
#     10676    0.004    0.000    0.004    0.000 {method 'get' of 'dict' objects}
#         2    0.004    0.002    0.026    0.013 collections.py:1810(<listcomp>)
#     12313    0.004    0.000    0.004    0.000 artist.py:770(get_visible)
#      3792    0.004    0.000    0.005    0.000 function_base.py:258(iterable)
#      3221    0.004    0.000    0.026    0.000 common.py:503(is_period_dtype)
#      1542    0.003    0.000    0.007    0.000 lines.py:1352(set_dash_joinstyle)
#      5680    0.003    0.000    0.003    0.000 artist.py:199(axes)
#       368    0.003    0.000    0.028    0.000 managers.py:318(apply)
#      1978    0.003    0.000    0.013    0.000 axis.py:1881(getter)
#       435    0.003    0.000    0.016    0.000 collections.py:212(_prepare_points)
#      1542    0.003    0.000    0.007    0.000 lines.py:1412(set_solid_capstyle)
#      1542    0.003    0.000    0.006    0.000 lines.py:1061(set_drawstyle)
#      1032    0.003    0.000    0.010    0.000 transforms.py:2654(__init__)
#       480    0.003    0.000    0.115    0.000 ticker.py:677(set_locs)
#      1542    0.003    0.000    0.011    0.000 lines.py:648(set_data)
#       480    0.003    0.000    0.029    0.000 ops.py:1615(na_op)
#      3210    0.003    0.000    0.003    0.000 blocks.py:89(_check_ndim)
#      1916    0.003    0.000    0.332    0.000 patches.py:942(__init__)
#      1601    0.003    0.000    0.017    0.000 transforms.py:362(ymax)
#      3254    0.003    0.000    0.037    0.000 fromnumeric.py:3373(round_)
#        57    0.003    0.000    0.015    0.000 managers.py:868(fast_xs)
#      1908    0.003    0.000    0.009    0.000 ticker.py:567(fix_minus)
#        29    0.003    0.000    6.313    0.218 plotting.py:214(plot_series)
#       254    0.003    0.000    0.077    0.000 transforms.py:697(union)
#      1365    0.003    0.000    0.006    0.000 __init__.py:1373(is_math_text)
#       480    0.003    0.000    0.025    0.000 ticker.py:259(<listcomp>)
#      1936    0.003    0.000    0.005    0.000 patches.py:431(set_capstyle)
#      1542    0.003    0.000    0.021    0.000 lines.py:1255(set_markerfacecoloralt)
#       259    0.003    0.000    0.085    0.000 axis.py:573(_get_tick1line)
#      1626    0.003    0.000    0.006    0.000 markers.py:267(set_fillstyle)
#       255    0.003    0.000    0.089    0.000 axis.py:458(_get_tick1line)
#   306/305    0.003    0.000    0.006    0.000 transforms.py:413(bounds)
#      7199    0.003    0.000    0.003    0.000 {method 'update' of 'dict' objects}
#         2    0.003    0.002    1.483    0.742 plotting.py:48(plot_polygon_collection)
#       259    0.003    0.000    0.091    0.000 axis.py:602(_get_gridline)
#      1020    0.003    0.000    0.040    0.000 linear_solver_natural_api.py:143(__le__)
#      3120    0.003    0.000    0.004    0.000 __init__.py:2017(<listcomp>)
#      1541    0.003    0.000    0.016    0.000 transforms.py:352(ymin)
#      1373    0.003    0.000    0.004    0.000 transforms.py:377(intervalx)
#      3832    0.003    0.000    0.044    0.000 patch.py:21(interiors)
#      1542    0.003    0.000    0.006    0.000 lines.py:1367(set_solid_joinstyle)
#      1355    0.003    0.000    0.016    0.000 transforms.py:347(xmin)
#     12742    0.003    0.000    0.003    0.000 artist.py:858(get_agg_filter)
#      2291    0.003    0.000    0.056    0.000 backend_bases.py:654(new_gc)
#      4061    0.003    0.000    0.004    0.000 __init__.py:1906(_str_equal)
#      5223    0.003    0.000    0.006    0.000 transforms.py:178(<lambda>)
#      2200    0.003    0.000    0.015    0.000 arrays.py:7(extract_array)
#       222    0.003    0.000    0.041    0.000 series.py:3600(_reduce)
#        70    0.003    0.000    0.019    0.000 managers.py:772(_interleave)
#      3867    0.003    0.000    0.003    0.000 cycler.py:138(keys)
#      2730    0.003    0.000    0.003    0.000 {method 'count' of 'str' objects}
#       255    0.003    0.000    0.091    0.000 axis.py:484(_get_gridline)
# 2335/1295    0.003    0.000    0.007    0.000 _base.py:736(get_yaxis_transform)
#      3832    0.003    0.000    0.072    0.000 patch.py:16(exterior)
#       240    0.003    0.000    0.004    0.000 spines.py:254(_adjust_location)
#      2150    0.003    0.000    0.004    0.000 range.py:510(__len__)
#      2667    0.003    0.000    0.007    0.000 artist.py:905(set_visible)
#       259    0.003    0.000    0.049    0.000 axis.py:543(_get_text1)
#       985    0.003    0.000    0.010    0.000 common.py:1578(is_bool_dtype)
#      3600    0.003    0.000    0.038    0.000 linear_solver_natural_api.py:104(__add__)
#      1184    0.003    0.000    0.006    0.000 dtypes.py:672(construct_from_string)
#         9    0.003    0.000    0.471    0.052 <ipython-input-5-4ad955854af3>:1(convertTourToPathDF)
#       255    0.003    0.000    0.048    0.000 axis.py:425(_get_text1)
#      1373    0.003    0.000    0.004    0.000 transforms.py:386(intervaly)
#   813/812    0.003    0.000    0.009    0.000 transforms.py:1025(get_points)
#       348    0.003    0.000    0.008    0.000 algorithms.py:1417(_get_take_nd_function)
#      2057    0.003    0.000    0.015    0.000 base.py:1681(is_object)
#      2072    0.003    0.000    0.009    0.000 {built-in method builtins.all}
#      2570    0.003    0.000    0.011    0.000 axis.py:325(_set_artist_props)
#      2636    0.003    0.000    0.022    0.000 series.py:490(get_values)
#      2310    0.003    0.000    0.008    0.000 transforms.py:2133(<lambda>)
#       147    0.003    0.000    0.025    0.000 patches.py:728(_update_patch_transform)
#       174    0.003    0.000    0.023    0.000 generic.py:5948(fillna)
#      2636    0.003    0.000    0.009    0.000 blocks.py:184(to_dense)
#      1431    0.003    0.000    0.004    0.000 shape_base.py:220(_warn_for_nonsequence)
# 3192/3190    0.003    0.000    0.023    0.000 transforms.py:1696(transform)
#        29    0.003    0.000    0.048    0.002 plotting.py:8(_flatten_multi_geoms)
#       118    0.003    0.000    0.024    0.000 _base.py:1446(apply_aspect)
#      3416    0.003    0.000    0.009    0.000 transforms.py:2181(get_affine)
#      4670    0.003    0.000    0.003    0.000 transforms.py:1671(<lambda>)
#      1542    0.003    0.000    0.009    0.000 lines.py:733(set_transform)
#      1860    0.003    0.000    0.007    0.000 transforms.py:2149(transform_non_affine)
#      1091    0.003    0.000    0.006    0.000 font_manager.py:757(set_style)
#       839    0.003    0.000    0.004    0.000 backend_agg.py:49(get_hinting_flag)
#      1355    0.003    0.000    0.013    0.000 transforms.py:357(xmax)
#      1064    0.003    0.000    0.006    0.000 text.py:1122(set_verticalalignment)
#      2276    0.002    0.000    0.007    0.000 patches.py:223(get_patch_transform)
#      3022    0.002    0.000    0.005    0.000 base.py:5318(ensure_index)
#      1075    0.002    0.000    0.002    0.000 {pandas._libs.lib.infer_datetimelike_array}
#      2958    0.002    0.000    0.007    0.000 backend_bases.py:918(set_foreground)
#      2864    0.002    0.000    0.010    0.000 transforms.py:2047(transform)
#       370    0.002    0.000    0.168    0.000 geodataframe.py:465(__getitem__)
#      1050    0.002    0.000    0.136    0.000 pywraplp.py:258(Add)
#      1795    0.002    0.000    0.006    0.000 cast.py:1218(construct_1d_ndarray_preserving_na)
#       754    0.002    0.000    0.006    0.000 transforms.py:2694(__init__)
#       548    0.002    0.000    0.005    0.000 __init__.py:968(get_siblings)
#      2748    0.002    0.000    0.002    0.000 series.py:382(_set_subtyp)
#       259    0.002    0.000    0.072    0.000 axis.py:588(_get_tick2line)
#     87/29    0.002    0.000    4.344    0.150 image.py:117(_draw_list_compositing_images)
#   444/222    0.002    0.000    0.025    0.000 transforms.py:2320(frozen)
#      1334    0.002    0.000    0.005    0.000 geodataframe.py:60(__setattr__)
#      1542    0.002    0.000    0.004    0.000 lines.py:635(axes)
#       347    0.002    0.000    0.009    0.000 cast.py:255(maybe_promote)
#      1627    0.002    0.000    0.002    0.000 dtypes.py:452(construct_from_string)
#      2778    0.002    0.000    0.009    0.000 common.py:316(apply_if_callable)
#       175    0.002    0.000    0.005    0.000 transforms.py:1914(rotate)
#      3150    0.002    0.000    0.007    0.000 text.py:1100(set_y)
#       116    0.002    0.000    0.004    0.000 indexing.py:2575(maybe_convert_indices)
#       839    0.002    0.000    0.002    0.000 {method 'clear' of 'matplotlib.ft2font.FT2Font' objects}
#       514    0.002    0.000    0.004    0.000 axis.py:198(_set_labelrotation)
#      2801    0.002    0.000    0.019    0.000 artist.py:974(<listcomp>)
#      2291    0.002    0.000    0.003    0.000 backend_bases.py:976(get_hatch_path)
#      2334    0.002    0.000    0.007    0.000 scale.py:101(get_transform)
#       222    0.002    0.000    0.025    0.000 nanops.py:203(_get_values)
#      4777    0.002    0.000    0.002    0.000 text.py:1136(set_text)
#      1928    0.002    0.000    0.004    0.000 patches.py:450(set_joinstyle)
#       442    0.002    0.000    0.023    0.000 base.py:106(<listcomp>)
#     11771    0.002    0.000    0.002    0.000 {built-in method builtins.id}
#      1107    0.002    0.000    0.016    0.000 fromnumeric.py:2171(all)
#      4856    0.002    0.000    0.002    0.000 font_manager.py:676(get_family)
#       308    0.002    0.000    0.013    0.000 base.py:786(array)
#       480    0.002    0.000    0.011    0.000 fromnumeric.py:2324(ptp)
#      2094    0.002    0.000    0.008    0.000 axis.py:792(get_transform)
#      1788    0.002    0.000    0.013    0.000 axis.py:301(set_label1)
#       811    0.002    0.000    0.007    0.000 text.py:1178(_preprocess_math)
#       877    0.002    0.000    0.003    0.000 dtypes.py:929(construct_from_string)
#       660    0.002    0.000    0.003    0.000 getlimits.py:365(__new__)
#       346    0.002    0.000    0.047    0.000 blocks.py:1217(take_nd)
#       308    0.002    0.000    0.005    0.000 base.py:504(_simple_new)
#      2678    0.002    0.000    0.007    0.000 text.py:1089(set_x)
#      1542    0.002    0.000    0.003    0.000 lines.py:1269(set_markersize)
#       255    0.002    0.000    0.072    0.000 axis.py:469(_get_tick2line)
#       493    0.002    0.000    0.007    0.000 fromnumeric.py:41(_wrapit)
#       116    0.002    0.000    0.102    0.001 managers.py:1329(take)
#      1926    0.002    0.000    0.002    0.000 {built-in method numpy.seterrobj}
#       754    0.002    0.000    0.004    0.000 lines.py:928(get_markeredgecolor)
#       729    0.002    0.000    0.006    0.000 managers.py:139(shape)
#       754    0.002    0.000    0.010    0.000 lines.py:709(_transform_path)
#      2318    0.002    0.000    0.004    0.000 generic.py:426(_info_axis)
#      1268    0.002    0.000    0.004    0.000 stride_tricks.py:257(<listcomp>)
#      2237    0.002    0.000    0.015    0.000 {method 'max' of 'numpy.ndarray' objects}
#    456/87    0.002    0.000    0.003    0.000 arrayprint.py:716(recurser)
#       539    0.002    0.000    0.010    0.000 common.py:93(is_bool_indexer)
#       872    0.002    0.000    0.019    0.000 missing.py:105(_isna_new)
#       480    0.002    0.000    0.002    0.000 {method 'clip' of 'numpy.ndarray' objects}
#       512    0.002    0.000    0.006    0.000 _dtype.py:46(__str__)
#         2    0.002    0.001    1.400    0.700 plotting.py:103(<listcomp>)
#       172    0.002    0.000    0.006    0.000 colors.py:254(to_rgba_array)
#       754    0.002    0.000    0.003    0.000 markers.py:258(__bool__)
#      1788    0.002    0.000    0.013    0.000 axis.py:314(set_label2)
#       115    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#       960    0.002    0.000    0.002    0.000 ticker.py:1857(closeto)
#        58    0.002    0.000    4.343    0.075 _base.py:2573(draw)
#       312    0.002    0.000    0.005    0.000 cast.py:1193(construct_1d_object_array_from_listlike)
#      5289    0.002    0.000    0.002    0.000 text.py:841(get_text)
#       464    0.002    0.000    0.002    0.000 ticker.py:712(<genexpr>)
#      1938    0.002    0.000    0.025    0.000 patches.py:292(set_edgecolor)
#       255    0.002    0.000    0.042    0.000 axis.py:442(_get_text2)
#       259    0.002    0.000    0.042    0.000 axis.py:558(_get_text2)
# 2482/2479    0.002    0.000    0.005    0.000 transforms.py:2573(get_matrix)
#       480    0.002    0.000    0.090    0.000 ticker.py:256(format_ticks)
#      3804    0.002    0.000    0.002    0.000 stride_tricks.py:261(<genexpr>)
#      1091    0.002    0.000    0.004    0.000 font_manager.py:767(set_variant)
#      1078    0.002    0.000    0.004    0.000 artist.py:1005(set_zorder)
#       839    0.002    0.000    0.002    0.000 {method 'set_size' of 'matplotlib.ft2font.FT2Font' objects}
#       255    0.002    0.000    0.011    0.000 _base.py:684(get_xaxis_text1_transform)
#      5439    0.002    0.000    0.002    0.000 blocks.py:195(mgr_locs)
#       115    0.002    0.000    0.118    0.001 generic.py:3323(_take)
#      2513    0.002    0.000    0.003    0.000 transforms.py:1687(__array__)
#       122    0.002    0.000    0.005    0.000 numeric.py:2508(within_tol)
#      1916    0.002    0.000    0.003    0.000 patch.py:10(__init__)
#      4951    0.002    0.000    0.002    0.000 blocks.py:165(internal_values)
#       259    0.002    0.000    0.011    0.000 _base.py:760(get_yaxis_text1_transform)
#       237    0.002    0.000    0.003    0.000 core.py:2905(_update_from)
#      1897    0.002    0.000    0.002    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1542    0.002    0.000    0.004    0.000 lines.py:1227(set_markeredgewidth)
#      3358    0.002    0.000    0.002    0.000 figure.py:462(_get_dpi)
#       308    0.002    0.000    0.005    0.000 numpy_.py:35(__init__)
#      6177    0.002    0.000    0.002    0.000 font_manager.py:724(get_size_in_points)
#      2875    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_float}
#         1    0.002    0.002    0.006    0.006 <ipython-input-4-4f2ee41fde16>:19(<dictcomp>)
#      1542    0.002    0.000    0.004    0.000 lines.py:1038(set_antialiased)
#      2129    0.002    0.000    0.002    0.000 inference.py:438(is_hashable)
#       767    0.002    0.000    0.003    0.000 base.py:894(_get_geom_item)
#      2833    0.002    0.000    0.003    0.000 common.py:127(<lambda>)
#       963    0.002    0.000    0.012    0.000 numeric.py:3058(__enter__)
#      4544    0.002    0.000    0.002    0.000 {built-in method builtins.abs}
#      1052    0.002    0.000    0.003    0.000 text.py:918(set_color)
#       255    0.002    0.000    0.377    0.001 axis.py:1928(_get_tick)
#       898    0.002    0.000    0.011    0.000 blocks.py:225(make_block_same_class)
#       963    0.002    0.000    0.002    0.000 numeric.py:3054(__init__)
#        18    0.002    0.000    0.092    0.005 _axes.py:4312(scatter)
#      6299    0.002    0.000    0.002    0.000 {built-in method builtins.setattr}
#       259    0.002    0.000    0.374    0.001 axis.py:2217(_get_tick)
#      1054    0.002    0.000    0.004    0.000 text.py:934(set_horizontalalignment)
#      2721    0.002    0.000    0.002    0.000 {method 'replace' of 'str' objects}
#        29    0.002    0.000    4.378    0.151 figure.py:1661(draw)
#       319    0.002    0.000    0.090    0.000 backend_agg.py:119(draw_path)
#        58    0.002    0.000    0.004    0.000 transforms.py:534(anchored)
#       147    0.002    0.000    0.002    0.000 _base.py:4248(get_children)
#       127    0.002    0.000    0.017    0.000 cast.py:1072(find_common_type)
#       963    0.002    0.000    0.009    0.000 numeric.py:3063(__exit__)
#      1050    0.002    0.000    0.004    0.000 six.py:588(iteritems)
#         9    0.002    0.000    0.002    0.000 {built-in method ortools.constraint_solver._pywrapcp.DefaultRoutingSearchParameters}
#        29    0.002    0.000    0.002    0.000 {pandas._libs.lib.map_infer_mask}
#       960    0.002    0.000    0.034    0.000 linear_solver_natural_api.py:110(__sub__)
#      1052    0.002    0.000    0.004    0.000 text.py:1212(set_usetex)
#      2633    0.002    0.000    0.002    0.000 numerictypes.py:587(<listcomp>)
#      1672    0.002    0.000    0.002    0.000 {built-in method math.log10}
#      1019    0.002    0.000    0.009    0.000 {method 'any' of 'numpy.ndarray' objects}
#       115    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#      1102    0.002    0.000    0.002    0.000 backend_bases.py:851(set_alpha)
#       441    0.002    0.000    0.003    0.000 blocks.py:3100(_extend_blocks)
#       252    0.002    0.000    0.086    0.000 collections.py:863(draw)
#       579    0.002    0.000    0.003    0.000 ops.py:43(get_op_result_name)
#      1938    0.002    0.000    0.092    0.000 patches.py:310(set_facecolor)
#        60    0.002    0.000    0.360    0.006 axis.py:2004(_update_label_position)
#       480    0.002    0.000    0.003    0.000 ticker.py:1867(le)
#      1091    0.002    0.000    0.003    0.000 font_manager.py:744(set_family)
#       435    0.002    0.000    0.002    0.000 artist.py:163(have_units)
#       232    0.002    0.000    0.002    0.000 ticker.py:719(<genexpr>)
#      1073    0.002    0.000    0.002    0.000 backend_bases.py:868(set_antialiased)
#       514    0.002    0.000    0.057    0.000 lines.py:1021(get_path)
#      1508    0.002    0.000    0.002    0.000 lines.py:521(get_fillstyle)
#       259    0.002    0.000    0.009    0.000 _base.py:786(get_yaxis_text2_transform)
#       463    0.002    0.000    0.004    0.000 transforms.py:2415(__init__)
#       254    0.001    0.000    0.022    0.000 base.py:3940(__getitem__)
#       140    0.001    0.000    0.005    0.000 managers.py:963(iget)
#       519    0.001    0.000    0.002    0.000 generic.py:349(_get_axis_number)
#      2182    0.001    0.000    0.002    0.000 font_manager.py:928(_normalize_font_family)
#      1929    0.001    0.000    0.003    0.000 patches.py:264(set_antialiased)
#       255    0.001    0.000    0.009    0.000 _base.py:710(get_xaxis_text2_transform)
#       870    0.001    0.000    0.002    0.000 collections.py:683(get_edgecolor)
#       175    0.001    0.000    0.006    0.000 transforms.py:1930(rotate_deg)
#        60    0.001    0.000    0.364    0.006 axis.py:2298(_update_label_position)
#      1508    0.001    0.000    0.001    0.000 backend_agg.py:254(points_to_pixels)
#       979    0.001    0.000    0.035    0.000 generic.py:178(_validate_dtype)
#      1050    0.001    0.000    0.017    0.000 pywraplp.py:271(RowConstraint)
#       130    0.001    0.000    0.006    0.000 path.py:497(get_extents)
#      2833    0.001    0.000    0.001    0.000 common.py:122(classes_and_not_datetimelike)
#       259    0.001    0.000    0.004    0.000 axis.py:528(apply_tickdir)
#      3852    0.001    0.000    0.001    0.000 {built-in method numpy.geterrobj}
#      1542    0.001    0.000    0.003    0.000 lines.py:1212(set_markeredgecolor)
#       272    0.001    0.000    0.007    0.000 core.py:3663(filled)
#       839    0.001    0.000    0.003    0.000 font_manager.py:1338(get_font)
#       224    0.001    0.000    0.037    0.000 base.py:584(_shallow_copy_with_infer)
#        96    0.001    0.000    0.133    0.001 geoseries.py:58(x)
#      2237    0.001    0.000    0.013    0.000 _methods.py:26(_amax)
#       255    0.001    0.000    0.004    0.000 axis.py:411(apply_tickdir)
#      2508    0.001    0.000    0.001    0.000 transforms.py:2668(get_matrix)
#       900    0.001    0.000    0.001    0.000 <ipython-input-4-4f2ee41fde16>:36(<listcomp>)
#      1928    0.001    0.000    0.003    0.000 patches.py:469(set_hatch)
#       617    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       221    0.001    0.000    0.042    0.000 generic.py:11018(logical_func)
#      2404    0.001    0.000    0.014    0.000 base.py:350(type)
#       480    0.001    0.000    0.002    0.000 ticker.py:1846(__init__)
#       249    0.001    0.000    0.046    0.000 indexing.py:2205(_getitem_axis)
#        29    0.001    0.000    6.321    0.218 plotting.py:317(plot_dataframe)
#        96    0.001    0.000    0.128    0.001 geoseries.py:67(y)
#      1111    0.001    0.000    0.051    0.000 pywraplp.py:267(Sum)
#       559    0.001    0.000    0.014    0.000 common.py:702(is_datetimelike)
#       758    0.001    0.000    0.001    0.000 {built-in method _abc._abc_subclasscheck}
#      2100    0.001    0.000    0.002    0.000 pywraplp.py:215(infinity)
#       787    0.001    0.000    0.005    0.000 common.py:1198(is_datetime_or_timedelta_dtype)
#       156    0.001    0.000    0.031    0.000 managers.py:97(__init__)
#       772    0.001    0.000    0.010    0.000 markers.py:321(get_transform)
#       558    0.001    0.000    0.002    0.000 axis.py:1834(<genexpr>)
#        87    0.001    0.000    0.064    0.001 ops.py:1817(wrapper)
# ...
#         1    0.000    0.000    0.000    0.000 image.py:827(__init__)
#         7    0.000    0.000    0.000    0.000 backend_bases.py:2141(mpl_connect)
#         4    0.000    0.000    0.000    0.000 nanops.py:71(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:110(set_active)
#         1    0.000    0.000    0.000    0.000 legend.py:1250(_parse_legend_args)
#        18    0.000    0.000    0.000    0.000 legend_handler.py:345(get_numpoints)
#         2    0.000    0.000    0.001    0.000 _base.py:925(_gen_axes_patch)
#         2    0.000    0.000    0.000    0.000 axis.py:1582(set_label_text)
#         1    0.000    0.000    0.002    0.002 base.py:4447(get_indexer_for)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#       3/1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#         1    0.000    0.000    0.000    0.000 shape_base.py:1154(tile)
#         1    0.000    0.000    0.000    0.000 figure.py:70(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:1888(gca)
#        10    0.000    0.000    0.000    0.000 __init__.py:85(__hash__)
#         1    0.000    0.000    0.000    0.000 backend_bases.py:150(__init__)
#         1    0.000    0.000    0.000    0.000 figure.py:1882(_set_artist_props)
#         2    0.000    0.000    0.000    0.000 __init__.py:48(get_projection_class)
#        32    0.000    0.000    0.000    0.000 scale.py:31(__init__)
#         1    0.000    0.000    0.000    0.000 generic.py:1546(_is_label_reference)
#         4    0.000    0.000    0.000    0.000 gridspec.py:460(get_geometry)
#         2    0.000    0.000    0.000    0.000 pyplot.py:908(gca)
#         2    0.000    0.000    0.000    0.000 __init__.py:2053(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#         6    0.000    0.000    0.000    0.000 index_tricks.py:729(__getitem__)
#         5    0.000    0.000    0.000    0.000 __init__.py:76(__init__)
#         1    0.000    0.000    0.005    0.005 tight_layout.py:217(get_renderer)
#         1    0.000    0.000    0.000    0.000 figure.py:512(set_constrained_layout)
#         1    0.000    0.000    0.000    0.000 legend.py:978(set_title)
#         1    0.000    0.000    0.000    0.000 core.py:5686(max)
#         1    0.000    0.000    0.000    0.000 _validators.py:130(validate_kwargs)
#         4    0.000    0.000    0.000    0.000 tight_layout.py:108(<genexpr>)
#        18    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#         2    0.000    0.000    0.000    0.000 missing.py:530(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 managers.py:694(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#         2    0.000    0.000    0.000    0.000 figure.py:779(set_canvas)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#         1    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         2    0.000    0.000    0.000    0.000 generic.py:1576(<genexpr>)
#         2    0.000    0.000    0.000    0.000 transforms.py:770(null)
#        14    0.000    0.000    0.000    0.000 gridspec.py:457(get_gridspec)
#         1    0.000    0.000    0.000    0.000 figure.py:486(set_tight_layout)
#         1    0.000    0.000    0.000    0.000 {built-in method _operator.add}
#         1    0.000    0.000    0.000    0.000 _validators.py:114(_check_for_invalid_keys)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:237(set_time_limit)
#        18    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 base.py:1672(is_integer)
#         1    0.000    0.000    0.000    0.000 figure.py:543(set_constrained_layout_pads)
#         1    0.000    0.000    0.000    0.000 textpath.py:25(__init__)
#         1    0.000    0.000    0.000    0.000 base.py:2965(_convert_listlike_indexer)
#         9    0.000    0.000    0.000    0.000 collections.py:827(get_sizes)
#         2    0.000    0.000    0.026    0.013 collections.py:1809(set_paths)
#         1    0.000    0.000    0.000    0.000 generic.py:3461(xs)
#         2    0.000    0.000    0.000    0.000 transforms.py:2616(__init__)
#         5    0.000    0.000    0.000    0.000 figure.py:157(__call__)
#         8    0.000    0.000    0.000    0.000 axis.py:1462(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:212(_acquireLock)
#         2    0.000    0.000    0.000    0.000 patches.py:2214(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:1221(getLogger)
#         2    0.000    0.000    0.000    0.000 mathtext.py:3333(__init__)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:17(_get_left)
#         2    0.000    0.000    0.000    0.000 figure.py:108(bubble)
#         2    0.000    0.000    0.000    0.000 text.py:1027(set_fontsize)
#         3    0.000    0.000    0.000    0.000 nanops.py:63(check)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_Clear}
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetOffset}
#         1    0.000    0.000    0.001    0.001 <frozen importlib._bootstrap_external>:1272(find_spec)
#         2    0.000    0.000    0.000    0.000 core.py:293(_scalar_fill_value)
#         1    0.000    0.000    0.000    0.000 patches.py:337(set_alpha)
#         3    0.000    0.000    0.000    0.000 generic.py:3205(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:337(Clear)
#         1    0.000    0.000    0.000    0.000 __init__.py:662(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:2065(add)
#        20    0.000    0.000    0.000    0.000 artist.py:778(get_in_layout)
#         2    0.000    0.000    0.000    0.000 _base.py:3027(set_axis_on)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#         2    0.000    0.000    0.000    0.000 core.py:291(_extremum_fill_value)
#         2    0.000    0.000    0.000    0.000 gridspec.py:427(__init__)
#         1    0.000    0.000    0.000    0.000 legend.py:598(_set_artist_props)
#         2    0.000    0.000    0.000    0.000 _base.py:846(set_position)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:438(__getitem__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:311(<listcomp>)
#         2    0.000    0.000    0.000    0.000 numerictypes.py:238(obj2sctype)
#         2    0.000    0.000    0.000    0.000 frame.py:474(axes)
#         2    0.000    0.000    0.000    0.000 __init__.py:913(__init__)
#         1    0.000    0.000    0.000    0.000 cm.py:386(autoscale_None)
#         2    0.000    0.000    0.000    0.000 gridspec.py:519(__eq__)
#         2    0.000    0.000    0.000    0.000 figure.py:100(_entry_from_axes)
#         1    0.000    0.000    0.000    0.000 pywraplp.py:355(SetMinimization)
#         1    0.000    0.000    0.000    0.000 decorators.py:41(wrapper)
#         2    0.000    0.000    0.000    0.000 figure.py:160(__contains__)
#         2    0.000    0.000    0.000    0.000 weakref.py:51(_cb)
#         1    0.000    0.000    0.000    0.000 __init__.py:1930(getLogger)
#         1    0.000    0.000    0.000    0.000 figure.py:168(__init__)
#         2    0.000    0.000    0.000    0.000 six.py:180(find_module)
#         2    0.000    0.000    0.000    0.000 inspect.py:3010(bind)
#         2    0.000    0.000    0.000    0.000 text.py:1044(set_fontweight)
#         2    0.000    0.000    0.000    0.000 core.py:226(_get_dtype_of)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:21(_get_right)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:36(_relax_case)
#         1    0.000    0.000    0.000    0.000 managers.py:706(nblocks)
#         1    0.000    0.000    0.000    0.000 image.py:736(set_interpolation)
#         1    0.000    0.000    0.000    0.000 image.py:910(get_extent)
#         1    0.000    0.000    0.000    0.000 warnings.py:453(__init__)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:25(_get_bottom)
#         1    0.000    0.000    0.000    0.000 _axes.py:223(set_xlabel)
#         2    0.000    0.000    0.000    0.000 _base.py:898(set_axes_locator)
#         1    0.000    0.000    0.000    0.000 _validators.py:32(_check_for_default_values)
#         1    0.000    0.000    0.000    0.000 nanops.py:276(_wrap_results)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:29(_get_top)
#         2    0.000    0.000    0.000    0.000 gridspec.py:530(__hash__)
#         2    0.000    0.000    0.000    0.000 __init__.py:21(get_projection_class)
#         1    0.000    0.000    0.000    0.000 _base.py:1783(_sci)
#         2    0.000    0.000    0.000    0.000 core.py:211(_recursive_fill_value)
#         2    0.000    0.000    0.000    0.000 gridspec.py:144(_normalize)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2500(notify_axes_change)
#         1    0.000    0.000    0.000    0.000 text.py:1199(set_fontproperties)
#         1    0.000    0.000    0.000    0.000 base.py:2999(_convert_arr_indexer)
#         2    0.000    0.000    0.000    0.000 transforms.py:886(x0)
#         1    0.000    0.000    0.000    0.000 pyplot.py:3053(sci)
#         1    0.000    0.000    0.000    0.000 __init__.py:1322(get_backend)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:30(get_fig_manager)
#         1    0.000    0.000    0.000    0.000 image.py:246(changed)
#         1    0.000    0.000    0.000    0.000 legend.py:609(_set_loc)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#         1    0.000    0.000    0.000    0.000 types.py:164(__get__)
#         2    0.000    0.000    0.000    0.000 gridspec.py:310(locally_modified_subplot_params)
#         1    0.000    0.000    0.000    0.000 __init__.py:221(_releaseLock)
#         2    0.000    0.000    0.000    0.000 missing.py:71(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Solver_set_time_limit}
#         2    0.000    0.000    0.000    0.000 figure.py:1075(fixitems)
#         2    0.000    0.000    0.000    0.000 offsetbox.py:315(__init__)
#         1    0.000    0.000    0.000    0.000 core.py:306(minimum_fill_value)
#         1    0.000    0.000    0.000    0.000 _validators.py:10(_check_arg_length)
#         2    0.000    0.000    0.000    0.000 transforms.py:891(y0)
#         6    0.000    0.000    0.000    0.000 _subplots.py:110(get_subplotspec)
#         2    0.000    0.000    0.000    0.000 tight_layout.py:188(<genexpr>)
#         1    0.000    0.000    0.000    0.000 image.py:228(get_size)
#         2    0.000    0.000    0.000    0.000 _base.py:3915(set_navigate)
#         1    0.000    0.000    0.000    0.000 warnings.py:493(__exit__)
#         1    0.000    0.000    0.000    0.000 __init__.py:227(itervalues)
#         1    0.000    0.000    0.000    0.000 indexing.py:2676(is_nested_tuple)
#         2    0.000    0.000    0.000    0.000 gridspec.py:77(set_height_ratios)
#         2    0.000    0.000    0.000    0.000 gridspec.py:509(get_topmost_subplotspec)
#         1    0.000    0.000    0.000    0.000 image.py:803(set_filterrad)
#         2    0.000    0.000    0.000    0.000 widgets.py:33(__init__)
#         1    0.000    0.000    0.000    0.000 _axes.py:256(set_ylabel)
#         2    0.000    0.000    0.000    0.000 inspect.py:2609(__init__)
#         2    0.000    0.000    0.000    0.000 transforms.py:896(x1)
#         2    0.000    0.000    0.000    0.000 figure.py:101(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 _base.py:3931(set_navigate_mode)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.can_cast}
#         1    0.000    0.000    0.000    0.000 image.py:768(set_resample)
#         1    0.000    0.000    0.000    0.000 image.py:786(set_filternorm)
#         1    0.000    0.000    0.000    0.000 base.py:3035(_convert_list_indexer)
#         3    0.000    0.000    0.000    0.000 base.py:4698(_validate_indexer)
#         2    0.000    0.000    0.000    0.000 transforms.py:307(x1)
#         2    0.000    0.000    0.000    0.000 transforms.py:901(y1)
#         1    0.000    0.000    0.000    0.000 weakref.py:73(__eq__)
#         1    0.000    0.000    0.000    0.000 image.py:235(set_alpha)
#         1    0.000    0.000    0.000    0.000 base.py:1237(_get_names)
#         1    0.000    0.000    0.000    0.000 base.py:5381(_ensure_has_len)
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 core.py:1821(_check_mask_axis)
#         2    0.000    0.000    0.000    0.000 __init__.py:1342(is_interactive)
#         2    0.000    0.000    0.000    0.000 transforms.py:317(y1)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:156(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#         1    0.000    0.000    0.000    0.000 enum.py:628(value)
#         2    0.000    0.000    0.000    0.000 patches.py:1927(<listcomp>)
#         2    0.000    0.000    0.000    0.000 base.py:2915(is_int)
#         1    0.000    0.000    0.000    0.000 figure.py:2034(add_axobserver)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:755(set_minimumdescent)
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:2835(parameters)
#         1    0.000    0.000    0.000    0.000 legend.py:727(get_legend_handler_map)
#         1    0.000    0.000    0.000    0.000 {built-in method ortools.linear_solver._pywraplp.Objective_SetMinimization}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 re.py:232(compile)
#         2    0.000    0.000    0.000    0.000 gridspec.py:68(set_width_ratios)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:168(<listcomp>)
#         2    0.000    0.000    0.000    0.000 shape_base.py:1226(<genexpr>)
#         1    0.000    0.000    0.000    0.000 core.py:357(maximum_fill_value)
#         1    0.000    0.000    0.000    0.000 artist.py:580(set_snap)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:164(<listcomp>)
#         1    0.000    0.000    0.000    0.000 legend.py:1046(set_bbox_to_anchor)
#         1    0.000    0.000    0.000    0.000 generic.py:1693(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:160(<listcomp>)
#         2    0.000    0.000    0.000    0.000 legend.py:706(get_default_handler_map)
#         1    0.000    0.000    0.000    0.000 offsetbox.py:173(set_offset)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#         2    0.000    0.000    0.000    0.000 patches.py:1928(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:93(<listcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:1567(<listcomp>)
#         1    0.000    0.000    0.000    0.000 tight_layout.py:94(<listcomp>)
#         2    0.000    0.000    0.000    0.000 legend.py:675(_approx_text_height)
#         1    0.000    0.000    0.000    0.000 legend.py:958(get_frame)
#         1    0.000    0.000    0.000    0.000 generic.py:1627(<listcomp>)
#         2    0.000    0.000    0.000    0.000 __init__.py:914(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 artist.py:545(set_url)
#         3    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    0.000    0.000 indexing.py:937(_convert_for_reindex)
#         1    0.000    0.000    0.000    0.000 _pylab_helpers.py:116(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
